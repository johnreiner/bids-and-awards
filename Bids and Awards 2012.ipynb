# %%
import pandas as pd
import numpy as np

# %%
pd.options.display.max_columns = None
pd.options.display.max_rows = None

# %% [markdown]
# # Jan-Mar 2012

# %%
bajanmar2012 = pd.read_excel("C:/Users/wolfgang/Documents/Work/DPWH/PhilGEPS Data/2012/Bid Notice and Award Details Jan-Mar 2012.xlsx")

# %%
bajanmar2012.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112599 entries, 0 to 112598
# Data columns (total 26 columns):
# Organization_Name         112599 non-null object
# Reference_No              112599 non-null object
# Bid_Notice_Title          112599 non-null object
# Publish_Date              112599 non-null datetime64[ns]
# Classification            112599 non-null object
# Notice_Type               112599 non-null object
# Business_Category         112599 non-null object
# Funding_Source            112599 non-null object
# Procurement_Mode          112599 non-null object
# Trade_Agreement           112599 non-null object
# Approved_Budget           112599 non-null float64
# Item_No                   45194 non-null float64
# Item_Name                 45135 non-null object
# Item_Description          45034 non-null object
# Item_Budget               45194 non-null float64
# Closing_Date              112599 non-null datetime64[ns]
# Bid_Notice_Status         112599 non-null object
# ...

# %%
bajanmar2012.Bid_Notice_Status.value_counts().reset_index()
# Out:
#          index  Bid_Notice_Status
# 0       Closed              79729
# 1      Awarded              26773
# 2       Failed               3114
# 3    Cancelled               2941
# 4  Shortlisted                 42

# %%
Abajanmar2012 = bajanmar2012[bajanmar2012.Bid_Notice_Status == 'Awarded']

# %%
Abajanmar2012.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26773 entries, 3 to 112596
# Data columns (total 26 columns):
# Organization_Name         26773 non-null object
# Reference_No              26773 non-null object
# Bid_Notice_Title          26773 non-null object
# Publish_Date              26773 non-null datetime64[ns]
# Classification            26773 non-null object
# Notice_Type               26773 non-null object
# Business_Category         26773 non-null object
# Funding_Source            26773 non-null object
# Procurement_Mode          26773 non-null object
# Trade_Agreement           26773 non-null object
# Approved_Budget           26773 non-null float64
# Item_No                   11518 non-null float64
# Item_Name                 11518 non-null object
# Item_Description          11515 non-null object
# Item_Budget               11518 non-null float64
# Closing_Date              26773 non-null datetime64[ns]
# Bid_Notice_Status         26773 non-null object
# ...

# %%
Abajanmar2012.Organization_Name.value_counts()
# Out:
# PROVINCE OF LAGUNA                                              1553
# CITY OF SANTIAGO, ISABELA                                        988
# THE NATIONAL LIBRARY                                             907
# MUNICIPALITY OF KAPALONG, DAVAO DEL NORTE                        552
# MANILA INTERNATIONAL AIRPORT AUTHORITY                           539
# PROVINCE OF RIZAL                                                528
# CITY OF DIPOLOG, ZAMBOANGA DEL NORTE                             306
# NATIONAL LIBRARY OF THE PHILIPPINES                              258
# PROVINCE OF COMPOSTELA VALLEY                                    244
# MUNICIPALITY OF STO. TOMAS, BATANGAS                             244
# CITY OF ZAMBOANGA, ZAMBOANGA DEL SUR                             242
# CITY OF QUEZON                                                   238
# UNIVERSITY OF THE PHILIPPINES SYSTEM - DILIMAN                   223
# PROVINCE OF CAPIZ                                                218
# ...

# %% [markdown]
# ## Awarded DPWH

# %%
DPWH_Abajanmar2012 = Abajanmar2012[Abajanmar2012.Organization_Name == 'DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN']

# %%
DPWH_Abajanmar2012.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 36 entries, 2144 to 107528
# Data columns (total 26 columns):
# Organization_Name         36 non-null object
# Reference_No              36 non-null object
# Bid_Notice_Title          36 non-null object
# Publish_Date              36 non-null datetime64[ns]
# Classification            36 non-null object
# Notice_Type               36 non-null object
# Business_Category         36 non-null object
# Funding_Source            36 non-null object
# Procurement_Mode          36 non-null object
# Trade_Agreement           36 non-null object
# Approved_Budget           36 non-null float64
# Item_No                   17 non-null float64
# Item_Name                 17 non-null object
# Item_Description          17 non-null object
# Item_Budget               17 non-null float64
# Closing_Date              36 non-null datetime64[ns]
# Bid_Notice_Status         36 non-null object
# Award_No                  36 non-null float64
# ...

# %% [markdown]
# ### Awardees

# %%
DPWH_Abajanmar2012.Awardee.value_counts().reset_index()
# Out:
#                                            index  Awardee
# 0                              NORTHERN BUILDERS        3
# 1      P.T. DIAMOND MERCHANDISE AND CONSTRUCTION        2
# 2                 WERR CORPORATION INTERNATIONAL        2
# 3                      PERTCONSULT INTERNATIONAL        2
# 4         CARDNO EMERGING MARKETS PTY LTD (AUST)        2
# 5                     FIAT CONSTRUCTION SERVICES        2
# 6                 FOXROD AUTO PARTS AND SERVICES        2
# 7                          KANEMATSU CORPORATION        2
# 8               J. M. LUCIANO CONSTRUCTION, INC.        1
# 9               DESIGN CREST FURNITURE COMPONENT        1
# 10  UNITED TECHNOLOGIES CONSOLIDATED PARTNERSHIP        1
# 11                    TOKWING CONSTRUCTION CORP.        1
# 12               EQUI-PARCO CONSTRUCTION COMPANY        1
# 13                   O.R. SARMIENTO CONSTRUCTION        1
# 14                       A. M. ORETA & CO., INC.        1
# ...

# %% [markdown]
# ### Procurement Mode

# %%
DPWH_Abajanmar2012.Procurement_Mode.value_counts().reset_index()
# Out:
#                                index  Procurement_Mode
# 0                     Public Bidding                26
# 1                           Shopping                 7
# 2  International Competitive Bidding                 3

# %% [markdown]
# #### Public Bidding

# %%
DPWH_Abajanmar2012[DPWH_Abajanmar2012.Procurement_Mode == 'Public Bidding']
# Out:
#                                      Organization_Name Reference_No  \
# 2144    DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1699048
# 5515    DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1701261
# 7482    DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1702669
# 7483    DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1702669
# 17143   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1708857
# 17816   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1709384
# 17827   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1709398
# 32521   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1720082
# 32522   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1720082
# 32523   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1720082
# 32524   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1720082
# 39889   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1725743
# 52512   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1733908
# ...

# %% [markdown]
# #### Shopping

# %%
DPWH_Abajanmar2012[DPWH_Abajanmar2012.Procurement_Mode == 'Shopping']
# Out:
#                                     Organization_Name Reference_No  \
# 5307   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1701023
# 5419   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1701187
# 19535  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1710421
# 22273  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1712273
# 22299  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1712307
# 22310  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1712320
# 90336  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1762123
#
#                                         Bid_Notice_Title Publish_Date  \
# 5307   SUPPLY OF LOW CABINET, 2 SEATER SOFA, CENTER A...   2012-01-07
# 5419   SPARE PARTS/LABOR FOR MAZDA DOUBLE CAB PICK UP...   2012-01-07
# 19535  supply of vinyl tiles/installation for the rep...   2012-01-21
# 22273  SUPPLY OF VARIOUS CONST. MATERIALS FOR USE IN ...   2012-01-26
# 22299                      SUPPLY OF VARIOUS SPARE PARTS   2012-01-26
# ...

# %% [markdown]
# #### International Competitive Bidding

# %%
DPWH_Abajanmar2012[DPWH_Abajanmar2012.Procurement_Mode == 'International Competitive Bidding']
# Out:
#                                      Organization_Name Reference_No  \
# 93611   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1764949
# 93612   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1764949
# 105142  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN    1458090-2
#
#                                          Bid_Notice_Title Publish_Date  \
# 93611   ICD  6 Supply and Delivery of International Ro...   2012-03-17
# 93612   ICD  6 Supply and Delivery of International Ro...   2012-03-17
# 105142  CS IC 03 Consultancy Services for the Enhancem...   2012-03-27
#
#              Classification                 Notice_Type  \
# 93611                 Goods     Invitation to Bid (ITB)
# 93612                 Goods     Invitation to Bid (ITB)
# 105142  Consulting Services  Request for Proposal (RFP)
#
#                                    Business_Category   Funding_Source  \
# 93611   Engineering and Laboratory Testing Equipment           Others
# ...

# %% [markdown]
# ## City of Las Pinas

# %%
CLP_Abajanmar2012 = Abajanmar2012[Abajanmar2012.Organization_Name == 'CITY OF LAS PINAS']

# %%
CLP_Abajanmar2012.Procurement_Mode.value_counts().reset_index()
# Out:
#             index  Procurement_Mode
# 0  Public Bidding                 1

# %%
CLP_Abajanmar2012.Awardee.value_counts().reset_index()
# Out:
#                       index  Awardee
# 0  E.M. ANGELES ENTERPRISES        1

# %% [markdown]
# # Apr-Jun 2012

# %%
baaprjun2012 = pd.read_excel("C:/Users/wolfgang/Documents/Work/DPWH/PhilGEPS Data/2012/Bid Notice and Award Details Apr-June 2012.xlsx")

# %%
baaprjun2012.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 124430 entries, 0 to 124429
# Data columns (total 26 columns):
# Organization_Name         124430 non-null object
# Reference_No              124430 non-null object
# Bid_Notice_Title          124430 non-null object
# Publish_Date              124430 non-null datetime64[ns]
# Classification            124430 non-null object
# Notice_Type               124430 non-null object
# Business_Category         124430 non-null object
# Funding_Source            124430 non-null object
# Procurement_Mode          124430 non-null object
# Trade_Agreement           124430 non-null object
# Approved_Budget           124430 non-null float64
# Item_No                   46692 non-null float64
# Item_Name                 46590 non-null object
# Item_Description          46445 non-null object
# Item_Budget               46692 non-null float64
# Closing_Date              124430 non-null datetime64[ns]
# Bid_Notice_Status         124430 non-null object
# ...

# %%
baaprjun2012.Bid_Notice_Status.value_counts().reset_index()
# Out:
#          index  Bid_Notice_Status
# 0       Closed              90856
# 1      Awarded              26448
# 2       Failed               4115
# 3    Cancelled               2975
# 4  Shortlisted                 36

# %%
Abaaprjun2012 = baaprjun2012[baaprjun2012.Bid_Notice_Status == 'Awarded']

# %% [markdown]
# ## Awarded DPWH

# %%
DPWH_Abaaprjun2012 = Abaaprjun2012[Abaaprjun2012.Organization_Name == 'DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN']

# %%
DPWH_Abaaprjun2012.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 53 entries, 6623 to 124095
# Data columns (total 26 columns):
# Organization_Name         53 non-null object
# Reference_No              53 non-null object
# Bid_Notice_Title          53 non-null object
# Publish_Date              53 non-null datetime64[ns]
# Classification            53 non-null object
# Notice_Type               53 non-null object
# Business_Category         53 non-null object
# Funding_Source            53 non-null object
# Procurement_Mode          53 non-null object
# Trade_Agreement           53 non-null object
# Approved_Budget           53 non-null float64
# Item_No                   2 non-null float64
# Item_Name                 2 non-null object
# Item_Description          2 non-null object
# Item_Budget               2 non-null float64
# Closing_Date              53 non-null datetime64[ns]
# Bid_Notice_Status         53 non-null object
# Award_No                  53 non-null float64
# ...

# %% [markdown]
# ### Awardee

# %%
DPWH_Abaaprjun2012.Awardee.value_counts().reset_index()
# Out:
#                                               index  Awardee
# 0         P.T. DIAMOND MERCHANDISE AND CONSTRUCTION        7
# 1                       O.R. SARMIENTO CONSTRUCTION        4
# 2                        TOKWING CONSTRUCTION CORP.        2
# 3                          ENA POWER BUILDERS, INC.        2
# 4                 E.H. SISON ENGINEERS, CO. (EHSEC)        2
# 5            IKF HOME FURNISHING & OFFICE FURNITURE        2
# 6                                    ROFMAN TRADING        2
# 7                   DSB CONSTRUCTION & SUPPLY, INC.        2
# 8                 LUZON SALES COMPANY, INCORPORATED        2
# 9                                    MCSA MARKETING        2
# 10                        PERTCONSULT INTERNATIONAL        2
# 11                       FIAT CONSTRUCTION SERVICES        1
# 12                   FOXROD AUTO PARTS AND SERVICES        1
# 13        BIOSPHERE CONSTRUCTION AND SUPPLIES, INC.        1
# ...

# %% [markdown]
# ### Procurement Mode

# %%
DPWH_Abaaprjun2012.Procurement_Mode.value_counts()
# Out:
# Public Bidding                                           28
# Shopping                                                 22
# Negotiated Procurement                                    2
# Negotiated Procurement - Agency to Agency (Sec. 53.5)     1
# Name: Procurement_Mode, dtype: int64

# %% [markdown]
# #### Public Bidding

# %%
DPWH_Abaaprjun2012[DPWH_Abaaprjun2012.Procurement_Mode == 'Public Bidding']
# Out:
#                                      Organization_Name Reference_No  \
# 10746   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN    1742348-2
# 10747   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN    1742348-2
# 13936   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1787664
# 15057   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1788644
# 27694   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1796977
# 33650   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1801466
# 36945   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1803993
# 37564   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1804842
# 37566   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1804845
# 43798   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1809282
# 45260   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN    1665186-2
# 48588   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1813025
# 52817   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1816206
# ...

# %% [markdown]
# #### Shopping

# %%
DPWH_Abaaprjun2012[DPWH_Abaaprjun2012.Procurement_Mode == 'Shopping']
# Out:
#                                      Organization_Name Reference_No  \
# 33570   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1801388
# 53105   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1816504
# 53146   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1816539
# 53210   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1816608
# 53236   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1816637
# 53852   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1816941
# 68471   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1827988
# 72041   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1830808
# 79878   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1835784
# 80013   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1835891
# 80218   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1835949
# 80223   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1835954
# 80231   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1835962
# ...

# %% [markdown]
# #### Negotiated Procurement

# %%
DPWH_Abaaprjun2012[DPWH_Abaaprjun2012.Procurement_Mode == 'Negotiated Procurement']
# Out:
#                                     Organization_Name Reference_No  \
# 6623   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1782283
# 34686  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN    1703162-2
#
#                                         Bid_Notice_Title Publish_Date  \
# 6623   Consultancy Services for the Strengthening/Ret...   2012-04-04
# 34686  Consultancy Services for the Procurement of Ci...   2012-04-27
#
#             Classification                        Notice_Type  \
# 6623   Consulting Services  Notice for Negotiated Procurement
# 34686  Consulting Services  Notice for Negotiated Procurement
#
#          Business_Category                                   Funding_Source  \
# 6623   Consulting Services              Government of the Philippines (GOP)
# 34686  Consulting Services  Japan Bank for International Cooperation (JBIC)
#
#              Procurement_Mode                     Trade_Agreement  \
# ...

# %% [markdown]
# #### Negotiated Procurement - Agency to Agency (Sec. 53.5)

# %%
DPWH_Abaaprjun2012[DPWH_Abaaprjun2012.Procurement_Mode == 'Negotiated Procurement - Agency to Agency (Sec. 53.5)']
# Out:
#                                    Organization_Name Reference_No  \
# 6712  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1782379
#
#                                        Bid_Notice_Title Publish_Date  \
# 6712  Consultancy Services for the Development of Qu...   2012-04-04
#
#            Classification                        Notice_Type  \
# 6712  Consulting Services  Notice for Negotiated Procurement
#
#         Business_Category                       Funding_Source  \
# 6712  Consulting Services  Government of the Philippines (GOP)
#
#                                        Procurement_Mode  \
# 6712  Negotiated Procurement - Agency to Agency (Sec...
#
#                          Trade_Agreement  Approved_Budget  Item_No Item_Name  \
# 6712  Implementing Rules and Regulations        7500000.0      NaN       NaN
#
#      Item_Description  Item_Budget        Closing_Date Bid_Notice_Status  \
# 6712              NaN          NaN 2012-04-10 14:00:00           Awarded
#
# ...

# %% [markdown]
# ## City of Las Pinas

# %%
CLP_Abaaprjun2012 = Abaaprjun2012[Abaaprjun2012.Organization_Name == 'CITY OF LAS PINAS']

# %%
CLP_Abaaprjun2012.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 28 entries, 8083 to 14584
# Data columns (total 26 columns):
# Organization_Name         28 non-null object
# Reference_No              28 non-null object
# Bid_Notice_Title          28 non-null object
# Publish_Date              28 non-null datetime64[ns]
# Classification            28 non-null object
# Notice_Type               28 non-null object
# Business_Category         28 non-null object
# Funding_Source            28 non-null object
# Procurement_Mode          28 non-null object
# Trade_Agreement           28 non-null object
# Approved_Budget           28 non-null float64
# Item_No                   28 non-null float64
# Item_Name                 28 non-null object
# Item_Description          28 non-null object
# Item_Budget               28 non-null float64
# Closing_Date              28 non-null datetime64[ns]
# Bid_Notice_Status         28 non-null object
# Award_No                  28 non-null float64
# ...

# %% [markdown]
# ### Awardee

# %%
CLP_Abaaprjun2012.Awardee.value_counts().reset_index()
# Out:
#                              index  Awardee
# 0         E.M. ANGELES ENTERPRISES        9
# 1              EXEL CONCEPTS CORP.        7
# 2      KME DESIGN AND CONSTRUCTION        4
# 3                ARAC CONSTRUCTION        4
# 4        CYNDEL GENERAL CONTRACTOR        3
# 5  REDCAR TRADING AND CONSTRUCTION        1

# %% [markdown]
# ### Procurement Mode

# %%
CLP_Abaaprjun2012.Procurement_Mode.value_counts().reset_index()
# Out:
#             index  Procurement_Mode
# 0  Public Bidding                28

# %% [markdown]
# #### Public Bidding

# %%
CLP_Abaaprjun2012[CLP_Abaaprjun2012.Procurement_Mode == 'Public Bidding']
# Out:
#        Organization_Name Reference_No  \
# 8083   CITY OF LAS PINAS      1783750
# 8084   CITY OF LAS PINAS      1783750
# 8085   CITY OF LAS PINAS      1783750
# 8086   CITY OF LAS PINAS      1783750
# 8087   CITY OF LAS PINAS      1783750
# 8088   CITY OF LAS PINAS      1783750
# 8089   CITY OF LAS PINAS      1783750
# 8090   CITY OF LAS PINAS      1783750
# 8091   CITY OF LAS PINAS      1783750
# 8092   CITY OF LAS PINAS      1783750
# 8093   CITY OF LAS PINAS      1783750
# 8094   CITY OF LAS PINAS      1783750
# 8095   CITY OF LAS PINAS      1783750
# 8096   CITY OF LAS PINAS      1783750
# 8097   CITY OF LAS PINAS      1783750
# 8098   CITY OF LAS PINAS      1783750
# 8099   CITY OF LAS PINAS      1783750
# 8100   CITY OF LAS PINAS      1783750
# 8101   CITY OF LAS PINAS      1783750
# 8102   CITY OF LAS PINAS      1783750
# 8103   CITY OF LAS PINAS      1783750
# 8104   CITY OF LAS PINAS      1783750
# 8105   CITY OF LAS PINAS      1783750
# ...

# %% [markdown]
# # Jul-Sep 2012

# %%
bajulsep2012 = pd.read_excel("C:/Users/wolfgang/Documents/Work/DPWH/PhilGEPS Data/2012/Bid Notice and Award Details July-Sept 2012.xlsx")

# %%
bajulsep2012.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 127181 entries, 0 to 127180
# Data columns (total 26 columns):
# Organization_Name         127181 non-null object
# Reference_No              127181 non-null object
# Bid_Notice_Title          127181 non-null object
# Publish_Date              127181 non-null datetime64[ns]
# Classification            127181 non-null object
# Notice_Type               127181 non-null object
# Business_Category         127181 non-null object
# Funding_Source            127181 non-null object
# Procurement_Mode          127181 non-null object
# Trade_Agreement           127181 non-null object
# Approved_Budget           127181 non-null float64
# Item_No                   43472 non-null float64
# Item_Name                 43469 non-null object
# Item_Description          43308 non-null object
# Item_Budget               43472 non-null float64
# Closing_Date              127181 non-null datetime64[ns]
# Bid_Notice_Status         127181 non-null object
# ...

# %%
bajulsep2012.Bid_Notice_Status.value_counts().reset_index()
# Out:
#          index  Bid_Notice_Status
# 0       Closed              90915
# 1      Awarded              28249
# 2       Failed               4754
# 3    Cancelled               3215
# 4  Shortlisted                 46
# 5       Active                  2

# %%
Abajulsep2012 = bajulsep2012[bajulsep2012.Bid_Notice_Status == 'Awarded']

# %%
Abajulsep2012.Organization_Name.value_counts()
# Out:
# PROVINCE OF LEYTE                                               609
# PROVINCE OF RIZAL                                               496
# CITY OF QUEZON                                                  418
# CAMARINES NORTE STATE COLLEGE                                   396
# SIQUIJOR STATE COLLEGE                                          349
# PROVINCE OF COMPOSTELA VALLEY                                   311
# MANILA INTERNATIONAL AIRPORT AUTHORITY                          284
# NATIONAL LIBRARY OF THE PHILIPPINES                             275
# PHILIPPINE AMUSEMENT AND GAMING CORPORATION                     251
# CITY OF ZAMBOANGA, ZAMBOANGA DEL SUR                            245
# LANDBANK OF THE PHILIPPINES - HEAD OFFICE                       231
# MUNICIPALITY OF STO. TOMAS, BATANGAS                            224
# PROVINCE OF CAPIZ                                               220
# UNIVERSITY OF THE PHILIPPINES SYSTEM - DILIMAN                  214
# ...

# %% [markdown]
# ## Awarded DPWH

# %%
DPWH_Abajulsep2012 = Abajulsep2012[Abajulsep2012.Organization_Name == 'DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN']

# %% [markdown]
# ### Awardee

# %%
DPWH_Abajulsep2012.Awardee.value_counts().reset_index()
# Out:
#                                                 index  Awardee
# 0                               COMPRENET ENTERPRISES        5
# 1                           PERTCONSULT INTERNATIONAL        3
# 2                             MAXIMA MACHINERIES INC.        3
# 3                         R.D. POLICARPIO & CO., INC.        3
# 4   CHINA INTERNATIONAL WATER AND ELECTRIC CORPORA...        2
# 5           P.T. DIAMOND MERCHANDISE AND CONSTRUCTION        2
# 6              IKF HOME FURNISHING & OFFICE FURNITURE        2
# 7                                        NAIC TRADING        2
# 8                              AZITSOROG INCORPORATED        1
# 9        UNITED TECHNOLOGIES CONSOLIDATED PARTNERSHIP        1
# 10                                     V.O.M. TRADING        1
# 11           OPTIMAL INFRASTRUCTURE DEVELOPMENT, INC.        1
# 12                                 BSP & COMPANY INC.        1
# 13          BIOSPHERE CONSTRUCTION AND SUPPLIES, INC.        1
# ...

# %% [markdown]
# ### Procurement Mode

# %%
DPWH_Abajulsep2012.Procurement_Mode.value_counts().reset_index()
# Out:
#                                index  Procurement_Mode
# 0                           Shopping                21
# 1                     Public Bidding                18
# 2  International Competitive Bidding                14

# %% [markdown]
# #### Shopping

# %%
DPWH_Abajulsep2012[DPWH_Abajulsep2012.Procurement_Mode == 'Shopping']
# Out:
#                                      Organization_Name Reference_No  \
# 15745   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1882428
# 19168   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1885347
# 28187   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1892001
# 28197   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1892015
# 39702   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1901146
# 39729   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1901176
# 41862   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1902363
# 49298   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1908739
# 57637   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1915417
# 63340   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1919351
# 63361   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1919357
# 63363   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1919360
# 63366   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1919363
# ...

# %% [markdown]
# #### Public Bidding

# %%
DPWH_Abajulsep2012[DPWH_Abajulsep2012.Procurement_Mode == 'Public Bidding']
# Out:
#                                      Organization_Name Reference_No  \
# 16431   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN    1778920-2
# 26254   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1890690
# 29682   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN    1710441-2
# 32319   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN    1801897-2
# 32320   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN    1801897-2
# 32321   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN    1801897-2
# 33015   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1895851
# 36607   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN    1857285-2
# 68534   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN    1866272-2
# 68725   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1923054
# 69253   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1923900
# 75522   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1927869
# 78194   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN    1866344-2
# ...

# %% [markdown]
# #### International Competitive Bidding

# %%
DPWH_Abajulsep2012[DPWH_Abajulsep2012.Procurement_Mode == 'International Competitive Bidding']
# Out:
#                                      Organization_Name Reference_No  \
# 11210   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1878908
# 28985   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1892628
# 29133   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1892887
# 68132   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1922530
# 69385   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1924020
# 69386   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1924020
# 76348   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1928964
# 76349   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1928964
# 76350   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1928964
# 100505  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1947403
# 115990  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1960423
# 116030  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1960527
# 125338  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1967536
# ...

# %% [markdown]
# ## City of Las Pinas

# %%
CLP_Abajulsep2012 = Abajulsep2012[Abajulsep2012.Organization_Name == 'CITY OF LAS PINAS']

# %%
CLP_Abajulsep2012.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 39 entries, 83862 to 98558
# Data columns (total 26 columns):
# Organization_Name         39 non-null object
# Reference_No              39 non-null object
# Bid_Notice_Title          39 non-null object
# Publish_Date              39 non-null datetime64[ns]
# Classification            39 non-null object
# Notice_Type               39 non-null object
# Business_Category         39 non-null object
# Funding_Source            39 non-null object
# Procurement_Mode          39 non-null object
# Trade_Agreement           39 non-null object
# Approved_Budget           39 non-null float64
# Item_No                   39 non-null float64
# Item_Name                 39 non-null object
# Item_Description          39 non-null object
# Item_Budget               39 non-null float64
# Closing_Date              39 non-null datetime64[ns]
# Bid_Notice_Status         39 non-null object
# Award_No                  39 non-null float64
# ...

# %% [markdown]
# ### Awardee

# %%
CLP_Abajulsep2012.Awardee.value_counts().reset_index()
# Out:
#                              index  Awardee
# 0         E.M. ANGELES ENTERPRISES       13
# 1                ARAC CONSTRUCTION       12
# 2      KME DESIGN AND CONSTRUCTION        5
# 3              EXEL CONCEPTS CORP.        4
# 4  REDCAR TRADING AND CONSTRUCTION        4
# 5        CYNDEL GENERAL CONTRACTOR        1

# %% [markdown]
# ### Procurement Mode

# %%
CLP_Abajulsep2012.Procurement_Mode.value_counts().reset_index()
# Out:
#             index  Procurement_Mode
# 0  Public Bidding                39

# %% [markdown]
# #### Public Bidding

# %%
CLP_Abajulsep2012[CLP_Abajulsep2012.Procurement_Mode == 'Public Bidding']
# Out:
#        Organization_Name Reference_No  \
# 83862  CITY OF LAS PINAS      1934390
# 83863  CITY OF LAS PINAS      1934390
# 83864  CITY OF LAS PINAS      1934390
# 83865  CITY OF LAS PINAS      1934390
# 83866  CITY OF LAS PINAS      1934390
# 83867  CITY OF LAS PINAS      1934390
# 90364  CITY OF LAS PINAS      1939537
# 90365  CITY OF LAS PINAS      1939537
# 90366  CITY OF LAS PINAS      1939537
# 90367  CITY OF LAS PINAS      1939537
# 90368  CITY OF LAS PINAS      1939537
# 98531  CITY OF LAS PINAS      1945897
# 98532  CITY OF LAS PINAS      1945897
# 98533  CITY OF LAS PINAS      1945897
# 98534  CITY OF LAS PINAS      1945897
# 98535  CITY OF LAS PINAS      1945897
# 98536  CITY OF LAS PINAS      1945897
# 98537  CITY OF LAS PINAS      1945897
# 98538  CITY OF LAS PINAS      1945897
# 98539  CITY OF LAS PINAS      1945897
# 98540  CITY OF LAS PINAS      1945897
# 98541  CITY OF LAS PINAS      1945897
# 98542  CITY OF LAS PINAS      1945897
# ...

# %% [markdown]
# # Oct-Dec 2012

# %%
baoctdec2012 = pd.read_excel("C:/Users/wolfgang/Documents/Work/DPWH/PhilGEPS Data/2012/Bid Notice and Award Details Oct-Dec 2012.xlsx")

# %%
baoctdec2012.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145398 entries, 0 to 145397
# Data columns (total 26 columns):
# Organization_Name         145398 non-null object
# Reference_No              145398 non-null object
# Bid_Notice_Title          145398 non-null object
# Publish_Date              145398 non-null datetime64[ns]
# Classification            145398 non-null object
# Notice_Type               145398 non-null object
# Business_Category         145398 non-null object
# Funding_Source            145398 non-null object
# Procurement_Mode          145398 non-null object
# Trade_Agreement           145398 non-null object
# Approved_Budget           145398 non-null float64
# Item_No                   55038 non-null float64
# Item_Name                 55037 non-null object
# Item_Description          54956 non-null object
# Item_Budget               55038 non-null float64
# Closing_Date              145398 non-null datetime64[ns]
# Bid_Notice_Status         145398 non-null object
# ...

# %%
baoctdec2012.Bid_Notice_Status.value_counts().reset_index()
# Out:
#          index  Bid_Notice_Status
# 0       Closed             101336
# 1      Awarded              35570
# 2       Failed               4854
# 3    Cancelled               3574
# 4  Shortlisted                 48
# 5     Closed                   16

# %%
Abaoctdec2012 = baoctdec2012[baoctdec2012.Bid_Notice_Status == 'Awarded']

# %%
Abaoctdec2012.Organization_Name.value_counts()
# Out:
# NATIONAL LIBRARY OF THE PHILIPPINES                             1553
# PROVINCE OF RIZAL                                                674
# PROVINCE OF LEYTE                                                541
# PROVINCE OF LAGUNA                                               485
# CITY OF QUEZON                                                   471
# PROVINCE OF ILOCOS SUR                                           395
# MUNICIPALITY OF KAPALONG, DAVAO DEL NORTE                        350
# PROVINCE OF COMPOSTELA VALLEY                                    344
# PHILIPPINE AMUSEMENT AND GAMING CORPORATION                      329
# SAMAR STATE UNIVERSITY                                           327
# PROVINCE OF CAPIZ                                                284
# OFFICE OF THE PRESIDENT                                          267
# MUNICIPALITY OF STO. TOMAS, BATANGAS                             263
# PROVINCE OF ILOCOS NORTE                                         261
# ...

# %% [markdown]
# ## Awarded DPWH

# %%
DPWH_Abaoctdec2012 = Abaoctdec2012[Abaoctdec2012.Organization_Name == 'DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN']

# %%
DPWH_Abaoctdec2012.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 41 entries, 14477 to 144635
# Data columns (total 26 columns):
# Organization_Name         41 non-null object
# Reference_No              41 non-null object
# Bid_Notice_Title          41 non-null object
# Publish_Date              41 non-null datetime64[ns]
# Classification            41 non-null object
# Notice_Type               41 non-null object
# Business_Category         41 non-null object
# Funding_Source            41 non-null object
# Procurement_Mode          41 non-null object
# Trade_Agreement           41 non-null object
# Approved_Budget           41 non-null float64
# Item_No                   33 non-null float64
# Item_Name                 33 non-null object
# Item_Description          33 non-null object
# Item_Budget               33 non-null float64
# Closing_Date              41 non-null datetime64[ns]
# Bid_Notice_Status         41 non-null object
# Award_No                  41 non-null float64
# ...

# %% [markdown]
# ### Awardee

# %%
DPWH_Abaoctdec2012.Awardee.value_counts().reset_index()
# Out:
#                                                 index  Awardee
# 0                               COMPRENET ENTERPRISES        3
# 1                         ELIAKIM GENERAL MERCHANDISE        2
# 2                   E.H. SISON ENGINEERS, CO. (EHSEC)        2
# 3   TEKNIKOS REFRIGERATION AND AIRCONDITIONING SER...        2
# 4                                      BSPH MARKETING        1
# 5                           L.R. TIQUI BUILDERS, INC.        1
# 6                        MACRO CONSTRUCTION EQUIPMENT        1
# 7                                DEMCOR ENGINEERS CO.        1
# 8                    R.A. PAHATI CONST. & SUPPLY, INC        1
# 9                   HY-INTL UNLIMITED TRADING COMPANY        1
# 10                    EQUI-PARCO CONSTRUCTION COMPANY        1
# 11                          J.B.S. CONSTRUCTION, INC.        1
# 12                          CIVIC MERCHANDISING, INC.        1
# 13                                   FUNCTIONAL, INC.        1
# ...

# %% [markdown]
# ### Procurement Mode

# %%
DPWH_Abaoctdec2012.Procurement_Mode.value_counts()
# Out:
# Public Bidding                                          19
# Shopping                                                18
# Negotiated Procurement - Emergency Cases (Sec. 53.2)     2
# Direct Contracting (Sec. 50)                             1
# International Competitive Bidding                        1
# Name: Procurement_Mode, dtype: int64

# %% [markdown]
# #### Public Bidding

# %%
DPWH_Abaoctdec2012[DPWH_Abaoctdec2012.Procurement_Mode == 'Public Bidding']
# Out:
#                                      Organization_Name Reference_No  \
# 20330   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1983725
# 20331   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1983725
# 20343   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1983743
# 30910   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1992511
# 49542   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      2005922
# 49543   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      2005922
# 49544   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      2005922
# 49545   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      2005922
# 50287   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      2006624
# 63443   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      2015623
# 63444   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      2015623
# 63445   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      2015623
# 76979   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      2027009
# ...

# %% [markdown]
# #### Shopping

# %%
DPWH_Abaoctdec2012[DPWH_Abaoctdec2012.Procurement_Mode == 'Shopping']
# Out:
#                                      Organization_Name Reference_No  \
# 14477   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1979490
# 18974   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1982582
# 29551   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1991417
# 29574   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1991433
# 45258   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      2002786
# 69373   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      2020830
# 69424   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      2020888
# 84898   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      2032147
# 85141   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      2032423
# 86072   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      2033293
# 113687  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      2053145
# 124863  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      2061777
# 124905  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      2061819
# ...

# %% [markdown]
# #### Negotiated Procurement - Emergency Cases (Sec. 53.2)

# %%
DPWH_Abaoctdec2012[DPWH_Abaoctdec2012.Procurement_Mode == 'Negotiated Procurement - Emergency Cases (Sec. 53.2)']
# Out:
#                                      Organization_Name Reference_No  \
# 127918  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      2064401
# 140328  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      2075030
#
#                                          Bid_Notice_Title Publish_Date  \
# 127918  (12CS047 A) RFP for the Consultancy Services f...   2012-12-13
# 140328  (12CS048 A) RFP for Consultancy Services for t...   2012-12-22
#
#              Classification                 Notice_Type    Business_Category  \
# 127918  Consulting Services  Request for Proposal (RFP)  Consulting Services
# 140328  Consulting Services  Request for Proposal (RFP)  Consulting Services
#
#                              Funding_Source  \
# 127918  Government of the Philippines (GOP)
# 140328  Government of the Philippines (GOP)
#
#                                          Procurement_Mode  \
# 127918  Negotiated Procurement - Emergency Cases (Sec....
# ...

# %% [markdown]
# #### Direct Contracting (Sec. 50)

# %%
DPWH_Abaoctdec2012[DPWH_Abaoctdec2012.Procurement_Mode == 'Direct Contracting (Sec. 50)']
# Out:
#                                      Organization_Name Reference_No  \
# 116583  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      2055561
#
#                                          Bid_Notice_Title Publish_Date  \
# 116583  (12CS028) Consultancy Services for the Constru...   2012-12-06
#
#              Classification                        Notice_Type  \
# 116583  Consulting Services  Notice for Negotiated Procurement
#
#           Business_Category                                   Funding_Source  \
# 116583  Consulting Services  Japan Bank for International Cooperation (JBIC)
#
#                     Procurement_Mode                     Trade_Agreement  \
# 116583  Direct Contracting (Sec. 50)  Implementing Rules and Regulations
#
#         Approved_Budget  Item_No               Item_Name  \
# 116583      554488000.0      1.0  12CS028 Pasig Marikina
#
#                                          Item_Description  Item_Budget  \
# ...

# %% [markdown]
# #### International Competitive Bidding

# %%
DPWH_Abaoctdec2012[DPWH_Abaoctdec2012.Procurement_Mode == 'International Competitive Bidding']
# Out:
#                                      Organization_Name Reference_No  \
# 144635  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      2077656
#
#                                          Bid_Notice_Title Publish_Date  \
# 144635  12Z00074 UI 1,CP I & III, Bongabon Pantabangan...   2012-12-29
#
#        Classification                     Notice_Type      Business_Category  \
# 144635    Civil Works  Invitation to Prequalify (IPQ)  Construction Projects
#
#        Funding_Source                   Procurement_Mode Trade_Agreement  \
# 144635         Others  International Competitive Bidding          Others
#
#         Approved_Budget  Item_No                    Item_Name  \
# 144635              0.0      1.0  (12Z00074) UI I, CP I & III
#
#                                          Item_Description  Item_Budget  \
# 144635  UI 1: CP I & III, Bongabon Pantabangan & Canil...          0.0
#
#               Closing_Date Bid_Notice_Status  Award_No  \
# ...

# %% [markdown]
# ## City of Las Pinas

# %%
CLP_Abaoctdec2012 = Abaoctdec2012[Abaoctdec2012.Organization_Name == 'CITY OF LAS PINAS']

# %%
CLP_Abaoctdec2012.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18 entries, 35886 to 115905
# Data columns (total 26 columns):
# Organization_Name         18 non-null object
# Reference_No              18 non-null object
# Bid_Notice_Title          18 non-null object
# Publish_Date              18 non-null datetime64[ns]
# Classification            18 non-null object
# Notice_Type               18 non-null object
# Business_Category         18 non-null object
# Funding_Source            18 non-null object
# Procurement_Mode          18 non-null object
# Trade_Agreement           18 non-null object
# Approved_Budget           18 non-null float64
# Item_No                   17 non-null float64
# Item_Name                 17 non-null object
# Item_Description          17 non-null object
# Item_Budget               17 non-null float64
# Closing_Date              18 non-null datetime64[ns]
# Bid_Notice_Status         18 non-null object
# Award_No                  18 non-null float64
# ...

# %%
CLP_Abaoctdec2012.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18 entries, 35886 to 115905
# Data columns (total 26 columns):
# Organization_Name         18 non-null object
# Reference_No              18 non-null object
# Bid_Notice_Title          18 non-null object
# Publish_Date              18 non-null datetime64[ns]
# Classification            18 non-null object
# Notice_Type               18 non-null object
# Business_Category         18 non-null object
# Funding_Source            18 non-null object
# Procurement_Mode          18 non-null object
# Trade_Agreement           18 non-null object
# Approved_Budget           18 non-null float64
# Item_No                   17 non-null float64
# Item_Name                 17 non-null object
# Item_Description          17 non-null object
# Item_Budget               17 non-null float64
# Closing_Date              18 non-null datetime64[ns]
# Bid_Notice_Status         18 non-null object
# Award_No                  18 non-null float64
# ...

# %% [markdown]
# ### Awardee

# %%
CLP_Abaoctdec2012.Awardee.value_counts().reset_index()
# Out:
#                              index  Awardee
# 0         E.M. ANGELES ENTERPRISES        7
# 1                ARAC CONSTRUCTION        5
# 2  REDCAR TRADING AND CONSTRUCTION        5
# 3              EXEL CONCEPTS CORP.        1

# %% [markdown]
# ### Procurement Mode

# %%
CLP_Abaoctdec2012.Procurement_Mode.value_counts().reset_index()
# Out:
#             index  Procurement_Mode
# 0  Public Bidding                18

# %% [markdown]
# #### Public Bidding

# %%
CLP_Abaoctdec2012[CLP_Abaoctdec2012.Procurement_Mode == 'Public Bidding']
# Out:
#         Organization_Name Reference_No  \
# 35886   CITY OF LAS PINAS      1995705
# 35887   CITY OF LAS PINAS      1995705
# 35888   CITY OF LAS PINAS      1995705
# 35889   CITY OF LAS PINAS      1995705
# 35890   CITY OF LAS PINAS      1995705
# 35891   CITY OF LAS PINAS      1995705
# 75813   CITY OF LAS PINAS      2025595
# 75814   CITY OF LAS PINAS      2025595
# 75815   CITY OF LAS PINAS      2025595
# 75816   CITY OF LAS PINAS      2025595
# 75817   CITY OF LAS PINAS      2025595
# 75818   CITY OF LAS PINAS      2025595
# 75819   CITY OF LAS PINAS      2025595
# 75820   CITY OF LAS PINAS      2025595
# 75821   CITY OF LAS PINAS      2025595
# 75822   CITY OF LAS PINAS      2025595
# 75823   CITY OF LAS PINAS      2025595
# 115905  CITY OF LAS PINAS      2054797
#
#                                          Bid_Notice_Title Publish_Date  \
# 35886   Various Infrastructure Projects in Las Pinas City   2012-10-23
# ...
