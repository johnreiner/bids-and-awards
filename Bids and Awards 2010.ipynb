# %%
import pandas as pd
import numpy as np

# %%
pd.options.display.max_columns = None
pd.options.display.max_rows = None

# %% [markdown]
# # Jan-Mar 2010

# %%
bajanmar2010 = pd.read_excel("C:/Users/wolfgang/Documents/Work/DPWH/PhilGEPS Data/2010/Bid Notice and Award Details Jan-Mar 2010.xlsx")

# %%
bajanmar2010.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114570 entries, 0 to 114569
# Data columns (total 26 columns):
# Organization_Name         114570 non-null object
# Reference_No              114570 non-null object
# Bid_Notice_Title          114570 non-null object
# Publish_Date              114570 non-null datetime64[ns]
# Classification            114570 non-null object
# Notice_Type               114570 non-null object
# Business_Category         114570 non-null object
# Funding_Source            114570 non-null object
# Procurement_Mode          114570 non-null object
# Trade_Agreement           114570 non-null object
# Approved_Budget           114570 non-null float64
# Item_No                   34905 non-null float64
# Item_Name                 34905 non-null object
# Item_Description          34905 non-null object
# Item_Budget               34905 non-null float64
# Closing_Date              114570 non-null datetime64[ns]
# Bid_Notice_Status         114570 non-null object
# ...

# %%
bajanmar2010.Bid_Notice_Status.value_counts().reset_index()
# Out:
#          index  Bid_Notice_Status
# 0       Closed              95393
# 1      Awarded              14099
# 2    Cancelled               2670
# 3       Failed               2386
# 4  Shortlisted                 22

# %%
Abajanmar2010 = bajanmar2010[bajanmar2010.Bid_Notice_Status == 'Awarded']

# %%
Abajanmar2010.Organization_Name.value_counts()
# Out:
# PROVINCE OF LAGUNA                                              856
# PROVINCE OF RIZAL                                               561
# CITY OF URDANETA, PANGASINAN                                    515
# CITY OF DIPOLOG, ZAMBOANGA DEL NORTE                            474
# PHILIPPINE AMUSEMENT AND GAMING CORPORATION                     438
# DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS-BULACAN 1ST DEO         230
# PROVINCE OF BATANGAS                                            220
# CITY OF ORMOC, LEYTE                                            187
# CITY OF QUEZON                                                  186
# DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - ISABELA 3RD DEO       185
# CITY  OF HIMAMAYLAN, NEGROS OCCIDENTAL                          177
# MUNICIPALITY OF CABUGAO, ILOCOS SUR                             172
# UNIVERSITY OF THE PHILIPPINES SYSTEM - DILIMAN                  167
# MUNICIPALITY OF STO. TOMAS, BATANGAS                            155
# ...

# %% [markdown]
# ## Awarded DPWH

# %%
DPWH_Abajanmar2010 = Abajanmar2010[Abajanmar2010.Organization_Name == 'DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN']

# %%
DPWH_Abajanmar2010.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 2594 to 112178
# Data columns (total 26 columns):
# Organization_Name         51 non-null object
# Reference_No              51 non-null object
# Bid_Notice_Title          51 non-null object
# Publish_Date              51 non-null datetime64[ns]
# Classification            51 non-null object
# Notice_Type               51 non-null object
# Business_Category         51 non-null object
# Funding_Source            51 non-null object
# Procurement_Mode          51 non-null object
# Trade_Agreement           51 non-null object
# Approved_Budget           51 non-null float64
# Item_No                   4 non-null float64
# Item_Name                 4 non-null object
# Item_Description          4 non-null object
# Item_Budget               4 non-null float64
# Closing_Date              51 non-null datetime64[ns]
# Bid_Notice_Status         51 non-null object
# Award_No                  51 non-null float64
# ...

# %% [markdown]
# ### Awardees

# %%
DPWH_Abajanmar2010.Awardee.value_counts()
# Out:
# MCSA MARKETING                                         4
# UK OFFICE, INC.                                        4
# JQ TECH COMPUTER SERVICE                               3
# CENTRAL LOCKWOOD HARDWARE AND LUMBER INC.              3
# BIOSPHERE CONSTRUCTION AND SUPPLIES, INC.              3
# CYTEL  PHILIPPINES  ENTERPRISES                        2
# MMG GENERAL MERCHANDISE                                2
# STANLEY BRADLEY TRADING INC.                           2
# WORKSTATION DESIGNERS CENTER                           2
# GUARANTY HARDWARE & CONSTRUCTION SUPPLY                2
# PUMPCRAFT INDUSTRIAL SALES                             1
# SILICON ELECTRICAL SUPPLY, INC.                        1
# UNITED TECHNOLOGIES CONSOLIDATED PARTNERSHIP           1
# ASIAN PEST CONTROL                                     1
# ARMANGEL MEDICAL EQUIPMENT SALES AND SERVICES          1
# SMDI CONSULTANTS, INC.                                 1
# ...

# %% [markdown]
# ### Procurement Mode

# %%
DPWH_Abajanmar2010.Procurement_Mode.value_counts().reset_index()
# Out:
#                           index  Procurement_Mode
# 0                      Shopping                45
# 1                Public Bidding                 4
# 2        Negotiated Procurement                 1
# 3  Direct Contracting (Sec. 50)                 1

# %% [markdown]
# #### Shopping

# %%
DPWH_Abajanmar2010[DPWH_Abajanmar2010.Procurement_Mode == 'Shopping']
# Out:
#                                      Organization_Name Reference_No  \
# 2594    DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1095061
# 2605    DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1095073
# 2610    DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1095079
# 2619    DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1095089
# 6386    DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1097972
# 6397    DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1097985
# 6405    DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1097994
# 6415    DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1098006
# 6925    DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1098368
# 6935    DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1098378
# 6975    DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1098415
# 7055    DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1098450
# 7062    DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1098459
# ...

# %% [markdown]
# #### Public Bidding

# %%
DPWH_Abajanmar2010[DPWH_Abajanmar2010.Procurement_Mode == 'Public Bidding']
# Out:
#                                      Organization_Name Reference_No  \
# 6417    DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1098008
# 6418    DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1098008
# 6419    DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1098008
# 102246  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1178496
#
#                                          Bid_Notice_Title Publish_Date  \
# 6417    Feasibility Study of Selected MTPIP Based Road...   2010-01-12
# 6418    Feasibility Study of Selected MTPIP Based Road...   2010-01-12
# 6419    Feasibility Study of Selected MTPIP Based Road...   2010-01-12
# 102246  Repair/Renovation of Health Facilities Damaged...   2010-03-19
#
#              Classification                         Notice_Type  \
# 6417    Consulting Services  Request for Expression of Interest
# 6418    Consulting Services  Request for Expression of Interest
# 6419    Consulting Services  Request for Expression of Interest
# ...

# %% [markdown]
# #### Negotiated Procurement

# %%
DPWH_Abajanmar2010[DPWH_Abajanmar2010.Procurement_Mode == 'Negotiated Procurement']
# Out:
#                                     Organization_Name Reference_No  \
# 37320  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1123802
#
#                                         Bid_Notice_Title Publish_Date  \
# 37320  Procurement of Unleaded Gasoline and Blended D...   2010-02-06
#
#       Classification                        Notice_Type  \
# 37320          Goods  Notice for Negotiated Procurement
#
#                                        Business_Category  \
# 37320  Fuels/Fuel Additives & Lubricants & Anti Corro...
#
#                             Funding_Source        Procurement_Mode  \
# 37320  Government of the Philippines (GOP)  Negotiated Procurement
#
#                           Trade_Agreement  Approved_Budget  Item_No Item_Name  \
# 37320  Implementing Rules and Regulations       24382200.0      NaN       NaN
#
#       Item_Description  Item_Budget        Closing_Date Bid_Notice_Status  \
# 37320              NaN          NaN 2010-02-10 14:00:00           Awarded
# ...

# %% [markdown]
# ## City of Las Pinas

# %%
CLP_Abajanmar2010 = Abajanmar2010[Abajanmar2010.Organization_Name == 'CITY OF LAS PINAS']

# %%
CLP_Abajanmar2010.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23 entries, 15109 to 75416
# Data columns (total 26 columns):
# Organization_Name         23 non-null object
# Reference_No              23 non-null object
# Bid_Notice_Title          23 non-null object
# Publish_Date              23 non-null datetime64[ns]
# Classification            23 non-null object
# Notice_Type               23 non-null object
# Business_Category         23 non-null object
# Funding_Source            23 non-null object
# Procurement_Mode          23 non-null object
# Trade_Agreement           23 non-null object
# Approved_Budget           23 non-null float64
# Item_No                   21 non-null float64
# Item_Name                 21 non-null object
# Item_Description          21 non-null object
# Item_Budget               21 non-null float64
# Closing_Date              23 non-null datetime64[ns]
# Bid_Notice_Status         23 non-null object
# Award_No                  23 non-null float64
# ...

# %% [markdown]
# ### Awardee

# %%
CLP_Abajanmar2010.Awardee.value_counts().reset_index()
# Out:
#                           index  Awardee
# 0             ARAC CONSTRUCTION       10
# 1  KME DESIGNS AND CONSTRUCTION        5
# 2      E.M. ANGELES ENTERPRISES        4
# 3           EXEL CONCEPTS CORP.        4

# %% [markdown]
# ### Procurement Mode

# %%
CLP_Abajanmar2010.Procurement_Mode.value_counts()
# Out:
# Public Bidding    23
# Name: Procurement_Mode, dtype: int64

# %% [markdown]
# #### Public Bidding

# %%
CLP_Abajanmar2010[CLP_Abajanmar2010.Procurement_Mode == 'Public Bidding']
# Out:
#        Organization_Name Reference_No  \
# 15109  CITY OF LAS PINAS      1104209
# 22654  CITY OF LAS PINAS      1111030
# 22655  CITY OF LAS PINAS      1111030
# 22656  CITY OF LAS PINAS      1111030
# 22657  CITY OF LAS PINAS      1111030
# 22658  CITY OF LAS PINAS      1111030
# 22659  CITY OF LAS PINAS      1111030
# 22660  CITY OF LAS PINAS      1111030
# 22661  CITY OF LAS PINAS      1111030
# 22662  CITY OF LAS PINAS      1111030
# 22663  CITY OF LAS PINAS      1111030
# 22664  CITY OF LAS PINAS      1111030
# 22665  CITY OF LAS PINAS      1111030
# 22666  CITY OF LAS PINAS      1111030
# 22667  CITY OF LAS PINAS      1111030
# 22668  CITY OF LAS PINAS      1111030
# 22669  CITY OF LAS PINAS      1111030
# 22670  CITY OF LAS PINAS      1111030
# 22671  CITY OF LAS PINAS      1111030
# 71133  CITY OF LAS PINAS      1151448
# 71134  CITY OF LAS PINAS      1151448
# 71135  CITY OF LAS PINAS      1151448
# 75416  CITY OF LAS PINAS      1155126
#
# ...

# %% [markdown]
# # Apr-Jun 2010

# %%
baaprjun2010 = pd.read_excel("C:/Users/wolfgang/Documents/Work/DPWH/PhilGEPS Data/2010/Bid Notice and Award Details Apr-June 2010.xlsx")

# %%
baaprjun2010.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 75411 entries, 0 to 75410
# Data columns (total 26 columns):
# Organization_Name         75411 non-null object
# Reference_No              75411 non-null object
# Bid_Notice_Title          75411 non-null object
# Publish_Date              75411 non-null datetime64[ns]
# Classification            75411 non-null object
# Notice_Type               75411 non-null object
# Business_Category         75411 non-null object
# Funding_Source            75411 non-null object
# Procurement_Mode          75411 non-null object
# Trade_Agreement           75411 non-null object
# Approved_Budget           75411 non-null float64
# Item_No                   25043 non-null float64
# Item_Name                 25043 non-null object
# Item_Description          25043 non-null object
# Item_Budget               25043 non-null float64
# Closing_Date              75411 non-null datetime64[ns]
# Bid_Notice_Status         75411 non-null object
# ...

# %%
baaprjun2010.Bid_Notice_Status.value_counts().reset_index()
# Out:
#          index  Bid_Notice_Status
# 0       Closed              63771
# 1      Awarded               8383
# 2       Failed               1874
# 3    Cancelled               1366
# 4  Shortlisted                 17

# %%
Abaaprjun2010 = baaprjun2010[baaprjun2010.Bid_Notice_Status == 'Awarded']

# %% [markdown]
# ## Awarded DPWH

# %%
DPWH_Abaaprjun2010 = Abaaprjun2010[Abaaprjun2010.Organization_Name == 'DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN']

# %%
DPWH_Abaaprjun2010.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5 entries, 3331 to 16312
# Data columns (total 26 columns):
# Organization_Name         5 non-null object
# Reference_No              5 non-null object
# Bid_Notice_Title          5 non-null object
# Publish_Date              5 non-null datetime64[ns]
# Classification            5 non-null object
# Notice_Type               5 non-null object
# Business_Category         5 non-null object
# Funding_Source            5 non-null object
# Procurement_Mode          5 non-null object
# Trade_Agreement           5 non-null object
# Approved_Budget           5 non-null float64
# Item_No                   0 non-null float64
# Item_Name                 0 non-null object
# Item_Description          0 non-null object
# Item_Budget               0 non-null float64
# Closing_Date              5 non-null datetime64[ns]
# Bid_Notice_Status         5 non-null object
# Award_No                  5 non-null float64
# ...

# %% [markdown]
# ### Awardees

# %%
DPWH_Abaaprjun2010.Awardee.value_counts()
# Out:
# INTEGRATED COMPUTER SYSTEMS, INC.     1
# GEODATA SYSTEMS TECHNOLOGIES, INC.    1
# A. M. ORETA & CO., INC.               1
# CUSTOMERS FIRST TRADING               1
# FATMAN ENTERPRISES                    1
# Name: Awardee, dtype: int64

# %% [markdown]
# ### Procurement Mode

# %%
DPWH_Abaaprjun2010.Procurement_Mode.value_counts()
# Out:
# Shopping                        2
# Public Bidding                  2
# Direct Contracting (Sec. 50)    1
# Name: Procurement_Mode, dtype: int64

# %% [markdown]
# #### Shopping

# %%
DPWH_Abaaprjun2010[DPWH_Abaaprjun2010.Procurement_Mode == 'Shopping']
# Out:
#                                     Organization_Name Reference_No  \
# 6956   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1193175
# 16312  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1200752
#
#                                         Bid_Notice_Title Publish_Date  \
# 6956   3 units Printer Dot Matrix (Long Carriage) Bra...   2010-04-13
# 16312  340 PCS. GRANITE TILES 600mm X 60mm nano tech....   2010-04-23
#
#       Classification                  Notice_Type  \
# 6956           Goods  Request for Quotation (RFQ)
# 16312          Goods  Request for Quotation (RFQ)
#
#                          Business_Category  \
# 6956                      Office Equipment
# 16312  Construction Materials and Supplies
#
#                             Funding_Source Procurement_Mode  \
# 6956   Government of the Philippines (GOP)         Shopping
# 16312  Government of the Philippines (GOP)         Shopping
#
# ...

# %% [markdown]
# #### Public Bidding

# %%
DPWH_Abaaprjun2010[DPWH_Abaaprjun2010.Procurement_Mode == 'Public Bidding']
# Out:
#                                     Organization_Name Reference_No  \
# 3331   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1190085
# 15489  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1199995
#
#                                         Bid_Notice_Title Publish_Date  \
# 3331   CP V B, Pandan Libertad Antique/Aklan Boundary...   2010-04-08
# 15489  Supply, Delivery, Installation and Commissioni...   2010-04-22
#
#       Classification              Notice_Type       Business_Category  \
# 3331     Civil Works  Invitation to Bid (ITB)   Construction Projects
# 15489          Goods  Invitation to Bid (ITB)  Information Technology
#
#                             Funding_Source Procurement_Mode  \
# 3331   Government of the Philippines (GOP)   Public Bidding
# 15489  Government of the Philippines (GOP)   Public Bidding
#
#                           Trade_Agreement  Approved_Budget  Item_No Item_Name  \
# ...

# %% [markdown]
# #### Direct Contracting (Sec. 50)

# %%
DPWH_Abaaprjun2010[DPWH_Abaaprjun2010.Procurement_Mode == 'Direct Contracting (Sec. 50)']
# Out:
#                                     Organization_Name Reference_No  \
# 11466  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1196944
#
#                                         Bid_Notice_Title Publish_Date  \
# 11466  NRIMP2  Direct Contracting  Provision and Inst...   2010-04-17
#
#       Classification                    Notice_Type       Business_Category  \
# 11466          Goods  Notice for Direct Contracting  Information Technology
#
#         Funding_Source              Procurement_Mode  \
# 11466  World Bank (WB)  Direct Contracting (Sec. 50)
#
#                  Trade_Agreement  Approved_Budget  Item_No Item_Name  \
# 11466  WB Procurement Guidelines              0.0      NaN       NaN
#
#       Item_Description  Item_Budget        Closing_Date Bid_Notice_Status  \
# 11466              NaN          NaN 2010-05-13 10:00:00           Awarded
#
#        Award_No                                        Award_Title  \
# ...

# %% [markdown]
# ## City of Las Pinas

# %%
CLP_Abaaprjun2010 = Abaaprjun2010[Abaaprjun2010.Organization_Name == 'CITY OF LAS PINAS']

# %%
CLP_Abaaprjun2010.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 0 entries
# Data columns (total 26 columns):
# Organization_Name         0 non-null object
# Reference_No              0 non-null object
# Bid_Notice_Title          0 non-null object
# Publish_Date              0 non-null datetime64[ns]
# Classification            0 non-null object
# Notice_Type               0 non-null object
# Business_Category         0 non-null object
# Funding_Source            0 non-null object
# Procurement_Mode          0 non-null object
# Trade_Agreement           0 non-null object
# Approved_Budget           0 non-null float64
# Item_No                   0 non-null float64
# Item_Name                 0 non-null object
# Item_Description          0 non-null object
# Item_Budget               0 non-null float64
# Closing_Date              0 non-null datetime64[ns]
# Bid_Notice_Status         0 non-null object
# Award_No                  0 non-null float64
# Award_Title               0 non-null object
# ...

# %% [markdown]
# # Jul-Sep 2011

# %%
bajulsep2010 = pd.read_excel("C:/Users/wolfgang/Documents/Work/DPWH/PhilGEPS Data/2010/Bid Notice and Award Details July-Sept 2010.xlsx")

# %%
bajulsep2010.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 94446 entries, 0 to 94445
# Data columns (total 26 columns):
# Organization_Name         94446 non-null object
# Reference_No              94446 non-null object
# Bid_Notice_Title          94446 non-null object
# Publish_Date              94446 non-null datetime64[ns]
# Classification            94446 non-null object
# Notice_Type               94446 non-null object
# Business_Category         94446 non-null object
# Funding_Source            94446 non-null object
# Procurement_Mode          94446 non-null object
# Trade_Agreement           94446 non-null object
# Approved_Budget           94446 non-null float64
# Item_No                   27231 non-null float64
# Item_Name                 27231 non-null object
# Item_Description          27231 non-null object
# Item_Budget               27231 non-null float64
# Closing_Date              94446 non-null datetime64[ns]
# Bid_Notice_Status         94446 non-null object
# ...

# %%
bajulsep2010.Bid_Notice_Status.value_counts().reset_index()
# Out:
#          index  Bid_Notice_Status
# 0       Closed              78573
# 1      Awarded              11629
# 2    Cancelled               2173
# 3       Failed               2053
# 4  Shortlisted                 18

# %%
Abajulsep2010 = bajulsep2010[bajulsep2010.Bid_Notice_Status == 'Awarded']

# %%
Abajulsep2010.Organization_Name.value_counts()
# Out:
# PROVINCE OF LAGUNA                                              570
# CITY OF DIPOLOG, ZAMBOANGA DEL NORTE                            403
# LIGA NG MGA BARANGAY, BAUANG, LA UNION CHAPTER                  278
# CITY OF ORMOC, LEYTE                                            223
# CITY OF QUEZON                                                  196
# CITY OF LUCENA                                                  190
# CITY OF MAKATI                                                  185
# MUNICIPALITY OF STO. TOMAS, BATANGAS                            180
# BANGKO SENTRAL NG PILIPINAS                                     180
# MUNICIPALITY OF CABUGAO, ILOCOS SUR                             179
# UNIVERSITY OF THE PHILIPPINES SYSTEM - DILIMAN                  175
# MUNICIPALITY OF AGOO, LA UNION                                  156
# CITY OF ZAMBOANGA, ZAMBOANGA DEL SUR                            134
# PHILIPPINE AMUSEMENT AND GAMING CORPORATION                     133
# ...

# %% [markdown]
# ## Awarded DPWH

# %%
DPWH_Abajulsep2010 = Abajulsep2010[Abajulsep2010.Organization_Name == 'DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN']

# %% [markdown]
# ### Awardees

# %%
DPWH_Abajulsep2010.Awardee.value_counts()
# Out:
# COMMERCIAL FREIGHT SERVICES, INC.                    2
# E. GARDIOLA CONSTRUCTION                             1
# HI-TRI DEVELOPMENT CORPORATION                       1
# ROYAL CROWN MONARCH CONSTRUCTION & SUPPLIES CORP.    1
# EPLDT VENTUS, INC.                                   1
# WIDE WIDE WORLD EXPRESS CORPORATION                  1
# R.A. PAHATI GRAVEL AND SAND                          1
# HAIDEE CONSTRUCTION & DEVELOPMENT CORPORATION        1
# Name: Awardee, dtype: int64

# %% [markdown]
# ### Procurement Mode

# %%
DPWH_Abajulsep2010.Procurement_Mode.value_counts().reset_index()
# Out:
#             index  Procurement_Mode
# 0  Public Bidding                 9

# %% [markdown]
# #### Public Bidding

# %%
DPWH_Abajulsep2010[DPWH_Abajulsep2010.Procurement_Mode == 'Public Bidding']
# Out:
#                                     Organization_Name Reference_No  \
# 5492   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1252877
# 14701  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1261160
# 28966  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1272910
# 42119  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1284330
# 53773  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1293995
# 53828  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1294062
# 84521  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1319633
# 84545  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1319647
# 84549  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1319651
#
#                                         Bid_Notice_Title Publish_Date  \
# 5492   Forwarding/Hauling Services for the Door to Do...   2010-07-08
# 14701  One (1) year Courier Services for the Door to ...   2010-07-17
# 28966  forwarding/hauling services for the door to do...   2010-07-30
# ...

# %% [markdown]
# ## City of Las Pinas

# %%
CLP_Abajulsep2010 = Abajulsep2010[Abajulsep2010.Organization_Name == 'CITY OF LAS PINAS']

# %% [markdown]
# ### Awardee

# %%
CLP_Abajulsep2010.Awardee.value_counts()
# Out:
# E.M. ANGELES ENTERPRISES    2
# ARAC CONSTRUCTION           1
# Name: Awardee, dtype: int64

# %% [markdown]
# ### Procurement Mode

# %%
CLP_Abajulsep2010.Procurement_Mode.value_counts()
# Out:
# Public Bidding    3
# Name: Procurement_Mode, dtype: int64

# %%
CLP_Abajulsep2010[CLP_Abajulsep2010.Procurement_Mode == 'Public Bidding']
# Out:
#        Organization_Name Reference_No  \
# 57319  CITY OF LAS PINAS      1296779
# 57320  CITY OF LAS PINAS      1296779
# 78006  CITY OF LAS PINAS      1314022
#
#                                         Bid_Notice_Title Publish_Date  \
# 57319  Various Infrastructure Projects in Las Pinas City   2010-08-26
# 57320  Various Infrastructure Projects in Las Pinas City   2010-08-26
# 78006  Construction of Balihatar Bridge Along Gen. Lu...   2010-09-16
#
#       Classification              Notice_Type      Business_Category  \
# 57319    Civil Works  Invitation to Bid (ITB)  Construction Projects
# 57320    Civil Works  Invitation to Bid (ITB)  Construction Projects
# 78006    Civil Works  Invitation to Bid (ITB)  Construction Projects
#
#                             Funding_Source Procurement_Mode  \
# 57319  Government of the Philippines (GOP)   Public Bidding
# 57320  Government of the Philippines (GOP)   Public Bidding
# 78006  Government of the Philippines (GOP)   Public Bidding
#
# ...

# %% [markdown]
# # Oct-Dec 2011

# %%
baoctdec2010 = pd.read_excel("C:/Users/wolfgang/Documents/Work/DPWH/PhilGEPS Data/2010/Bid Notice and Award Details Oct-Dec 2010.xlsx")

# %%
baoctdec2010.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80094 entries, 0 to 80093
# Data columns (total 26 columns):
# Organization_Name         80094 non-null object
# Reference_No              80094 non-null object
# Bid_Notice_Title          80094 non-null object
# Publish_Date              80094 non-null datetime64[ns]
# Classification            80094 non-null object
# Notice_Type               80094 non-null object
# Business_Category         80094 non-null object
# Funding_Source            80094 non-null object
# Procurement_Mode          80094 non-null object
# Trade_Agreement           80094 non-null object
# Approved_Budget           80094 non-null float64
# Item_No                   25512 non-null float64
# Item_Name                 25512 non-null object
# Item_Description          25480 non-null object
# Item_Budget               25512 non-null float64
# Closing_Date              80094 non-null datetime64[ns]
# Bid_Notice_Status         80094 non-null object
# ...

# %%
baoctdec2010.Bid_Notice_Status.value_counts().reset_index()
# Out:
#          index  Bid_Notice_Status
# 0       Closed              65851
# 1      Awarded              10907
# 2       Failed               1837
# 3    Cancelled               1488
# 4  Shortlisted                 11

# %%
Abaoctdec2010 = baoctdec2010[baoctdec2010.Bid_Notice_Status == 'Awarded']

# %%
Abaoctdec2010.Organization_Name.value_counts()
# Out:
# PROVINCE OF LAGUNA                                              1587
# UNIVERSITY OF THE PHILIPPINES SYSTEM - DILIMAN                   387
# CITY OF QUEZON                                                   309
# PROVINCE OF RIZAL                                                289
# CITY OF DIPOLOG, ZAMBOANGA DEL NORTE                             282
# PHILIPPINE AMUSEMENT AND GAMING CORPORATION                      244
# CITY OF MAKATI                                                   237
# PHILIPPINE AMUSEMENT AND GAMING CORPORATION-PARAÑAQUE            217
# MUNICIPALITY OF GUINOBATAN, ALBAY                                160
# PROVINCE OF ALBAY                                                156
# MUNICIPALITY OF STO. TOMAS, BATANGAS                             153
# BANGKO SENTRAL NG PILIPINAS                                      152
# PHILIPPINE AMUSEMENT AND GAMING CORPORATION-HERITAGE             147
# DEPARTMENT OF EDUCATION - DIVISION OF CAMARINES SUR              137
# ...

# %% [markdown]
# ## Awarded DPWH

# %%
DPWH_Abaoctdec2010 = Abaoctdec2010[Abaoctdec2010.Organization_Name == 'DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN']

# %%
DPWH_Abaoctdec2010.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20 entries, 13345 to 80064
# Data columns (total 26 columns):
# Organization_Name         20 non-null object
# Reference_No              20 non-null object
# Bid_Notice_Title          20 non-null object
# Publish_Date              20 non-null datetime64[ns]
# Classification            20 non-null object
# Notice_Type               20 non-null object
# Business_Category         20 non-null object
# Funding_Source            20 non-null object
# Procurement_Mode          20 non-null object
# Trade_Agreement           20 non-null object
# Approved_Budget           20 non-null float64
# Item_No                   5 non-null float64
# Item_Name                 5 non-null object
# Item_Description          5 non-null object
# Item_Budget               5 non-null float64
# Closing_Date              20 non-null datetime64[ns]
# Bid_Notice_Status         20 non-null object
# Award_No                  20 non-null float64
# ...

# %% [markdown]
# ### Awardee

# %%
DPWH_Abaoctdec2010.Awardee.value_counts()
# Out:
# NEWBURG COMMERCIAL INC.                             3
# PERTCONSULT INTERNATIONAL                           2
# CIRIACO CORPORATION                                 2
# R. D. INTERIOR JUNIOR CONSTRUCTION                  1
# UNITED TECHNOLOGIES CONSOLIDATED PARTNERSHIP        1
# KANE CONSTRUCTION, INC.                             1
# CYCORE TECHNOLOGY SOLUTIONS CO. INC.                1
# T.J. BAGUS FURNITURE & GENERAL MERCHANDISE          1
# FRANCISCO GLASS AND ALUMINUM SUPPLY AND SERVICES    1
# CENTRAL LOCKWOOD HARDWARE AND LUMBER INC.           1
# PRUDENCE MERCHANDISING, INC.                        1
# MCSA MARKETING                                      1
# JORDAL MEDICAL SYSTEMS, INC.                        1
# L.R. TIQUI BUILDERS, INC.                           1
# NORTHERN BUILDERS                                   1
# B. VICENCIO CONSTRUCTION                            1
# Name: Awardee, dtype: int64

# %% [markdown]
# ### Procurement Mode

# %%
DPWH_Abaoctdec2010.Procurement_Mode.value_counts().reset_index()
# Out:
#             index  Procurement_Mode
# 0  Public Bidding                11
# 1        Shopping                 9

# %% [markdown]
# #### Public Bidding

# %%
DPWH_Abaoctdec2010[DPWH_Abaoctdec2010.Procurement_Mode == 'Public Bidding']
# Out:
#                                     Organization_Name Reference_No  \
# 13345  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1337615
# 15208  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1339077
# 46868  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1363221
# 46872  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1363234
# 46902  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1363269
# 46905  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1363283
# 52537  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1368354
# 72553  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1385517
# 79483  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1392402
# 79484  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1392402
# 80064  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1392872
#
#                                         Bid_Notice_Title Publish_Date  \
# 13345  Metro Manila Interchange Construction Project,...   2010-10-13
# ...

# %% [markdown]
# #### Shopping

# %%
DPWH_Abaoctdec2010[DPWH_Abaoctdec2010.Procurement_Mode == 'Shopping']
# Out:
#                                     Organization_Name Reference_No  \
# 15365  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1339211
# 15366  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1339211
# 15367  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1339211
# 18572  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1342132
# 19301  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1342393
# 19324  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1342407
# 36433  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1354219
# 36489  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1354281
# 41979  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1359337
#
#                                         Bid_Notice_Title Publish_Date  \
# 15365          Cable Cat 5E etc.. C 0113 0452 10 ET. AL.   2010-10-14
# 15366          Cable Cat 5E etc.. C 0113 0452 10 ET. AL.   2010-10-14
# 15367          Cable Cat 5E etc.. C 0113 0452 10 ET. AL.   2010-10-14
# ...

# %% [markdown]
# ## City of Las Pinas

# %%
CLP_Abaoctdec2010 = Abaoctdec2010[Abaoctdec2010.Organization_Name == 'CITY OF LAS PINAS']

# %%
CLP_Abaoctdec2010.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24 entries, 20651 to 64177
# Data columns (total 26 columns):
# Organization_Name         24 non-null object
# Reference_No              24 non-null object
# Bid_Notice_Title          24 non-null object
# Publish_Date              24 non-null datetime64[ns]
# Classification            24 non-null object
# Notice_Type               24 non-null object
# Business_Category         24 non-null object
# Funding_Source            24 non-null object
# Procurement_Mode          24 non-null object
# Trade_Agreement           24 non-null object
# Approved_Budget           24 non-null float64
# Item_No                   20 non-null float64
# Item_Name                 20 non-null object
# Item_Description          20 non-null object
# Item_Budget               20 non-null float64
# Closing_Date              24 non-null datetime64[ns]
# Bid_Notice_Status         24 non-null object
# Award_No                  24 non-null float64
# ...

# %% [markdown]
# ### Awardee

# %%
CLP_Abaoctdec2010.Awardee.value_counts()
# Out:
# E.M. ANGELES ENTERPRISES           12
# ARAC CONSTRUCTION                   5
# CYNDEL GENERAL CONTRACTOR           3
# EXEL CONCEPTS CORP.                 2
# REDCAR TRADING AND CONSTRUCTION     1
# NATHAN ENTERPRISES                  1
# Name: Awardee, dtype: int64

# %% [markdown]
# ### Procurement Procedure

# %%
CLP_Abaoctdec2010.Procurement_Mode.value_counts().reset_index()
# Out:
#             index  Procurement_Mode
# 0  Public Bidding                24

# %% [markdown]
# #### Public Bidding

# %%
CLP_Abaoctdec2010[CLP_Abaoctdec2010.Procurement_Mode == 'Public Bidding']
# Out:
#        Organization_Name Reference_No  \
# 20651  CITY OF LAS PINAS      1343235
# 21886  CITY OF LAS PINAS      1344359
# 21887  CITY OF LAS PINAS      1344359
# 21888  CITY OF LAS PINAS      1344359
# 21889  CITY OF LAS PINAS      1344359
# 21890  CITY OF LAS PINAS      1344359
# 23939  CITY OF LAS PINAS      1346290
# 23940  CITY OF LAS PINAS      1346290
# 46022  CITY OF LAS PINAS      1363058
# 46023  CITY OF LAS PINAS      1363058
# 46024  CITY OF LAS PINAS      1363058
# 46025  CITY OF LAS PINAS      1363058
# 46026  CITY OF LAS PINAS      1363058
# 46027  CITY OF LAS PINAS      1363058
# 46028  CITY OF LAS PINAS      1363058
# 46029  CITY OF LAS PINAS      1363058
# 46030  CITY OF LAS PINAS      1363058
# 46031  CITY OF LAS PINAS      1363058
# 46032  CITY OF LAS PINAS      1363058
# 46033  CITY OF LAS PINAS      1363058
# 46034  CITY OF LAS PINAS      1363058
# 59871  CITY OF LAS PINAS      1375055
# 61061  CITY OF LAS PINAS      1376614
# ...
