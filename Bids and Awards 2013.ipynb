# %%
import pandas as pd

# %%
import numpy as np

# %% [markdown]
# # Bid Notice and Award Details Jan-Mar 2013

# %%
bajanmar2013 = pd.read_csv("C:/Users/jantiquerra/Documents/Stories/DPWH/PhilGEPS Data/2013/csv/Bid Notice and Award Details Jan-Mar 2013.csv")

# %%
pd.set_option('display.max_columns', None)

# %%
bajanmar2013.head()
# Out:
#                                    Organization_Name Reference_ID  \
# 0  NATIONAL IRRIGATION ADMINISTRATION - CAMARINES...      2077513
# 1  NATIONAL IRRIGATION ADMINISTRATION - CAMARINES...      2077513
# 2             MANILA INTERNATIONAL AIRPORT AUTHORITY      2077923
# 3                         CITY OF BATANGAS, BATANGAS      2077965
# 4                         CITY OF BATANGAS, BATANGAS      2077970
#
#                                         Notice_Title Publish_Date  \
# 0  CN   2012   0059G RFQ (REPAIR/RESTORATION OF N...     1/1/2013
# 1  CN   2012   0059G RFQ (REPAIR/RESTORATION OF N...     1/1/2013
# 2   Request for Quotation RIS #12 08 055 / 12 62 015     1/1/2013
# 3                supply & delivery of Meals & Snacks     1/1/2013
# 4             supply & delivery of Various Materials     1/1/2013
#
#   Classification                  Notice_Type  \
# 0          Goods  Request for Quotation (RFQ)
# 1          Goods  Request for Quotation (RFQ)
# ...

# %%
bajanmar2013.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 161053 entries, 0 to 161052
# Data columns (total 26 columns):
# Organization_Name                  161053 non-null object
# Reference_ID                       161053 non-null object
# Notice_Title                       161053 non-null object
# Publish_Date                       161053 non-null object
# Classification                     161053 non-null object
# Notice_Type                        161053 non-null object
# Business_Category                  161053 non-null object
# Funding_Source                     161053 non-null object
# Procurement_Mode                   161053 non-null object
# Trade_Agreement                    161053 non-null object
# Approved_Budget_of_the_Contract    161053 non-null object
# Item_No                            90208 non-null float64
# Item_Name                          90208 non-null object
# Item_Description                   90059 non-null object
# ...

# %%
bajanmar2013.Award_Status.value_counts().reset_index()
# Out:
#        index  Award_Status
# 0     Posted         42881
# 1    Updated         16929
# 2  Cancelled           124

# %%
bajanmar2013.Notice_Status.value_counts().reset_index()
# Out:
#          index  Notice_Status
# 0       Closed          99552
# 1      Awarded          51211
# 2       Failed           5936
# 3    Cancelled           4326
# 4  Shortlisted             28

# %% [markdown]
# ## Awarded Projects

# %%
Abajanmar2013 = bajanmar2013[bajanmar2013.Notice_Status == 'Awarded']

# %%
Abajanmar2013.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51211 entries, 5 to 161052
# Data columns (total 26 columns):
# Organization_Name                  51211 non-null object
# Reference_ID                       51211 non-null object
# Notice_Title                       51211 non-null object
# Publish_Date                       51211 non-null object
# Classification                     51211 non-null object
# Notice_Type                        51211 non-null object
# Business_Category                  51211 non-null object
# Funding_Source                     51211 non-null object
# Procurement_Mode                   51211 non-null object
# Trade_Agreement                    51211 non-null object
# Approved_Budget_of_the_Contract    51211 non-null object
# Item_No                            48906 non-null float64
# Item_Name                          48906 non-null object
# Item_Description                   48889 non-null object
# ...

# %%
Abajanmar2013.Organization_Name.tolist()
# Out:
# ['MUNICIPALITY OF LUPI, CAMARINES SUR',
#  'DEPARTMENT OF NATIONAL DEFENSE - PROCUREMENT UNIT',
#  'DEPARTMENT OF NATIONAL DEFENSE - PROCUREMENT UNIT',
#  'MUNICIPALITY OF LUPI, CAMARINES SUR',
#  'MUNICIPALITY OF LUPI, CAMARINES SUR',
#  'CITY OF BAGUIO, BENGUET',
#  'CITY OF BAGUIO, BENGUET',
#  'CITY OF BAGUIO, BENGUET',
#  'CITY OF BAGUIO, BENGUET',
#  'BICOL REGIONAL TRAINING AND TEACHING HOSPITAL',
#  'HOME DEVELOPMENT MUTUAL FUND - CORPORATE HEADQUARTERS',
#  'CITY OF SAN CARLOS, NEGROS OCCIDENTAL',
#  'MUNICIPALITY OF STA. CRUZ, ILOCOS SUR',
#  'MUNICIPALITY OF STA. CRUZ, ILOCOS SUR',
#  'MUNICIPALITY OF STA. CRUZ, ILOCOS SUR',
#  'DEPARTMENT OF AGRICULTURE - REGION III',
#  'DEPARTMENT OF AGRICULTURE - REGION III',
#  'DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MIS. OCC. SUB-DEO',
#  'DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MIS. OCC. SUB-DEO',
#  'RAMON MAGSAYSAY TECHNOLOGICAL UNIVERSITY',
#  'BARANGAY SAN AGUSTIN, OAS, ALBAY',
# ...

# %% [markdown]
# ### Awarded to DPWH Main

# %%
DPWH_awarded_janmar2013 = Abajanmar2013[Abajanmar2013.Organization_Name == "DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN"]

# %%
DPWH_awarded_janmar2013.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 38 entries, 767 to 160068
# Data columns (total 26 columns):
# Organization_Name                  38 non-null object
# Reference_ID                       38 non-null object
# Notice_Title                       38 non-null object
# Publish_Date                       38 non-null object
# Classification                     38 non-null object
# Notice_Type                        38 non-null object
# Business_Category                  38 non-null object
# Funding_Source                     38 non-null object
# Procurement_Mode                   38 non-null object
# Trade_Agreement                    38 non-null object
# Approved_Budget_of_the_Contract    38 non-null object
# Item_No                            38 non-null float64
# Item_Name                          38 non-null object
# Item_Description                   38 non-null object
# Item_Budget                        38 non-null object
# ...

# %%
DPWH_awarded_janmar2013.Awardee_Corporate_Title.value_counts().reset_index()
# Out:
#                                                 index  Awardee_Corporate_Title
# 0                                     URBAN ENGINEERS                        3
# 1                  R. D. INTERIOR JUNIOR CONSTRUCTION                        2
# 2           P.T. DIAMOND MERCHANDISE AND CONSTRUCTION                        2
# 3                         VICENTE T. LAO CONSTRUCTION                        2
# 4           CENTRAL LOCKWOOD HARDWARE AND LUMBER INC.                        2
# 5                               COMPRENET ENTERPRISES                        2
# 6   CAVDEAL - CAVITE IDEAL INTERNATIONAL CONSTRUCT...                        2
# 7          CIVIL SERVICE COMMISSION  - CENTRAL OFFICE                        1
# 8                               NERA PHILIPPINES INC.                        1
# 9                             OTUS COPY SYSTEMS, INC.                        1
# 10                          PERTCONSULT INTERNATIONAL                        1
# ...

# %%
DPWH_awarded_janmar2013.Classification.value_counts().reset_index()
# Out:
#                  index  Classification
# 0                Goods              19
# 1          Civil Works              11
# 2  Consulting Services               8

# %%
DPWH_awarded_janmar2013.Award_Status.value_counts().reset_index()
# Out:
#      index  Award_Status
# 0   Posted            19
# 1  Updated            19

# %%
DPWH_awarded_janmar2013.Procurement_Mode.value_counts().reset_index()
# Out:
#                                                index  Procurement_Mode
# 0                                           Shopping                17
# 1                                     Public Bidding                15
# 2                  International Competitive Bidding                 4
# 3  Negotiated Procurement - Agency to Agency (Sec...                 1
# 4                       Direct Contracting (Sec. 50)                 1

# %% [markdown]
# #### Direct Contracting

# %%
DPWH_awarded_janmar2013[DPWH_awarded_janmar2013.Procurement_Mode == "Direct Contracting (Sec. 50)"]
# Out:
#                                      Organization_Name Reference_ID  \
# 102886  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      2149906
#
#                                              Notice_Title Publish_Date  \
# 102886  Construction/Improvement of Ternate Nasugbu Ro...    2/28/2013
#
#        Classification                        Notice_Type  \
# 102886    Civil Works  Notice for Negotiated Procurement
#
#             Business_Category                       Funding_Source  \
# 102886  Construction Projects  Government of the Philippines (GOP)
#
#                     Procurement_Mode                     Trade_Agreement  \
# 102886  Direct Contracting (Sec. 50)  Implementing Rules and Regulations
#
#        Approved_Budget_of_the_Contract  Item_No  \
# 102886                   55,545,506.03      1.0
#
#                                                 Item_Name  \
# 102886  13 001 Nego. Const./Impvt. of Ternate Nasugbu ...
#
# ...

# %% [markdown]
# #### Public Bidding

# %%
DPWH_awarded_janmar2013[DPWH_awarded_janmar2013.Procurement_Mode == "Public Bidding"]
# Out:
#                                      Organization_Name Reference_ID  \
# 767     DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      2078876
# 5455    DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN    1971728-2
# 5456    DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN    1972399-2
# 5459    DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN    1986429-2
# 10719   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      2086132
# 18836   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      2092119
# 33141   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      2101622
# 38794   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      2106022
# 38832   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      2106047
# 38878   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      2106098
# 58191   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      2117942
# 84959   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN    1811362-2
# 108315  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      2153690
# ...

# %% [markdown]
# # Bid Notice and Award Details Apr-Jun 2013

# %%
baaprjun2013 = pd.read_csv("C:/Users/jantiquerra/Documents/Stories/DPWH/PhilGEPS Data/2013/csv/Bid Notice and Award Details Apr-June 2013.csv")

# %%
baaprjun2013.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 136313 entries, 0 to 136312
# Data columns (total 26 columns):
# Organization_Name                  136313 non-null object
# Reference_ID                       136313 non-null object
# Notice_Title                       136284 non-null object
# Publish_Date                       136313 non-null object
# Classification                     136313 non-null object
# Notice_Type                        136313 non-null object
# Business_Category                  136313 non-null object
# Funding_Source                     136313 non-null object
# Procurement_Mode                   136313 non-null object
# Trade_Agreement                    136313 non-null object
# Approved_Budget_of_the_Contract    136313 non-null object
# Item_No                            83192 non-null float64
# Item_Name                          83191 non-null object
# Item_Description                   83114 non-null object
# ...

# %%
baaprjun2013.Award_Status.value_counts().reset_index()
# Out:
#        index  Award_Status
# 0     Posted         32808
# 1    Updated         11789
# 2  Cancelled            71

# %% [markdown]
# ## Awarded Projects

# %%
Abaaprjun2013 = baaprjun2013[baaprjun2013.Notice_Status == 'Awarded']

# %%
Abaaprjun2013.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 38047 entries, 0 to 136311
# Data columns (total 26 columns):
# Organization_Name                  38047 non-null object
# Reference_ID                       38047 non-null object
# Notice_Title                       38018 non-null object
# Publish_Date                       38047 non-null object
# Classification                     38047 non-null object
# Notice_Type                        38047 non-null object
# Business_Category                  38047 non-null object
# Funding_Source                     38047 non-null object
# Procurement_Mode                   38047 non-null object
# Trade_Agreement                    38047 non-null object
# Approved_Budget_of_the_Contract    38047 non-null object
# Item_No                            38047 non-null float64
# Item_Name                          38046 non-null object
# Item_Description                   38030 non-null object
# ...

# %%
Abaaprjun2013.head()
# Out:
#                    Organization_Name Reference_ID  \
# 0   CITY OF PUERTO PRINCESA, PALAWAN      2109433
# 8                    PHILIPPINE NAVY      2186148
# 9                    PHILIPPINE NAVY      2186179
# 12                   PHILIPPINE NAVY      2186204
# 13                   PHILIPPINE NAVY      2186221
#
#                                          Notice_Title Publish_Date  \
# 0   pr#240 03 13/03 07 13 (diving gear & accessories)     4/1/2013
# 8   Supply & Delivery of Vehicle Repair Parts & Ac...     4/1/2013
# 9   Supply & Delivery of Construction Supplies & M...     4/1/2013
# 12  Supply & Delivery of Construction Supplies & M...     4/1/2013
# 13  Supply & Delivery of Construction Supplies & M...     4/1/2013
#
#    Classification                         Notice_Type  \
# 0           Goods  Request for Expression of Interest
# 8           Goods         Request for Quotation (RFQ)
# 9           Goods         Request for Quotation (RFQ)
# ...

# %%
Abaaprjun2013.Organization_Name.tolist()
# Out:
# ['CITY OF PUERTO PRINCESA, PALAWAN',
#  'PHILIPPINE NAVY',
#  'PHILIPPINE NAVY',
#  'PHILIPPINE NAVY',
#  'PHILIPPINE NAVY',
#  'PHILIPPINE NAVY',
#  'PHILIPPINE NAVY',
#  'PHILIPPINE NAVY',
#  'PHILIPPINE NAVY',
#  'PHILIPPINE NAVY',
#  'PHILIPPINE NAVY',
#  'PHILIPPINE NAVY',
#  'PHILIPPINE NAVY',
#  'DAVAO CITY WATER DISTRICT',
#  'METROPOLITAN WATERWORKS AND SEWERAGE SYSTEM',
#  'CITY OF URDANETA, PANGASINAN',
#  'METROPOLITAN WATERWORKS AND SEWERAGE SYSTEM',
#  'CITY OF VALENZUELA',
#  'DEPARTMENT OF TRADE AND INDUSTRY - MAIN',
#  'DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - CATANDUANES ED',
#  'DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - CATANDUANES ED',
#  'DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS-CAMARINES SUR 2ND DE',
#  'PALOMPON INSTITUTE OF TECHNOLOGY',
#  'PALOMPON INSTITUTE OF TECHNOLOGY',
#  'PALOMPON INSTITUTE OF TECHNOLOGY',
#  'PALOMPON INSTITUTE OF TECHNOLOGY',
#  'PALOMPON INSTITUTE OF TECHNOLOGY',
#  'PALOMPON INSTITUTE OF TECHNOLOGY',
# ...

# %%
Abaaprjun2013.Organization_Name.tolist()
# Out:
# ['CITY OF PUERTO PRINCESA, PALAWAN',
#  'PHILIPPINE NAVY',
#  'PHILIPPINE NAVY',
#  'PHILIPPINE NAVY',
#  'PHILIPPINE NAVY',
#  'PHILIPPINE NAVY',
#  'PHILIPPINE NAVY',
#  'PHILIPPINE NAVY',
#  'PHILIPPINE NAVY',
#  'PHILIPPINE NAVY',
#  'PHILIPPINE NAVY',
#  'PHILIPPINE NAVY',
#  'PHILIPPINE NAVY',
#  'DAVAO CITY WATER DISTRICT',
#  'METROPOLITAN WATERWORKS AND SEWERAGE SYSTEM',
#  'CITY OF URDANETA, PANGASINAN',
#  'METROPOLITAN WATERWORKS AND SEWERAGE SYSTEM',
#  'CITY OF VALENZUELA',
#  'DEPARTMENT OF TRADE AND INDUSTRY - MAIN',
#  'DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - CATANDUANES ED',
#  'DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - CATANDUANES ED',
#  'DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS-CAMARINES SUR 2ND DE',
#  'PALOMPON INSTITUTE OF TECHNOLOGY',
#  'PALOMPON INSTITUTE OF TECHNOLOGY',
#  'PALOMPON INSTITUTE OF TECHNOLOGY',
#  'PALOMPON INSTITUTE OF TECHNOLOGY',
#  'PALOMPON INSTITUTE OF TECHNOLOGY',
#  'PALOMPON INSTITUTE OF TECHNOLOGY',
# ...

# %% [markdown]
# ### Awarded to DPWH Main

# %%
DPWH_awarded_aprjun2013 = Abaaprjun2013[Abaaprjun2013.Organization_Name == "DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN"]

# %%
DPWH_awarded_aprjun2013.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 52 entries, 1852 to 122531
# Data columns (total 26 columns):
# Organization_Name                  52 non-null object
# Reference_ID                       52 non-null object
# Notice_Title                       52 non-null object
# Publish_Date                       52 non-null object
# Classification                     52 non-null object
# Notice_Type                        52 non-null object
# Business_Category                  52 non-null object
# Funding_Source                     52 non-null object
# Procurement_Mode                   52 non-null object
# Trade_Agreement                    52 non-null object
# Approved_Budget_of_the_Contract    52 non-null object
# Item_No                            52 non-null float64
# Item_Name                          52 non-null object
# Item_Description                   52 non-null object
# Item_Budget                        52 non-null object
# ...

# %%
DPWH_awarded_aprjun2013.Awardee_Corporate_Title.value_counts().reset_index()
# Out:
#                                             index  Awardee_Corporate_Title
# 0       CENTRAL LOCKWOOD HARDWARE AND LUMBER INC.                        5
# 1                                  MCSA MARKETING                        4
# 2                           COMPRENET ENTERPRISES                        4
# 3                    GLOBAL MYOHO RENGE COPY INC.                        3
# 4                  FOXROD AUTO PARTS AND SERVICES                        3
# 5                     R.D. POLICARPIO & CO., INC.                        2
# 6                     ELIAKIM GENERAL MERCHANDISE                        2
# 7                       CHEMGATE INDUSTRIAL SALES                        1
# 8                    AKINTO MARKETING CORPORATION                        1
# 9       P.T. DIAMOND MERCHANDISE AND CONSTRUCTION                        1
# 10          ZURBANO PUBLISHING AND PRINTING CORP.                        1
# ...

# %%
DPWH_awarded_aprjun2013.Classification.value_counts().reset_index()
# Out:
#                  index  Classification
# 0                Goods              41
# 1          Civil Works               8
# 2  Consulting Services               3

# %%
DPWH_awarded_aprjun2013.Award_Status.value_counts().reset_index()
# Out:
#      index  Award_Status
# 0   Posted            36
# 1  Updated            16

# %% [markdown]
# ### Procurement Mode

# %%
DPWH_awarded_aprjun2013.Procurement_Mode.value_counts().reset_index()
# Out:
#                                index  Procurement_Mode
# 0                           Shopping                35
# 1                     Public Bidding                10
# 2       Direct Contracting (Sec. 50)                 4
# 3  International Competitive Bidding                 2
# 4       National Competitive Bidding                 1

# %% [markdown]
# #### Public Bidding

# %%
DPWH_awarded_aprjun2013[DPWH_awarded_aprjun2013.Procurement_Mode == 'Public Bidding']
# Out:
#                                      Organization_Name Reference_ID  \
# 8173    DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      2195707
# 36166   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      2215051
# 53424   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      2226244
# 57485   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN    2200192-2
# 80316   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      2242838
# 88633   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN    2163868-2
# 99319   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      2254786
# 99662   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      2255087
# 99711   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      2255129
# 102750  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      2256561
#
#                                              Notice_Title Publish_Date  \
# 8173    PROCUREMENT OF TELECOMMUNICATIONS SERVICE PROV...     4/5/2013
# 36166   Supply of DPWH Security Services requirement o...    4/26/2013
# ...

# %% [markdown]
# #### Direct Contracting

# %%
DPWH_awarded_aprjun2013[DPWH_awarded_aprjun2013.Procurement_Mode == 'Direct Contracting (Sec. 50)']
# Out:
#                                     Organization_Name Reference_ID  \
# 13684  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      2199549
# 13685  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      2199549
# 13686  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      2199549
# 13687  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      2199549
#
#                                             Notice_Title Publish_Date  \
# 13684  (13Z00003,4,6 7) Contract Packages 72,73,74 an...    4/11/2013
# 13685  (13Z00003,4,6 7) Contract Packages 72,73,74 an...    4/11/2013
# 13686  (13Z00003,4,6 7) Contract Packages 72,73,74 an...    4/11/2013
# 13687  (13Z00003,4,6 7) Contract Packages 72,73,74 an...    4/11/2013
#
#       Classification                        Notice_Type  \
# 13684    Civil Works  Notice for Negotiated Procurement
# 13685    Civil Works  Notice for Negotiated Procurement
# 13686    Civil Works  Notice for Negotiated Procurement
# ...

# %% [markdown]
# # Bid Notice and Award Details Jul-Sep 2013

# %%
bajulsep2013 = pd.read_csv("C:/Users/jantiquerra/Documents/Stories/DPWH/PhilGEPS Data/2013/csv/Bid Notice and Award Details July-Sept 2013.csv")

# %%
bajulsep2013.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 164690 entries, 0 to 164689
# Data columns (total 26 columns):
# Organization_Name         164690 non-null object
# Reference_No              164690 non-null object
# Bid_Notice_Title          164629 non-null object
# Publish_Date              164690 non-null object
# Classification            164690 non-null object
# Notice_Type               164690 non-null object
# Business_Category         164690 non-null object
# Funding_Source            164690 non-null object
# Procurement_Mode          164690 non-null object
# Trade_Agreement           164690 non-null object
# Approved_Budget           164690 non-null object
# Item_No                   97062 non-null float64
# Item_Name                 97062 non-null object
# Item_Description          96845 non-null object
# Item_Budget               97062 non-null object
# Closing_Date              164629 non-null object
# Bid_Notice_Status         164690 non-null object
# ...

# %% [markdown]
# ## Awarded Projects

# %%
bajulsep2013.Bid_Notice_Status.value_counts().reset_index()
# Out:
#          index  Bid_Notice_Status
# 0       Closed             108025
# 1      Awarded              44161
# 2       Failed               7116
# 3    Cancelled               5194
# 4  Shortlisted                193
# 5       Active                  1

# %%
Abajulsep2013 = bajulsep2013[bajulsep2013.Bid_Notice_Status == 'Awarded']

# %%
Abajulsep2013.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 44161 entries, 4 to 164689
# Data columns (total 26 columns):
# Organization_Name         44161 non-null object
# Reference_No              44161 non-null object
# Bid_Notice_Title          44100 non-null object
# Publish_Date              44161 non-null object
# Classification            44161 non-null object
# Notice_Type               44161 non-null object
# Business_Category         44161 non-null object
# Funding_Source            44161 non-null object
# Procurement_Mode          44161 non-null object
# Trade_Agreement           44161 non-null object
# Approved_Budget           44161 non-null object
# Item_No                   44157 non-null float64
# Item_Name                 44157 non-null object
# Item_Description          44150 non-null object
# Item_Budget               44157 non-null object
# Closing_Date              44100 non-null object
# Bid_Notice_Status         44161 non-null object
# ...

# %%
Abajulsep2013.Organization_Name.tolist()
# Out:
# ['PALAWAN STATE UNIVERSITY',
#  'SUBIC BAY METROPOLITAN AUTHORITY',
#  'DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - PANGASINAN 2ND',
#  'DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - PANGASINAN 2ND',
#  'DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - PANGASINAN 2ND',
#  'DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - PANGASINAN 2ND',
#  'DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - PANGASINAN 2ND',
#  'DEPARTMENT OF AGRICULTURE - REGION VI',
#  'DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - BULACAN 1ST DEO',
#  'DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - BULACAN 1ST DEO',
#  'DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - BULACAN 1ST DEO',
#  'DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - CATANDUANES ED',
#  'DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - ILOCOS SUR 1ST DIS',
#  'DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - ALBAY 1ST DEO',
#  'CITY OF QUEZON',
#  'CITY OF URDANETA, PANGASINAN',
#  'CITY OF QUEZON',
#  'CITY OF QUEZON',
#  'CITY OF QUEZON',
#  'CITY OF QUEZON',
#  'CITY OF QUEZON',
#  'CITY OF QUEZON',
# ...

# %% [markdown]
# ### Awarded to DPWH Main

# %%
DPWH_awarded_julsep2013 = Abajulsep2013[Abajulsep2013.Organization_Name == "DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN"]

# %%
DPWH_awarded_julsep2013.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 35 entries, 11780 to 161730
# Data columns (total 26 columns):
# Organization_Name         35 non-null object
# Reference_No              35 non-null object
# Bid_Notice_Title          35 non-null object
# Publish_Date              35 non-null object
# Classification            35 non-null object
# Notice_Type               35 non-null object
# Business_Category         35 non-null object
# Funding_Source            35 non-null object
# Procurement_Mode          35 non-null object
# Trade_Agreement           35 non-null object
# Approved_Budget           35 non-null object
# Item_No                   35 non-null float64
# Item_Name                 35 non-null object
# Item_Description          35 non-null object
# Item_Budget               35 non-null object
# Closing_Date              35 non-null object
# Bid_Notice_Status         35 non-null object
# Award_No                  35 non-null float64
# ...

# %%
DPWH_awarded_julsep2013.Awardee.value_counts().reset_index()
# Out:
#                                                index  Awardee
# 0                                U-FIRST ENTERPRISES        2
# 1          BIOSPHERE CONSTRUCTION AND SUPPLIES, INC.        2
# 2          CENTRAL LOCKWOOD HARDWARE AND LUMBER INC.        2
# 3                       NEW  A. G. STYLIST FURNITURE        2
# 4                     FOXROD AUTO PARTS AND SERVICES        2
# 5                              COMPRENET ENTERPRISES        2
# 6                                  NORTHERN BUILDERS        1
# 7                           JQ TECH COMPUTER SERVICE        1
# 8                                CHINA WUYI CO. LTD.        1
# 9          P.T. DIAMOND MERCHANDISE AND CONSTRUCTION        1
# 10                    WERR CORPORATION INTERNATIONAL        1
# 11        PHILIPPINE LONG DISTANCE TELEPHONE COMPANY        1
# 12                      GLOBAL MYOHO RENGE COPY INC.        1
# 13                           AUTOCIRCULO CORPORATION        1
# ...

# %%
DPWH_awarded_julsep2013.Classification.value_counts().reset_index()
# Out:
#                  index  Classification
# 0                Goods              24
# 1          Civil Works               8
# 2  Consulting Services               3

# %%
DPWH_awarded_julsep2013.Award_Notice_Status.value_counts().reset_index()
# Out:
#      index  Award_Notice_Status
# 0  Updated                   21
# 1   Posted                   14

# %%
DPWH_awarded_julsep2013.Procurement_Mode.value_counts()
# Out:
# Shopping                                                             21
# Public Bidding                                                       11
# Negotiated Procurement - Highly Technical Consultants (Sec. 53.7)     1
# Direct Contracting (Sec. 50)                                          1
# International Competitive Bidding                                     1
# Name: Procurement_Mode, dtype: int64

# %% [markdown]
# #### Shopping

# %%
DPWH_awarded_julsep2013[DPWH_awarded_julsep2013.Procurement_Mode == 'Shopping']
# Out:
#                                      Organization_Name Reference_No  \
# 17699   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      2291456
# 17719   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      2291482
# 17732   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      2291495
# 17760   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      2291516
# 17767   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      2291526
# 35958   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      2304247
# 41250   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      2307641
# 41417   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      2307802
# 72500   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      2329218
# 73923   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      2329832
# 83944   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      2336950
# 97094   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      2345649
# 113912  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      2356337
# ...

# %% [markdown]
# #### Public Bidding

# %%
DPWH_awarded_julsep2013[DPWH_awarded_julsep2013.Procurement_Mode == 'Public Bidding']
# Out:
#                                      Organization_Name Reference_No  \
# 21556   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      2293934
# 36331   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN    2270384-2
# 46752   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      2311176
# 47045   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      2311356
# 61825   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      2321651
# 73907   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      2329811
# 108878  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      2353924
# 108904  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      2353961
# 150535  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      2381963
# 150589  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      2382040
# 161730  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      2389529
#
#                                          Bid_Notice_Title Publish_Date  \
# 21556   (13Z00020) Road Upgrading (Gravel to Concrete)...    7/12/2013
# ...

# %% [markdown]
# #### Direct Contracting

# %%
DPWH_awarded_julsep2013[DPWH_awarded_julsep2013.Procurement_Mode == 'Direct Contracting (Sec. 50)']
# Out:
#                                     Organization_Name Reference_No  \
# 27613  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      2298255
#
#                                         Bid_Notice_Title Publish_Date  \
# 27613  12CS003 Consultancy Services for the Detailed ...    7/16/2013
#
#             Classification                        Notice_Type  \
# 27613  Consulting Services  Notice for Negotiated Procurement
#
#          Business_Category                                   Funding_Source  \
# 27613  Consulting Services  Japan Bank for International Cooperation (JBIC)
#
#                    Procurement_Mode                     Trade_Agreement  \
# 27613  Direct Contracting (Sec. 50)  Implementing Rules and Regulations
#
#       Approved_Budget  Item_No      Item_Name  \
# 27613  308,070,000.00      1.0  12CS003 CLLEX
#
#                                         Item_Description     Item_Budget  \
# 27613  12CS003 Consultancy Services for the Detailed ...  308,070,000.00
#
# ...

# %% [markdown]
# # Bid Notice and Award Details Oct-Dec 2013

# %%
baoctdec2013 = pd.read_csv("C:/Users/jantiquerra/Documents/Stories/DPWH/PhilGEPS Data/2013/csv/Bid Notice and Award Details Oct-Dec 2013.csv")

# %%
baoctdec2013.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169639 entries, 0 to 169638
# Data columns (total 26 columns):
# Organization_Name                  169639 non-null object
# Reference_ID                       169639 non-null object
# Notice_Title                       169326 non-null object
# Publish_Date                       169639 non-null object
# Classification                     169639 non-null object
# Notice_Type                        169639 non-null object
# Business_Category                  169639 non-null object
# Funding_Source                     169639 non-null object
# Procurement_Mode                   169639 non-null object
# Trade_Agreement                    169639 non-null object
# Approved_Budget_of_the_Contract    169639 non-null object
# Item_No                            102392 non-null float64
# Item_Name                          102389 non-null object
# Item_Description                   102320 non-null object
# ...

# %%
baoctdec2013.Organization_Name.tolist()
# Out:
# ['BARANGAY VILLACORTA, MABINI, PANGASINAN',
#  'MUNICIPALITY OF QUINAPONDAN, EASTERN SAMAR',
#  'TARLAC STATE UNIVERSITY',
#  'TARLAC STATE UNIVERSITY',
#  'TARLAC STATE UNIVERSITY',
#  'TARLAC STATE UNIVERSITY',
#  'TARLAC STATE UNIVERSITY',
#  'TARLAC STATE UNIVERSITY',
#  'TARLAC STATE UNIVERSITY',
#  'TARLAC STATE UNIVERSITY',
#  'TARLAC STATE UNIVERSITY',
#  'TARLAC STATE UNIVERSITY',
#  'TARLAC STATE UNIVERSITY',
#  'TARLAC STATE UNIVERSITY',
#  'TARLAC STATE UNIVERSITY',
#  'TARLAC STATE UNIVERSITY',
#  'TARLAC STATE UNIVERSITY',
#  'TARLAC STATE UNIVERSITY',
#  'TARLAC STATE UNIVERSITY',
#  'TARLAC STATE UNIVERSITY',
#  'TARLAC STATE UNIVERSITY',
#  'TARLAC STATE UNIVERSITY',
#  'TARLAC STATE UNIVERSITY',
#  'TARLAC STATE UNIVERSITY',
#  'TARLAC STATE UNIVERSITY',
#  'TARLAC STATE UNIVERSITY',
#  'TARLAC STATE UNIVERSITY',
#  'TARLAC STATE UNIVERSITY',
#  'TARLAC STATE UNIVERSITY',
#  'TARLAC STATE UNIVERSITY',
#  'TARLAC STATE UNIVERSITY',
#  'TARLAC STATE UNIVERSITY',
# ...

# %%
baoctdec2013.Notice_Status.value_counts().reset_index()
# Out:
#          index  Notice_Status
# 0       Closed         109060
# 1      Awarded          47262
# 2       Failed           8087
# 3    Cancelled           5181
# 4  Shortlisted             49

# %%
Abaoctdec2013 = baoctdec2013[baoctdec2013.Notice_Status == 'Awarded']

# %%
Abaoctdec2013.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 47262 entries, 807 to 169638
# Data columns (total 26 columns):
# Organization_Name                  47262 non-null object
# Reference_ID                       47262 non-null object
# Notice_Title                       46949 non-null object
# Publish_Date                       47262 non-null object
# Classification                     47262 non-null object
# Notice_Type                        47262 non-null object
# Business_Category                  47262 non-null object
# Funding_Source                     47262 non-null object
# Procurement_Mode                   47262 non-null object
# Trade_Agreement                    47262 non-null object
# Approved_Budget_of_the_Contract    47262 non-null object
# Item_No                            47262 non-null float64
# Item_Name                          47261 non-null object
# Item_Description                   47261 non-null object
# ...

# %%
Abaoctdec2013.Organization_Name.tolist()
# Out:
# ['MUNICIPALITY OF HINATUAN , SURIGAO DEL SUR',
#  'DEPARTMENT OF SCIENCE AND TECHNOLOGY - REGION VI',
#  'HOME DEVELOPMENT MUTUAL FUND - CORPORATE HEADQUARTERS',
#  'MUNICIPALITY OF CABUGAO, ILOCOS SUR',
#  'SURIGAO METROPOLITAN WATER DISTRICT',
#  'NATIONAL HOUSING AUTHORITY',
#  'DEVELOPMENT BANK OF THE PHILIPPINES - DAVAO CITY',
#  'PROVINCE OF BATAAN',
#  'PROVINCE OF BATAAN',
#  'PROVINCE OF BATAAN',
#  'PROVINCE OF BATAAN',
#  'PROVINCE OF BATAAN',
#  'PROVINCE OF BATAAN',
#  'PROVINCE OF BATAAN',
#  'PROVINCE OF BATAAN',
#  'PROVINCE OF BATAAN',
#  'PROVINCE OF BATAAN',
#  'PROVINCE OF BATAAN',
#  'PROVINCE OF BATAAN',
#  'PROVINCE OF BATAAN',
#  'PROVINCE OF BATAAN',
#  'PROVINCE OF BATAAN',
#  'PROVINCE OF BATAAN',
#  'PROVINCE OF BATAAN',
#  'PROVINCE OF BATAAN',
#  'PROVINCE OF BATAAN',
#  'PROVINCE OF BATAAN',
#  'PROVINCE OF BATAAN',
#  'PROVINCE OF BATAAN',
#  'PROVINCE OF BATAAN',
#  'PROVINCE OF BATAAN',
#  'DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - SDN 1ST DEO',
# ...

# %% [markdown]
# ### Awarded to DPWH Main

# %%
DPWH_awarded_octdec2013 = Abaoctdec2013[Abaoctdec2013.Organization_Name == 'DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN']

# %%
DPWH_awarded_octdec2013.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 49 entries, 3482 to 168016
# Data columns (total 26 columns):
# Organization_Name                  49 non-null object
# Reference_ID                       49 non-null object
# Notice_Title                       48 non-null object
# Publish_Date                       49 non-null object
# Classification                     49 non-null object
# Notice_Type                        49 non-null object
# Business_Category                  49 non-null object
# Funding_Source                     49 non-null object
# Procurement_Mode                   49 non-null object
# Trade_Agreement                    49 non-null object
# Approved_Budget_of_the_Contract    49 non-null object
# Item_No                            49 non-null float64
# Item_Name                          49 non-null object
# Item_Description                   49 non-null object
# Item_Budget                        49 non-null object
# ...

# %%
DPWH_awarded_octdec2013.Awardee_Corporate_Title.value_counts().reset_index()
# Out:
#                                              index  Awardee_Corporate_Title
# 0                            COMPRENET ENTERPRISES                        6
# 1        CENTRAL LOCKWOOD HARDWARE AND LUMBER INC.                        6
# 2                   MB MASTER SUPPLIES CORPORATION                        5
# 3               ALLIED QUAD CONSTRUCTION & TRADING                        4
# 4                      ELIAKIM GENERAL MERCHANDISE                        3
# 5                      LINK_NETWORK SOLUTIONS INC.                        2
# 6                      TOYO CONSTRUCTION CO., LTD.                        2
# 7          GUARANTY HARDWARE & CONSTRUCTION SUPPLY                        2
# 8          UNIVERSITY OF THE PHILIPPINES - DILIMAN                        1
# 9                           CELLTRON MARKETING CO.                        1
# 10                        GAKKEN PHILIPPINES, INC.                        1
# ...

# %%
DPWH_awarded_octdec2013.Classification.value_counts().reset_index()
# Out:
#                  index  Classification
# 0                Goods              42
# 1          Civil Works               6
# 2  Consulting Services               1

# %%
DPWH_awarded_octdec2013.Award_Status.value_counts().reset_index()
# Out:
#      index  Award_Status
# 0  Updated            39
# 1   Posted            10

# %%
DPWH_awarded_octdec2013.Procurement_Mode.value_counts()
# Out:
# Shopping                                                    36
# Public Bidding                                               7
# International Competitive Bidding                            4
# Negotiated Procurement - Two Failed Biddings (Sec. 53.1)     1
# Negotiated Procurement - Agency to Agency (Sec. 53.5)        1
# Name: Procurement_Mode, dtype: int64

# %% [markdown]
# #### Public Bidding

# %%
DPWH_awarded_octdec2013[DPWH_awarded_octdec2013.Procurement_Mode == 'Public Bidding']
# Out:
#                                      Organization_Name Reference_ID  \
# 8389    DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      2396845
# 20520   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      2405461
# 48839   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      2425455
# 87969   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      2450639
# 117153  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      2471516
# 117178  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      2471541
# 117210  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      2471579
#
#                                              Notice_Title Publish_Date  \
# 8389    Procurement of various IT EQuipment for the us...    10/4/2013
# 20520   (13Z00032) Mindanao Roads Improvement Project,...   10/10/2013
# 48839   (13Z00028) PM No. 01 2012, Widening/Reconstruc...   10/26/2013
# 87969   Procurement of Janitorial Services Contract Re...   11/15/2013
# ...

# %% [markdown]
# #### Negotiated Procurement - Two Failed Biddings (Sec. 53.1)

# %%
DPWH_awarded_octdec2013[DPWH_awarded_octdec2013.Procurement_Mode == 'Negotiated Procurement - Two Failed Biddings (Sec. 53.1)']
# Out:
#                                      Organization_Name Reference_ID  \
# 158822  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      2500895
#
#                                              Notice_Title Publish_Date  \
# 158822  Procurement of THirteen (13) units each of Amp...   12/18/2013
#
#        Classification                        Notice_Type  \
# 158822          Goods  Notice for Negotiated Procurement
#
#                          Business_Category  \
# 158822  Industrial Machinery and Equipment
#
#                              Funding_Source  \
# 158822  Government of the Philippines (GOP)
#
#                                          Procurement_Mode  \
# 158822  Negotiated Procurement - Two Failed Biddings (...
#
#                            Trade_Agreement Approved_Budget_of_the_Contract  \
# 158822  Implementing Rules and Regulations                  130,000,000.00
#
#         Item_No                               Item_Name  \
# ...

# %% [markdown]
# #### International Competitive Bidding

# %%
DPWH_awarded_octdec2013[DPWH_awarded_octdec2013.Procurement_Mode == 'International Competitive Bidding']
# Out:
#                                     Organization_Name Reference_ID  \
# 6962   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      2395834
# 7114   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      2395987
# 12018  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      2399868
# 48657  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      2425248
#
#                                             Notice_Title Publish_Date  \
# 6962   (13Z00016) Contract Package 1, Pasig River (Re...    10/3/2013
# 7114   (13Z00017) Contract Package 2, Lower Marikina ...    10/3/2013
# 12018  (13Z00029) Mindoro West Coast Road Improvement...    10/5/2013
# 48657  (13Z00031) UI 4, Catanduanes Circumferential R...   10/26/2013
#
#       Classification                     Notice_Type      Business_Category  \
# 6962     Civil Works  Invitation to Prequalify (IPQ)  Construction Projects
# 7114     Civil Works  Invitation to Prequalify (IPQ)  Construction Projects
# ...
