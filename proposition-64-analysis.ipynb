# %% [markdown]
# # Prop 64 analysis
#
# This is a sample notebook prepared as part of the Python for Data Journalists MOOC.

# %%
import pandas as pd

# %%
# %matplotlib inline

# %% [markdown]
# Reading in the list of proposition and committees from CSV

# %%
props = pd.read_csv("http://www.firstpythonnotebook.org/_static/committees.csv")

# %%
props.head(7)
# Out:
#                                         ocd_prop_id  calaccess_prop_id  \
# 0  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 1  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 2  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 3  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 4  ocd-contest/85990193-9d6f-4600-b8e7-bf1317841d82            1362198
# 5  ocd-contest/85990193-9d6f-4600-b8e7-bf1317841d82            1362198
# 6  ocd-contest/85990193-9d6f-4600-b8e7-bf1317841d82            1362198
#
#    ccdc_prop_id                                          prop_name  \
# 0            70  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 1            70  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 2            70  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 3            70  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# ...

# %%
props.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102 entries, 0 to 101
# Data columns (total 8 columns):
# ocd_prop_id               102 non-null object
# calaccess_prop_id         102 non-null int64
# ccdc_prop_id              102 non-null int64
# prop_name                 102 non-null object
# ccdc_committee_id         102 non-null int64
# calaccess_committee_id    102 non-null int64
# committee_name            102 non-null object
# committee_position        102 non-null object
# dtypes: int64(4), object(4)
# memory usage: 4.8+ KB

# %% [markdown]
# Read in the list of contributions to ballot measures

# %%
contribs = pd.read_csv("http://www.firstpythonnotebook.org/_static/contributions.csv")

# %%
contribs.head()
# Out:
#    calaccess_committee_id                              committee_name  \
# 0                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
# 1                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
# 2                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
# 3                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
# 4                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
#
#    calaccess_filing_id date_received contributor_lastname  \
# 0              2083796    2016-09-18              BERGMAN
# 1              2083796    2016-09-18                KAHLE
# 2              2083796    2016-07-15             MCDEVITT
# 3              2083796    2016-08-10      WARREN-SAMARIPA
# 4              2083796    2016-07-26      WARREN-SAMARIPA
#
#   contributor_firstname contributor_city contributor_state contributor_zip  \
# 0              GRETCHEN    SPRING VALLEY                CA           91978
# ...

# %%
contribs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13456 entries, 0 to 13455
# Data columns (total 13 columns):
# calaccess_committee_id          13456 non-null int64
# committee_name                  13456 non-null object
# calaccess_filing_id             13456 non-null int64
# date_received                   13455 non-null object
# contributor_lastname            13455 non-null object
# contributor_firstname           13387 non-null object
# contributor_city                13455 non-null object
# contributor_state               13455 non-null object
# contributor_zip                 13455 non-null object
# contributor_employer            13387 non-null object
# contributor_occupation          13387 non-null object
# contributor_is_self_employed    13455 non-null object
# amount                          13455 non-null float64
# dtypes: float64(1), int64(2), object(10)
# memory usage: 841.0+ KB

# %%
props.prop_name.value_counts().reset_index()
# Out:
#                                                 index  prop_name
# 0   PROPOSITION 057 - CRIMINAL SENTENCES. JUVENILE...         13
# 1   PROPOSITION 056 - CIGARETTE TAX TO FUND HEALTH...         12
# 2   PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...         11
# 3   PROPOSITION 066- DEATH PENALTY. PROCEDURES. IN...          9
# 4   PROPOSITION 055 - TAX EXTENSION TO FUND EDUCAT...          8
# 5   PROPOSITION 067- REFERENDUM TO OVERTURN BAN ON...          7
# 6   PROPOSITION 062- DEATH PENALTY. INITIATIVE STA...          7
# 7   PROPOSITION 059- SB 254 (CHAPTER 20, STATUTES ...          6
# 8   PROPOSITION 053 - REVENUE BONDS. STATEWIDE VOT...          4
# 9   PROPOSITION 054 - LEGISLATURE. LEGISLATION AND...          4
# 10  PROPOSITION 058 - SB 1174 (CHAPTER 753, STATUT...          4
# 11  PROPOSITION 063- FIREARMS. AMMUNITION SALES. I...          4
# 12  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...          4
# ...

# %%
props.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102 entries, 0 to 101
# Data columns (total 8 columns):
# ocd_prop_id               102 non-null object
# calaccess_prop_id         102 non-null int64
# ccdc_prop_id              102 non-null int64
# prop_name                 102 non-null object
# ccdc_committee_id         102 non-null int64
# calaccess_committee_id    102 non-null int64
# committee_name            102 non-null object
# committee_position        102 non-null object
# dtypes: int64(4), object(4)
# memory usage: 4.8+ KB

# %%
props.committee_position.value_counts().reset_index()
# Out:
#      index  committee_position
# 0  SUPPORT                  72
# 1   OPPOSE                  30

# %%
contribs.contributor_state.value_counts()
# Out:
# CA    13416
# TX       17
# DC        8
# SC        5
# NJ        4
# FL        2
# CO        1
# MA        1
# MD        1
# Name: contributor_state, dtype: int64

# %%
props.prop_name.value_counts()
# Out:
# PROPOSITION 057 - CRIMINAL SENTENCES. JUVENILE CRIMINAL PROCEEDINGS AND SENTENCING. INITIATIVE CONSTITUTIONAL AMENDMENT AND STATUTE.                           13
# PROPOSITION 056 - CIGARETTE TAX TO FUND HEALTHCARE, TOBACCO USE PREVENTION, RESEARCH, AND LAW ENFORCEMENT. INITIATIVE CONSTITUTIONAL AMENDMENT AND STATUTE.    12
# PROPOSITION 064- MARIJUANA LEGALIZATION. INITIATIVE STATUTE.                                                                                                   11
# PROPOSITION 066- DEATH PENALTY. PROCEDURES. INITIATIVE STATUTE.                                                                                                 9
# PROPOSITION 055 - TAX EXTENSION TO FUND EDUCATION AND HEALTHCARE. INITIATIVE CONSTITUTIONAL AMENDMENT.                                                          8
# PROPOSITION 067- REFERENDUM TO OVERTURN BAN ON SINGLE-USE PLASTIC BAGS.                                                                                         7
# ...

# %%
props[props.prop_name == "PROPOSITION 064- MARIJUANA LEGALIZATION. INITIATIVE STATUTE."]
# Out:
#                                          ocd_prop_id  calaccess_prop_id  \
# 74  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 75  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 76  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 77  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 78  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 79  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 80  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 81  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 82  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 83  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 84  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
#
#     ccdc_prop_id                                          prop_name  \
# ...

# %%
prop = props[props.prop_name == "PROPOSITION 064- MARIJUANA LEGALIZATION. INITIATIVE STATUTE."]

# %%
prop.head()
# Out:
#                                          ocd_prop_id  calaccess_prop_id  \
# 74  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 75  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 76  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 77  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 78  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
#
#     ccdc_prop_id                                          prop_name  \
# 74            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 75            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 76            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 77            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 78            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
#
#     ccdc_committee_id  calaccess_committee_id  \
# 74                456                 1381808
# ...

# %%
prop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11 entries, 74 to 84
# Data columns (total 8 columns):
# ocd_prop_id               11 non-null object
# calaccess_prop_id         11 non-null int64
# ccdc_prop_id              11 non-null int64
# prop_name                 11 non-null object
# ccdc_committee_id         11 non-null int64
# calaccess_committee_id    11 non-null int64
# committee_name            11 non-null object
# committee_position        11 non-null object
# dtypes: int64(4), object(4)
# memory usage: 616.0+ bytes

# %%
props.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102 entries, 0 to 101
# Data columns (total 8 columns):
# ocd_prop_id               102 non-null object
# calaccess_prop_id         102 non-null int64
# ccdc_prop_id              102 non-null int64
# prop_name                 102 non-null object
# ccdc_committee_id         102 non-null int64
# calaccess_committee_id    102 non-null int64
# committee_name            102 non-null object
# committee_position        102 non-null object
# dtypes: int64(4), object(4)
# memory usage: 4.8+ KB

# %%
contribs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13456 entries, 0 to 13455
# Data columns (total 13 columns):
# calaccess_committee_id          13456 non-null int64
# committee_name                  13456 non-null object
# calaccess_filing_id             13456 non-null int64
# date_received                   13455 non-null object
# contributor_lastname            13455 non-null object
# contributor_firstname           13387 non-null object
# contributor_city                13455 non-null object
# contributor_state               13455 non-null object
# contributor_zip                 13455 non-null object
# contributor_employer            13387 non-null object
# contributor_occupation          13387 non-null object
# contributor_is_self_employed    13455 non-null object
# amount                          13455 non-null float64
# dtypes: float64(1), int64(2), object(10)
# memory usage: 841.0+ KB

# %%
pd.merge(prop, contribs, on="calaccess_committee_id")
# Out:
#                                          ocd_prop_id  calaccess_prop_id  \
# 0   ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 1   ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 2   ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 3   ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 4   ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 5   ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 6   ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 7   ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 8   ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 9   ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 10  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 11  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# ...

# %% [markdown]
# Merged prop and contribs

# %%
merged = pd.merge(prop, contribs, on="calaccess_committee_id")

# %%
merged.head()
# Out:
#                                         ocd_prop_id  calaccess_prop_id  \
# 0  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 1  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 2  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 3  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 4  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
#
#    ccdc_prop_id                                          prop_name  \
# 0            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 1            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 2            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 3            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 4            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
#
#    ccdc_committee_id  calaccess_committee_id  \
# 0                462                 1386560
# ...

# %%
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26 entries, 0 to 25
# Data columns (total 20 columns):
# ocd_prop_id                     26 non-null object
# calaccess_prop_id               26 non-null int64
# ccdc_prop_id                    26 non-null int64
# prop_name                       26 non-null object
# ccdc_committee_id               26 non-null int64
# calaccess_committee_id          26 non-null int64
# committee_name_x                26 non-null object
# committee_position              26 non-null object
# committee_name_y                26 non-null object
# calaccess_filing_id             26 non-null int64
# date_received                   26 non-null object
# contributor_lastname            26 non-null object
# contributor_firstname           20 non-null object
# contributor_city                26 non-null object
# contributor_state               26 non-null object
# contributor_zip                 26 non-null object
# ...

# %%
merged.amount.sum()
# Out:
# 17089.0

# %%
merged.committee_position.value_counts()
# Out:
# SUPPORT    26
# Name: committee_position, dtype: int64

# %% [markdown]
# Merged support and opposition to prop 64

# %%
support = merged[merged.committee_position == "SUPPORT"]

# %%
oppose = merged[merged.committee_position == "OPPOSE"]

# %%
support.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26 entries, 0 to 25
# Data columns (total 20 columns):
# ocd_prop_id                     26 non-null object
# calaccess_prop_id               26 non-null int64
# ccdc_prop_id                    26 non-null int64
# prop_name                       26 non-null object
# ccdc_committee_id               26 non-null int64
# calaccess_committee_id          26 non-null int64
# committee_name_x                26 non-null object
# committee_position              26 non-null object
# committee_name_y                26 non-null object
# calaccess_filing_id             26 non-null int64
# date_received                   26 non-null object
# contributor_lastname            26 non-null object
# contributor_firstname           20 non-null object
# contributor_city                26 non-null object
# contributor_state               26 non-null object
# contributor_zip                 26 non-null object
# ...

# %%
oppose.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 0 entries
# Data columns (total 20 columns):
# ocd_prop_id                     0 non-null object
# calaccess_prop_id               0 non-null int64
# ccdc_prop_id                    0 non-null int64
# prop_name                       0 non-null object
# ccdc_committee_id               0 non-null int64
# calaccess_committee_id          0 non-null int64
# committee_name_x                0 non-null object
# committee_position              0 non-null object
# committee_name_y                0 non-null object
# calaccess_filing_id             0 non-null int64
# date_received                   0 non-null object
# contributor_lastname            0 non-null object
# contributor_firstname           0 non-null object
# contributor_city                0 non-null object
# contributor_state               0 non-null object
# contributor_zip                 0 non-null object
# contributor_employer            0 non-null object
# ...

# %% [markdown]
# Sum of the amount given to support prop 64

# %%
support.amount.sum()
# Out:
# 17089.0

# %% [markdown]
# Sum of the amount given to oppose prop 64

# %%
oppose.amount.sum()
# Out:
# 0

# %%
support.amount.sum() / merged.amount.sum()
# Out:
# 1.0

# %%
merged.sort_values("amount", ascending=False)
# Out:
#                                          ocd_prop_id  calaccess_prop_id  \
# 13  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 14  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 20  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 21  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 24  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 12  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 25  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 17  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 19  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 22  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 23  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 18  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# ...

# %%
oppose.sort_values("amount", ascending=False).head()
# Out:
# Empty DataFrame
# Columns: [ocd_prop_id, calaccess_prop_id, ccdc_prop_id, prop_name, ccdc_committee_id, calaccess_committee_id, committee_name_x, committee_position, committee_name_y, calaccess_filing_id, date_received, contributor_lastname, contributor_firstname, contributor_city, contributor_state, contributor_zip, contributor_employer, contributor_occupation, contributor_is_self_employed, amount]
# Index: []

# %%
merged.groupby("committee_name_x").amount.sum().reset_index().sort_values("amount", ascending=False)
# Out:
#                              committee_name_x   amount
# 0  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE  17089.0

# %%
merged.groupby(["contributor_firstname", "contributor_lastname", "committee_position"]).amount.sum().reset_index().sort_values("amount", ascending=False)
# Out:
#    contributor_firstname contributor_lastname committee_position  amount
# 11                  RICH                 RIEL            SUPPORT  1000.0
# 3                JESSICA            MCELFRESH            SUPPORT   700.0
# 2                  JAMES      SCHMACTENBERGER            SUPPORT   300.0
# 0                 EDWARD               WICKER            SUPPORT   250.0
# 7                MICHAEL              GELFAND            SUPPORT   250.0
# 4                   JOHN              VENTURO            SUPPORT   198.0
# 6                    LEO             MCDEVITT            SUPPORT   198.0
# 10                 MYRNA                KAHLE            SUPPORT   119.0
# 14                 SUSAN               HANNON            SUPPORT   100.0
# 1               GRETCHEN              BERGMAN            SUPPORT    84.0
# 8               MICHELLE               SEXTON            SUPPORT    84.0
# 9               MICHELLE                WOLFF            SUPPORT    84.0
# ...

# %%
top_supporters = support.groupby(["contributor_firstname", "contributor_lastname"]).amount.sum().reset_index().sort_values("amount", ascending=False).head(10)

# %%
top_supporters.head(10)
# Out:
#    contributor_firstname contributor_lastname  amount
# 11                  RICH                 RIEL  1000.0
# 3                JESSICA            MCELFRESH   700.0
# 2                  JAMES      SCHMACTENBERGER   300.0
# 0                 EDWARD               WICKER   250.0
# 7                MICHAEL              GELFAND   250.0
# 4                   JOHN              VENTURO   198.0
# 6                    LEO             MCDEVITT   198.0
# 10                 MYRNA                KAHLE   119.0
# 14                 SUSAN               HANNON   100.0
# 1               GRETCHEN              BERGMAN    84.0

# %%
top_supporters.amount.plot.bar()

# %%
top_supporters.amount.plot.barh()

# %%
top_supporters.head(5).amount.plot.barh()

# %%
chart = top_supporters.head(5).amount.plot.barh()

# %%
chart.set_yticklabels(top_supporters.contributor_lastname)
