# %%
import pandas as pd
import numpy as np

# %%
pd.options.display.max_columns = None
pd.options.display.max_rows = None

# %% [markdown]
# # January to March 2016

# %%
bajanmar2016 = pd.read_excel("C:/Users/wolfgang/Documents/Work/2018/PhilGEPS_2016-2017/2016/Bid Notice and Award Details Jan-Mar 2016.xlsx")

# %%
bajanmar2016.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 241743 entries, 0 to 241742
# Data columns (total 26 columns):
# Organization_Name                  241743 non-null object
# Reference_ID                       241743 non-null object
# Notice_Title                       241739 non-null object
# Publish_Date                       241743 non-null datetime64[ns]
# Classification                     241743 non-null object
# Notice_Type                        241743 non-null object
# Business_Category                  241743 non-null object
# Funding_Source                     241743 non-null object
# Procurement_Mode                   241743 non-null object
# Trade_Agreement                    241743 non-null object
# Approved_Budget_of_the_Contract    241743 non-null float64
# Item_No                            157977 non-null float64
# Item_Name                          157976 non-null object
# Item_Description                   157644 non-null object
# ...

# %%
bajanmar2016.Notice_Status.value_counts().reset_index()
# Out:
#                       index  Notice_Status
# 0                    Closed         157540
# 1                   Awarded          62525
# 2                    Failed          14736
# 3                 Cancelled           6863
# 4               Shortlisted             75
# 5  Closed - Pending Opening              4

# %%
bajanmar2016.Award_Status.value_counts().reset_index()
# Out:
#        index  Award_Status
# 0    Updated         54227
# 1     Posted         21275
# 2  Cancelled           379

# %%
Abajanmar2016 = bajanmar2016[bajanmar2016.Notice_Status == 'Awarded']

# %%
Abajanmar2016.Organization_Name.value_counts()
# Out:
# MUNICIPALITY OF KAPALONG, DAVAO DEL NORTE                       972
# MUNICIPALITY OF LEON, ILOILO                                    919
# EAST AVENUE MEDICAL CENTER                                      917
# VETERANS REGIONAL HOSPITAL                                      866
# MUNICIPALITY OF BARUGO, LEYTE                                   866
# CITY OF DIGOS, DAVAO DEL SUR                                    756
# BASILAN DISTRICT ENGINEERING OFFICE                             658
# PROVINCE OF LAGUNA                                              559
# BAGUIO GENERAL HOSPITAL AND MEDICAL CENTER                      499
# PROVINCE OF CAPIZ                                               483
# PROVINCE OF KALINGA                                             474
# CARAGA STATE UNIVERSITY                                         462
# CORAZON LOCSIN MONTELIBANO MEMORIAL REGIONAL HOSPITAL-DOH R6    461
# CITY OF BAIS, NEGROS ORIENTAL                                   375
# ...

# %% [markdown]
# ### PPA Head Office

# %%
Abajanmar2016[Abajanmar2016.Organization_Name == 'PHILIPPINE PORTS AUTHORITY - HEAD OFFICE']
# Out:
#                                Organization_Name Reference_ID  \
# 22013   PHILIPPINE PORTS AUTHORITY - HEAD OFFICE      3637751
# 55588   PHILIPPINE PORTS AUTHORITY - HEAD OFFICE      3661290
# 55668   PHILIPPINE PORTS AUTHORITY - HEAD OFFICE      3661363
# 74310   PHILIPPINE PORTS AUTHORITY - HEAD OFFICE      3672266
# 94223   PHILIPPINE PORTS AUTHORITY - HEAD OFFICE      3684788
# 157429  PHILIPPINE PORTS AUTHORITY - HEAD OFFICE      3724759
# 157434  PHILIPPINE PORTS AUTHORITY - HEAD OFFICE      3724774
# 241575  PHILIPPINE PORTS AUTHORITY - HEAD OFFICE      3781067
# 241625  PHILIPPINE PORTS AUTHORITY - HEAD OFFICE      3781131
# 241636  PHILIPPINE PORTS AUTHORITY - HEAD OFFICE      3781141
#
#                                              Notice_Title Publish_Date  \
# 22013   APPRAISAL OF PPA PORT PROPERTIES, PLANTS AND E...   2016-01-15
# 55588   Proposed Construction and Installation of Aids...   2016-01-29
# ...

# %% [markdown]
# ## Regions

# %% [markdown]
# ### PPA Region 11

# %%
Abajanmar2016[Abajanmar2016.Organization_Name == 'PHILIPPINE PORTS AUTHORITY - REGION XI']
# Out:
#                              Organization_Name Reference_ID  \
# 8376    PHILIPPINE PORTS AUTHORITY - REGION XI      3628088
# 62159   PHILIPPINE PORTS AUTHORITY - REGION XI      3665486
# 184260  PHILIPPINE PORTS AUTHORITY - REGION XI      3742099
#
#                                              Notice_Title Publish_Date  \
# 8376    RFQ re Provision of Admin. and Technical perso...   2016-01-08
# 62159   RFQ re Supply of Labor and Materials for the P...   2016-02-02
# 184260  Invitation for Submission of Quotation re Repa...   2016-03-08
#
#        Classification                  Notice_Type      Business_Category  \
# 8376            Goods  Request for Quotation (RFQ)    Janitorial Services
# 62159           Goods  Request for Quotation (RFQ)      Printing Services
# 184260    Civil Works      Invitation to Bid (ITB)  Construction Projects
#
#                              Funding_Source Procurement_Mode  \
# 8376    Government of the Philippines (GOP)         Shopping
# ...

# %% [markdown]
# ### Region 8

# %%
Abajanmar2016[Abajanmar2016.Organization_Name == 'PHILIPPINE PORTS AUTHORITY - REGION VIII']
# Out:
#                               Organization_Name Reference_ID  \
# 50644  PHILIPPINE PORTS AUTHORITY - REGION VIII      3657968
# 73283  PHILIPPINE PORTS AUTHORITY - REGION VIII      3671369
# 73531  PHILIPPINE PORTS AUTHORITY - REGION VIII      3671513
#
#                                             Notice_Title Publish_Date  \
# 50644              Procurement of Supplies and Materials   2016-01-28
# 73283  Procurement of Janitorial Services Personnel C...   2016-02-04
# 73531  Procurement of Temp. Adm. and Tech. Support Pe...   2016-02-04
#
#                          Classification                  Notice_Type  \
# 50644                             Goods  Request for Quotation (RFQ)
# 73283  Goods - General Support Services      Invitation to Bid (ITB)
# 73531  Goods - General Support Services      Invitation to Bid (ITB)
#
#                  Business_Category                       Funding_Source  \
# 50644  Office Supplies and Devices  Government of the Philippines (GOP)
# ...

# %% [markdown]
# ### Region 6

# %%
Abajanmar2016[Abajanmar2016.Organization_Name == 'PHILIPPINE PORTS AUTHORITY - REGION VI']
# Out:
#                              Organization_Name Reference_ID  \
# 74353   PHILIPPINE PORTS AUTHORITY - REGION VI      3672312
# 112360  PHILIPPINE PORTS AUTHORITY - REGION VI      3695699
#
#                                              Notice_Title Publish_Date  \
# 74353   “SUPPLY AND DELIVERY OF FRESHWATER FOR PMO-PAN...   2016-02-04
# 112360  “PROCUREMENT OF OUTSOURCED TEMPORARY SUPPORT P...   2016-02-16
#
#        Classification              Notice_Type Business_Category  \
# 74353           Goods  Invitation to Bid (ITB)          Services
# 112360          Goods  Invitation to Bid (ITB)          Services
#
#                              Funding_Source Procurement_Mode  \
# 74353   Government of the Philippines (GOP)   Public Bidding
# 112360  Government of the Philippines (GOP)   Public Bidding
#
#                            Trade_Agreement  Approved_Budget_of_the_Contract  \
# 74353   Implementing Rules and Regulations                       1500000.00
# ...

# %% [markdown]
# ### Region 1

# %%
Abajanmar2016[Abajanmar2016.Organization_Name == 'PHILIPPINE PORTS AUTHORITY - REGION I']
# Out:
#                            Organization_Name Reference_ID       Notice_Title  \
# 90192  PHILIPPINE PORTS AUTHORITY - REGION I      3681774  INVITATION TO BID
#
#       Publish_Date Classification              Notice_Type Business_Category  \
# 90192   2016-02-10          Goods  Invitation to Bid (ITB)          Services
#
#                             Funding_Source Procurement_Mode  \
# 90192  Government of the Philippines (GOP)   Public Bidding
#
#                           Trade_Agreement  Approved_Budget_of_the_Contract  \
# 90192  Implementing Rules and Regulations                        4205314.8
#
#        Item_No          Item_Name  \
# 90192      1.0  Manpower Services
#
#                                         Item_Description  Item_Budget  \
# 90192  Provision of Professional, Technical and Admin...    4205314.8
#
#              Closing_Date Notice_Status   Award_No        Award_Title  \
# 90192 2016-02-17 01:00:00       Awarded  1136691.0  Manpower Services
#
# ...

# %% [markdown]
# ## PMOs

# %%
Abajanmar2016[Abajanmar2016.Organization_Name == 'PHILIPPINE PORTS AUTHORITY, PMO - NEGROS ORIENTAL/SIQUIJOR']
# Out:
#                                         Organization_Name Reference_ID  \
# 25799   PHILIPPINE PORTS AUTHORITY, PMO - NEGROS ORIEN...      3639563
# 25885   PHILIPPINE PORTS AUTHORITY, PMO - NEGROS ORIEN...      3639751
# 103059  PHILIPPINE PORTS AUTHORITY, PMO - NEGROS ORIEN...      3689434
# 104197  PHILIPPINE PORTS AUTHORITY, PMO - NEGROS ORIEN...      3680875
# 104207  PHILIPPINE PORTS AUTHORITY, PMO - NEGROS ORIEN...      3681256
# 178719  PHILIPPINE PORTS AUTHORITY, PMO - NEGROS ORIEN...      3739407
# 220754  PHILIPPINE PORTS AUTHORITY, PMO - NEGROS ORIEN...      3767416
#
#                                              Notice_Title Publish_Date  \
# 25799   Provision of Roll-On/Roll-Off (RORO) Services ...   2016-01-18
# 25885   Selection of Passenger Terminal Building (PTB)...   2016-01-18
# 103059  Fabrication and Installation of Various Signag...   2016-02-14
# 104197  Invitation to Bid Procurement of Janitorial Se...   2016-02-15
# ...

# %%
Abajanmar2016[Abajanmar2016.Organization_Name == 'PHILIPPINE PORTS AUTHORITY - PMO BATANGAS']
# Out:
#                                 Organization_Name Reference_ID  \
# 18905   PHILIPPINE PORTS AUTHORITY - PMO BATANGAS      3635552
# 159678  PHILIPPINE PORTS AUTHORITY - PMO BATANGAS      3725840
# 160838  PHILIPPINE PORTS AUTHORITY - PMO BATANGAS      3726746
# 169641  PHILIPPINE PORTS AUTHORITY - PMO BATANGAS      3733246
# 237919  PHILIPPINE PORTS AUTHORITY - PMO BATANGAS      3778242
#
#                                              Notice_Title Publish_Date  \
# 18905   SUPPLY AND DELIVERY OF DIESEL FUEL REQUIREMENT...   2016-01-14
# 159678  SUPPLY AND DELIVERY OF VARIOUS COMMON-USE SUPP...   2016-03-01
# 160838  SUPPLY AND DELIVERY OF DIESEL FUEL REQUIREMENT...   2016-03-01
# 169641  SUPPLY AND DELIVERY OF VARIOUS FIRE DETECTION ...   2016-03-03
# 237919  GARBAGE COLLECTION AND UPKEEPING OF GREEN AREA...   2016-03-30
#
#                           Classification                  Notice_Type  \
# 18905                              Goods  Request for Quotation (RFQ)
# ...

# %%
Abajanmar2016[Abajanmar2016.Organization_Name == 'PHILIPPINE PORTS AUTHORITY-PMO MARINDUQUE/QUEZON']
# Out:
#                                       Organization_Name Reference_ID  \
# 19843  PHILIPPINE PORTS AUTHORITY-PMO MARINDUQUE/QUEZON      3633269
#
#                                             Notice_Title Publish_Date  \
# 19843  Port of Sta. Cruz, Marinduque - Repair of R.C....   2016-01-15
#
#       Classification              Notice_Type      Business_Category  \
# 19843    Civil Works  Invitation to Bid (ITB)  Construction Projects
#
#                             Funding_Source Procurement_Mode  \
# 19843  Government of the Philippines (GOP)   Public Bidding
#
#                           Trade_Agreement  Approved_Budget_of_the_Contract  \
# 19843  Implementing Rules and Regulations                      18328626.78
#
#        Item_No                        Item_Name  \
# 19843      1.0  Repair of RC Pier and RoRo Ramp
#
#                                         Item_Description  Item_Budget  \
# 19843  Demolition/disposal of damaged RC deck, curtai...  18328626.78
#
# ...

# %%
Abajanmar2016[Abajanmar2016.Organization_Name == 'PHILIPPINE PORTS AUTHORITY - PMO CALAPAN']
# Out:
#                                Organization_Name Reference_ID  \
# 177077  PHILIPPINE PORTS AUTHORITY - PMO CALAPAN      3738039
# 239444  PHILIPPINE PORTS AUTHORITY - PMO CALAPAN      3779531
#
#                                              Notice_Title Publish_Date  \
# 177077  Procurement of Technical and Administrative Su...   2016-03-04
# 239444    Procurement of  Janitorial Services for CY 2016   2016-03-30
#
#                           Classification              Notice_Type  \
# 177077                             Goods  Invitation to Bid (ITB)
# 239444  Goods - General Support Services  Invitation to Bid (ITB)
#
#           Business_Category                       Funding_Source  \
# 177077  Janitorial Services  Government of the Philippines (GOP)
# 239444  Janitorial Services  Government of the Philippines (GOP)
#
#        Procurement_Mode                     Trade_Agreement  \
# 177077   Public Bidding  Implementing Rules and Regulations
# ...

# %%
Abajanmar2016[Abajanmar2016.Organization_Name == 'PHILIPPINE PORTS AUTHORITY - PMO LEGAZPI']
# Out:
#                                Organization_Name Reference_ID  \
# 9654    PHILIPPINE PORTS AUTHORITY - PMO LEGAZPI      3629090
# 166262  PHILIPPINE PORTS AUTHORITY - PMO LEGAZPI      3730687
# 166387  PHILIPPINE PORTS AUTHORITY - PMO LEGAZPI      3730831
# 166545  PHILIPPINE PORTS AUTHORITY - PMO LEGAZPI      3730996
# 166728  PHILIPPINE PORTS AUTHORITY - PMO LEGAZPI      3731131
# 166821  PHILIPPINE PORTS AUTHORITY - PMO LEGAZPI      3731229
# 177542  PHILIPPINE PORTS AUTHORITY - PMO LEGAZPI      3739717
#
#                                              Notice_Title  \
# 9654    CONSTRUCTION OF R.C. PIER AND RORO RAMP, PORT ...
# 166262  CONSTRUCTION OF CAUSEWAY WITH STAIRLANDING, PO...
# 166387  EXTENSION OF ROCK CAUSEWAY, PORT OF CODON, SAN...
# 166545  RAPU-RAPU PORT DEVELOPMENT PROJECT, PORT OF RA...
# 166728  BATAN PORT DEVELOPMENT PROJECT, BATAN ISLAND, ...
# 166821  CONSTRUCTION OF CAUSEWAY WITH STAIRLANDING, PO...
# 177542  MAINTENANCE OF PORT POLICE BUILDING AND PTB, B...
# ...

# %%
Abajanmar2016[Abajanmar2016.Organization_Name == 'PHILIPPINE PORTS AUTHORITY -PMO SURIGAO']
# Out:
#                               Organization_Name Reference_ID  \
# 20489   PHILIPPINE PORTS AUTHORITY -PMO SURIGAO      3636511
# 200811  PHILIPPINE PORTS AUTHORITY -PMO SURIGAO      3754571
# 239962  PHILIPPINE PORTS AUTHORITY -PMO SURIGAO      3779708
# 239994  PHILIPPINE PORTS AUTHORITY -PMO SURIGAO      3779732
#
#                                              Notice_Title Publish_Date  \
# 20489   IMPROVEMENT/PHASING OF 300KVA GENERATOR SET & ...   2016-01-15
# 200811  REPAIR OF DAMAGED CONCRETE PAVEMENT, SLOPE PRO...   2016-03-12
# 239962  CONSOLACION PORT IMPROVEMENT PROJECT, BRGY. CO...   2016-03-31
# 239994  CAMBAS-AC PORT IMPROVEMENT PROJECT, BRGY. CAMB...   2016-03-31
#
#        Classification                  Notice_Type  \
# 20489           Goods  Request for Quotation (RFQ)
# 200811    Civil Works      Invitation to Bid (ITB)
# 239962    Civil Works      Invitation to Bid (ITB)
# 239994    Civil Works      Invitation to Bid (ITB)
#
# ...

# %%
Abajanmar2016[Abajanmar2016.Organization_Name == 'PHILIPPINE PORTS AUTHORITY, PMO MISAMIS OCCIDENTAL/OZAMIZ']
# Out:
#                                         Organization_Name Reference_ID  \
# 71645   PHILIPPINE PORTS AUTHORITY, PMO MISAMIS OCCIDE...      3670306
# 234822  PHILIPPINE PORTS AUTHORITY, PMO MISAMIS OCCIDE...      3776175
# 237179  PHILIPPINE PORTS AUTHORITY, PMO MISAMIS OCCIDE...      3776215
#
#                                              Notice_Title Publish_Date  \
# 71645   UPKEEPING/CLEANLINESS/MAINTENANCE OF PORT FACI...   2016-02-04
# 234822                   PROVISION OF JANITORIAL SERVICES   2016-03-29
# 237179           PROVISION OF TEMPORARY SUPPORT PERSONNEL   2016-03-30
#
#                           Classification              Notice_Type  \
# 71645                        Civil Works  Invitation to Bid (ITB)
# 234822  Goods - General Support Services  Invitation to Bid (ITB)
# 237179  Goods - General Support Services  Invitation to Bid (ITB)
#
#                               Business_Category  \
# 71645   General Repair and Maintenance Services
# ...

# %%
Abajanmar2016[Abajanmar2016.Organization_Name == 'PHILIPPINE PORTS AUTHORITY - PMO DAPITAN']
# Out:
#                                Organization_Name Reference_ID  \
# 25386   PHILIPPINE PORTS AUTHORITY - PMO DAPITAN      3637206
# 203165  PHILIPPINE PORTS AUTHORITY - PMO DAPITAN      3756938
# 203166  PHILIPPINE PORTS AUTHORITY - PMO DAPITAN      3756942
#
#                                              Notice_Title Publish_Date  \
# 25386                    PROVISION OF JANITORIAL SERVICES   2016-01-18
# 203165  Repair of Roofing,Ceiling&Repainting of Old PT...   2016-03-13
# 203166  Repair of Electrical Room, Roofing of TMO Buil...   2016-03-13
#
#        Classification                  Notice_Type  \
# 25386           Goods      Invitation to Bid (ITB)
# 203165    Civil Works  Request for Quotation (RFQ)
# 203166    Civil Works  Request for Quotation (RFQ)
#
#                               Business_Category  \
# 25386                                  Services
# 203165  General Repair and Maintenance Services
# 203166  General Repair and Maintenance Services
#
# ...

# %%
Abajanmar2016[Abajanmar2016.Organization_Name == 'PHILIPPINE PORTS AUTHORITY - PMO GENERAL SANTOS']
# Out:
#                                       Organization_Name Reference_ID  \
# 91388   PHILIPPINE PORTS AUTHORITY - PMO GENERAL SANTOS      3681323
# 234365  PHILIPPINE PORTS AUTHORITY - PMO GENERAL SANTOS      3774175
#
#                 Notice_Title Publish_Date       Classification  \
# 91388   Re-Invitation to Bid   2016-02-11                Goods
# 234365     Invitation to Bid   2016-03-29  Consulting Services
#
#                     Notice_Type      Business_Category  \
# 91388   Invitation to Bid (ITB)               Services
# 234365  Invitation to Bid (ITB)  Construction Projects
#
#                              Funding_Source Procurement_Mode  \
# 91388   Government of the Philippines (GOP)   Public Bidding
# 234365  Government of the Philippines (GOP)   Public Bidding
#
#                            Trade_Agreement  Approved_Budget_of_the_Contract  \
# 91388   Implementing Rules and Regulations                        8508957.6
# ...

# %%
Abajanmar2016[Abajanmar2016.Organization_Name == 'PHILIPPINE PORTS AUTHORITY - PMO  NASIPIT']
# Out:
#                                 Organization_Name Reference_ID  \
# 28437   PHILIPPINE PORTS AUTHORITY - PMO  NASIPIT      3641783
# 142478  PHILIPPINE PORTS AUTHORITY - PMO  NASIPIT      3714902
#
#                                              Notice_Title Publish_Date  \
# 28437   Provision of Temporary Support Personnel for V...   2016-01-19
# 142478  Provision of Janitorial Services Including Jan...   2016-02-24
#
#                           Classification              Notice_Type  \
# 28437   Goods - General Support Services  Invitation to Bid (ITB)
# 142478  Goods - General Support Services  Invitation to Bid (ITB)
#
#           Business_Category                       Funding_Source  \
# 28437              Services  Government of the Philippines (GOP)
# 142478  Janitorial Services  Government of the Philippines (GOP)
#
#        Procurement_Mode                     Trade_Agreement  \
# 28437    Public Bidding  Implementing Rules and Regulations
# ...

# %%
Abajanmar2016[Abajanmar2016.Organization_Name == 'PHILIPPINE PORTS AUTHORITY - PMO ILIGAN']
# Out:
#                              Organization_Name Reference_ID  \
# 73953  PHILIPPINE PORTS AUTHORITY - PMO ILIGAN      3671945
# 74418  PHILIPPINE PORTS AUTHORITY - PMO ILIGAN      3672379
#
#                                             Notice_Title Publish_Date  \
# 73953       Provision of Janitorial Services for CY 2016   2016-02-04
# 74418  Provision of Temporary Support Personnel for C...   2016-02-04
#
#       Classification              Notice_Type    Business_Category  \
# 73953          Goods  Invitation to Bid (ITB)  Janitorial Services
# 74418          Goods  Invitation to Bid (ITB)  Janitorial Services
#
#                             Funding_Source Procurement_Mode  \
# 73953  Government of the Philippines (GOP)   Public Bidding
# 74418  Government of the Philippines (GOP)   Public Bidding
#
#                           Trade_Agreement  Approved_Budget_of_the_Contract  \
# 73953  Implementing Rules and Regulations                       1502419.23
# ...

# %%
Abajanmar2016[Abajanmar2016.Organization_Name == 'PHILIPPINE PORTS AUTHORITY, PMO-PULUPANDAN']
# Out:
#                                  Organization_Name Reference_ID  \
# 238989  PHILIPPINE PORTS AUTHORITY, PMO-PULUPANDAN      3779191
#
#                                              Notice_Title Publish_Date  \
# 238989  Provision of Three (3) Janitorial Services for...   2016-03-30
#
#        Classification                  Notice_Type    Business_Category  \
# 238989          Goods  Request for Quotation (RFQ)  Janitorial Services
#
#                              Funding_Source  \
# 238989  Government of the Philippines (GOP)
#
#                                          Procurement_Mode  \
# 238989  Negotiated Procurement - Small Value Procureme...
#
#                            Trade_Agreement  Approved_Budget_of_the_Contract  \
# 238989  Implementing Rules and Regulations                        434392.72
#
#         Item_No                Item_Name  \
# 238989      1.0  LBP Service Corporation
#
#                                          Item_Description  Item_Budget  \
# ...

# %%
Abajanmar2016[Abajanmar2016.Organization_Name == 'PHILIPPINE PORTS AUTHORITY - PMO COTABATO']
# Out:
#                                Organization_Name Reference_ID  \
# 67527  PHILIPPINE PORTS AUTHORITY - PMO COTABATO      3667682
#
#                                             Notice_Title Publish_Date  \
# 67527  Procurement of Temporary Support Personnel For...   2016-02-03
#
#                          Classification              Notice_Type  \
# 67527  Goods - General Support Services  Invitation to Bid (ITB)
#
#       Business_Category                       Funding_Source Procurement_Mode  \
# 67527          Services  Government of the Philippines (GOP)   Public Bidding
#
#                           Trade_Agreement  Approved_Budget_of_the_Contract  \
# 67527  Implementing Rules and Regulations                        3012645.6
#
#        Item_No                                          Item_Name  \
# 67527      1.0  Procurement of Temporary Support Personnel For CY
#
#                                         Item_Description  Item_Budget  \
# ...

# %%
Abajanmar2016[Abajanmar2016.Organization_Name == 'PHILIPPINE PORTS AUTHORITY  PMO-ZAMBOANGA']
# Out:
#                                 Organization_Name Reference_ID  \
# 216819  PHILIPPINE PORTS AUTHORITY  PMO-ZAMBOANGA      3763299
#
#                                              Notice_Title Publish_Date  \
# 216819  Repair & Reblocking of Damaged/Dilapidated Con...   2016-03-18
#
#        Classification              Notice_Type      Business_Category  \
# 216819    Civil Works  Invitation to Bid (ITB)  Construction Projects
#
#                              Funding_Source Procurement_Mode  \
# 216819  Government of the Philippines (GOP)   Public Bidding
#
#                            Trade_Agreement  Approved_Budget_of_the_Contract  \
# 216819  Implementing Rules and Regulations                       15332599.0
#
#         Item_No                 Item_Name  \
# 216819      1.0  Civil Works (reblocking)
#
#                                          Item_Description  Item_Budget  \
# 216819  Repair & Reblocking of Damaged/Dilapidated Con...   15332599.0
#
# ...

# %%
Abajanmar2016[Abajanmar2016.Organization_Name == 'PHILIPPINE PORTS AUTHORITY - PMO CAGAYAN DE ORO']
# Out:
#                                      Organization_Name Reference_ID  \
# 27253  PHILIPPINE PORTS AUTHORITY - PMO CAGAYAN DE ORO      3638658
#
#                                             Notice_Title Publish_Date  \
# 27253  PUBLIC BIDDING FOR THE LEASE, MANAGEMENT, OPER...   2016-01-19
#
#       Classification              Notice_Type Business_Category  \
# 27253          Goods  Invitation to Bid (ITB)          Services
#
#                             Funding_Source Procurement_Mode Trade_Agreement  \
# 27253  Government of the Philippines (GOP)   Public Bidding          Others
#
#        Approved_Budget_of_the_Contract  Item_No                Item_Name  \
# 27253                       4510362.02      1.0  Cargo Handling Services
#
#               Item_Description  Item_Budget        Closing_Date Notice_Status  \
# 27253  Cargo Handling Services   4510362.02 2016-02-09 13:00:00       Awarded
#
#         Award_No              Award_Title    Award_Type  \
# ...

# %%
Abajanmar2016[Abajanmar2016.Organization_Name == 'PHILIPPINE PORTS AUTHORITY - PDO-MANILA/N. LUZON']
# Out:
#                                        Organization_Name Reference_ID  \
# 209676  PHILIPPINE PORTS AUTHORITY - PDO-MANILA/N. LUZON      3760281
#
#                   Notice_Title Publish_Date                    Classification  \
# 209676  Port Security Services   2016-03-15  Goods - General Support Services
#
#                     Notice_Type  Business_Category  \
# 209676  Invitation to Bid (ITB)  Security Services
#
#                              Funding_Source Procurement_Mode  \
# 209676  Government of the Philippines (GOP)   Public Bidding
#
#                            Trade_Agreement  Approved_Budget_of_the_Contract  \
# 209676  Implementing Rules and Regulations                       70814952.0
#
#         Item_No          Item_Name            Item_Description  Item_Budget  \
# 209676      1.0  Security Services  PPA Port Security Services   70814952.0
#
#               Closing_Date Notice_Status   Award_No        Award_Title  \
# ...

# %%
Abajanmar2016[Abajanmar2016.Organization_Name == 'PHILIPPINE PORTS AUTHORITY - PMO TAGBILARAN']
# Out:
#                                  Organization_Name Reference_ID  \
# 43383  PHILIPPINE PORTS AUTHORITY - PMO TAGBILARAN      3651664
#
#                                             Notice_Title Publish_Date  \
# 43383  (REPOSTING) INVITATION TO BID FOR THE PROVISIO...   2016-01-26
#
#       Classification              Notice_Type    Business_Category  \
# 43383          Goods  Invitation to Bid (ITB)  Janitorial Services
#
#                             Funding_Source Procurement_Mode  \
# 43383  Government of the Philippines (GOP)   Public Bidding
#
#                           Trade_Agreement  Approved_Budget_of_the_Contract  \
# 43383  Implementing Rules and Regulations                        2439509.6
#
#        Item_No                       Item_Name     Item_Description  \
# 43383      1.0  PERFECT CLEAN GENERAL SERVICES  JANITORIAL SERVICES
#
#        Item_Budget        Closing_Date Notice_Status   Award_No  \
# 43383    2348437.1 2016-02-08 01:00:00       Awarded  1190217.0
#
# ...

# %%
Abajanmar2016[Abajanmar2016.Organization_Name == 'PHILIPPINE PORTS AUTHORITY - PMO ORMOC']
# Out:
#                             Organization_Name Reference_ID  \
# 47450  PHILIPPINE PORTS AUTHORITY - PMO ORMOC      3655338
#
#                                             Notice_Title Publish_Date  \
# 47450  INVITATION TO BID FOR THE PROVISION OF JANITOR...   2016-01-27
#
#                          Classification              Notice_Type  \
# 47450  Goods - General Support Services  Invitation to Bid (ITB)
#
#          Business_Category                       Funding_Source  \
# 47450  Janitorial Services  Government of the Philippines (GOP)
#
#                    Procurement_Mode                     Trade_Agreement  \
# 47450  National Competitive Bidding  Implementing Rules and Regulations
#
#        Approved_Budget_of_the_Contract  Item_No            Item_Name  \
# 47450                         689920.0      1.0  Janitorial Services
#
#                                         Item_Description  Item_Budget  \
# 47450  PROVISION OF JANITORIAL SERVICES FOR OFFICES O...     689920.0
# ...

# %% [markdown]
# ## New Section

# %%
PPA_HQ_janmar2016 = Abajanmar2016[Abajanmar2016.Organization_Name == 'PHILIPPINE PORTS AUTHORITY - HEAD OFFICE']

# %%
PPA_HQ_janmar2016.Awardee_Corporate_Title.value_counts().reset_index()
# Out:
#                                                index  Awardee_Corporate_Title
# 0                    GOLDRIDGE CONST. & DEV'T. CORP.                        2
# 1                   JEJOR'S CONSTRUCTION CORPORATION                        1
# 2  JOINT VENTURE J.S. LAYSON & CO., INC./A.T.TAN ...                        1
# 3                   ROYAL ASIA APPRAISAL CORPORATION                        1
# 4       PERRC CONSTRUCTION & DEVELOPMENT CORPORATION                        1
# 5                           MODE MATRIX MANILA, INC.                        1
# 6                                      CAVACON CORP.                        1
# 7                             LUCK-WELL CONSTRUCTION                        1
# 8                   SM PRIME HOLDINGS, INC. - MANILA                        1

# %%
PPA_R11_janmar2016 = Abajanmar2016[Abajanmar2016.Organization_Name == 'PHILIPPINE PORTS AUTHORITY - REGION XI']

# %%
PPA_R11_janmar2016.Awardee_Corporate_Title.value_counts().reset_index()
# Out:
#                                       index  Awardee_Corporate_Title
# 0  UNIVERSAL JANITORIAL AND ALLIED SERVICES                        1
# 1                  R.O. TESORO & SONS, INC.                        1
# 2                 MJJN ENGINEERING SERVICES                        1

# %% [markdown]
# ## DPWH Region 11

# %%
DPWH_R11_janmar2016 = Abajanmar2016[Abajanmar2016.Organization_Name == 'DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - REGION XI']

# %%
DPWH_R11_janmar2016.Awardee_Corporate_Title.value_counts().reset_index()
# Out:
#                                                 index  Awardee_Corporate_Title
# 0                        RELY CONSTRUCTION AND SUPPLY                        6
# 1                    THE WORLD PALACE BUSINESS CENTER                        4
# 2                    R.A. PAHATI CONST. & SUPPLY, INC                        3
# 3                              HEXAMINDZ CORPORATION                         2
# 4                              ULTICON BUILDERS, INC.                        2
# 5                              THREE W BUILDERS, INC.                        2
# 6                         P.L. SEBASTIAN CONSTRUCTION                        1
# 7   ROMA CONSTRUCTION AND DEVELOPMENT CORP. / H2 L...                        1
# 8                        MINDANAO LABORATORY SERVICES                        1
# 9                       LBC EXPRESS INC. - DAVAO CITY                        1
# 10                                  ALZAM ENTERPRISES                        1
# ...

# %%
DPWH_R11_janmar2016[DPWH_R11_janmar2016.Awardee_Corporate_Title == 'ULTICON BUILDERS, INC.']
# Out:
#                                        Organization_Name Reference_ID  \
# 36551  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - REGI...      3647202
# 36552  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - REGI...      3647203
#
#                                             Notice_Title Publish_Date  \
# 36551  16L00023  Construction/Opening of Tagugpo-Pias...   2016-01-22
# 36552  16L00024  Construction/Opening of Piasusuan-Bi...   2016-01-22
#
#       Classification              Notice_Type      Business_Category  \
# 36551    Civil Works  Invitation to Bid (ITB)  Construction Projects
# 36552    Civil Works  Invitation to Bid (ITB)  Construction Projects
#
#                             Funding_Source Procurement_Mode  \
# 36551  Government of the Philippines (GOP)   Public Bidding
# 36552  Government of the Philippines (GOP)   Public Bidding
#
#                           Trade_Agreement  Approved_Budget_of_the_Contract  \
# ...

# %% [markdown]
# # April to June 2016

# %%
baaprjun2016 = pd.read_excel("C:/Users/wolfgang/Documents/Work/2018/PhilGEPS_2016-2017/2016/Bid Notice and Award Details Apr-June 2016.xlsx")

# %%
baaprjun2016.Notice_Status.value_counts().reset_index()
# Out:
#          index  Notice_Status
# 0       Closed         141860
# 1      Awarded          52550
# 2       Failed          13522
# 3    Cancelled           6649
# 4  Shortlisted             78
# 5       Active             23

# %%
Abaaprjun2016 = baaprjun2016[baaprjun2016.Notice_Status == 'Awarded']

# %%
Abaaprjun2016.Organization_Name.value_counts()
# Out:
# CITY OF DIGOS, DAVAO DEL SUR                                    758
# MARIANO MARCOS MEMORIAL HOSPITAL AND MEDICAL CENTER             748
# BAGUIO GENERAL HOSPITAL AND MEDICAL CENTER                      667
# CARAGA STATE UNIVERSITY                                         560
# PHILIPPINE NATIONAL POLICE - LOGISTICS SUPPORT SERVICE          555
# CORAZON LOCSIN MONTELIBANO MEMORIAL REGIONAL HOSPITAL-DOH R6    553
# MISAMIS ORIENTAL STATE COLLEGE OF AGRICULTURE AND TECHNOLOGY    487
# CITY OF QUEZON                                                  419
# UNIVERSITY OF THE PHILIPPINES - DILIMAN                         411
# BUREAU OF CORRECTIONS                                           389
# PROVINCE OF KALINGA                                             383
# PALOMPON INSTITUTE OF TECHNOLOGY                                378
# MUNICIPALITY OF CALATRAVA, ROMBLON                              370
# NATIONAL POWER CORPORATION                                      347
# ...

# %% [markdown]
# ## PPA Regions

# %%
Abaaprjun2016[Abaaprjun2016.Organization_Name == 'PHILIPPINE PORTS AUTHORITY - HEAD OFFICE']
# Out:
#                                Organization_Name Reference_ID  \
# 45495   PHILIPPINE PORTS AUTHORITY - HEAD OFFICE      3809862
# 45519   PHILIPPINE PORTS AUTHORITY - HEAD OFFICE      3809885
# 73671   PHILIPPINE PORTS AUTHORITY - HEAD OFFICE      3825673
# 73737   PHILIPPINE PORTS AUTHORITY - HEAD OFFICE      3826430
# 104759  PHILIPPINE PORTS AUTHORITY - HEAD OFFICE      3848222
# 134966  PHILIPPINE PORTS AUTHORITY - HEAD OFFICE      3867250
# 137574  PHILIPPINE PORTS AUTHORITY - HEAD OFFICE      3868901
#
#                                              Notice_Title Publish_Date  \
# 45495   CONTRACT FOR THE PROVISION OF TECHNICAL AND AD...   2016-04-21
# 45519   PROVISION OF JANITORIAL AND MAINTENANCE SERVIC...   2016-04-21
# 73671   CONSTRUCTION OF WHARF FOR RAIL MOUNTED GANTRY ...   2016-05-05
# 73737   EXTENSION OF WHARF AND EXPANSION OF BACK-UP AR...   2016-05-05
# 104759  BIDDING FOR THE PPA MANAGED NETWORK SERVICES F...   2016-05-19
# ...

# %%
PPA_HQ_aprjun2016 = Abaaprjun2016[Abaaprjun2016.Organization_Name == 'PHILIPPINE PORTS AUTHORITY - HEAD OFFICE']

# %%
PPA_HQ_aprjun2016.Awardee_Corporate_Title.value_counts().reset_index()
# Out:
#                                                index  Awardee_Corporate_Title
# 0                            LBP SERVICE CORPORATION                        2
# 1                            ORACLE ( PHILS. ) CORP.                        1
# 2                               IONE RESOURCES, INC.                        1
# 3                                 UKC BUILDERS, INC.                        1
# 4  F. GURREA CONSTRUCTION INCORPORATED / MRBII CO...                        1
# 5                    TOWERS WATSON PHILIPPINES, INC.                        1

# %%
Abaaprjun2016[Abaaprjun2016.Organization_Name == 'PHILIPPINE PORTS AUTHORITY - REGION XI']
# Out:
#                              Organization_Name Reference_ID  \
# 14502   PHILIPPINE PORTS AUTHORITY - REGION XI      3790774
# 32815   PHILIPPINE PORTS AUTHORITY - REGION XI      3801912
# 46397   PHILIPPINE PORTS AUTHORITY - REGION XI      3810581
# 91990   PHILIPPINE PORTS AUTHORITY - REGION XI      3840022
# 108866  PHILIPPINE PORTS AUTHORITY - REGION XI      3850786
# 129008  PHILIPPINE PORTS AUTHORITY - REGION XI      3863839
# 141872  PHILIPPINE PORTS AUTHORITY - REGION XI      3872834
# 168752  PHILIPPINE PORTS AUTHORITY - REGION XI      3889443
# 168772  PHILIPPINE PORTS AUTHORITY - REGION XI      3889523
# 179431  PHILIPPINE PORTS AUTHORITY - REGION XI      3897391
# 186449  PHILIPPINE PORTS AUTHORITY - REGION XI      3900421
# 214238  PHILIPPINE PORTS AUTHORITY - REGION XI      3920792
# 214285  PHILIPPINE PORTS AUTHORITY - REGION XI      3920818
#
#                                              Notice_Title Publish_Date  \
# ...

# %%
PPA_R11_aprjun2016 = Abaaprjun2016[Abaaprjun2016.Organization_Name == 'PHILIPPINE PORTS AUTHORITY - REGION XI']

# %%
PPA_R11_aprjun2016.Awardee_Corporate_Title.value_counts().reset_index()
# Out:
#                                                index  Awardee_Corporate_Title
# 0                          KHAN KON CHI CONSTRUCTION                        4
# 1           UNIVERSAL JANITORIAL AND ALLIED SERVICES                        2
# 2  DAVAO BAYAN CONSTRUCTION AND HARDWARE SUPPLY, ...                        2
# 3                                   ZET CONSTRUCTION                        1
# 4                   GCV COPIER SUPPLIES AND SERVICES                        1
# 5                            LBP SERVICE CORPORATION                        1
# 6                        RJJL CONSTRUCTION & TRADING                        1
# 7               ANFLO RESORT DEVELOPMENT CORPORATION                        1

# %% [markdown]
# # July to September

# %%
bajulsep2016 = pd.read_excel("C:/Users/wolfgang/Documents/Work/2018/PhilGEPS_2016-2017/2016/Bid Notice and Award Details July-Sept 2016.xlsx")

# %%
bajulsep2016.Notice_Status.value_counts().reset_index()
# Out:
#          index  Notice_Status
# 0       Closed         171735
# 1      Awarded          61217
# 2       Failed          14362
# 3    Cancelled           7020
# 4  Shortlisted             48

# %%
Abajulsep2016 = bajulsep2016[bajulsep2016.Notice_Status == 'Awarded']

# %%
Abajulsep2016.Organization_Name.value_counts()
# Out:
# MUNICIPALITY OF KAPALONG, DAVAO DEL NORTE                       1722
# MUNICIPALITY OF BARUGO, LEYTE                                   1695
# CITY OF DIGOS, DAVAO DEL SUR                                     925
# PHILIPPINE NATIONAL POLICE - LOGISTICS SUPPORT SERVICE           757
# SOUTHERN PHILIPPINES MEDICAL CENTER                              714
# CORAZON LOCSIN MONTELIBANO MEMORIAL REGIONAL HOSPITAL-DOH R6     707
# MUNICIPALITY OF LEON, ILOILO                                     692
# BARANGAY MAZAWALO, PALOMPON, LEYTE                               527
# PROVINCE OF KALINGA                                              481
# CITY OF QUEZON                                                   440
# MUNICIPALITY OF ROSALES, PANGASINAN                              366
# CITY OF ANTIPOLO, RIZAL                                          349
# NATIONAL POWER CORPORATION - MINDANAO GENERATION                 338
# PROVINCE OF AGUSAN DEL SUR                                       322
# ...

# %%
Abajulsep2016[Abajulsep2016.Organization_Name == 'PHILIPPINE PORTS AUTHORITY - HEAD OFFICE']
# Out:
#                                Organization_Name Reference_ID  \
# 214043  PHILIPPINE PORTS AUTHORITY - HEAD OFFICE      4067005
# 250193  PHILIPPINE PORTS AUTHORITY - HEAD OFFICE      4041219
#
#                                              Notice_Title Publish_Date  \
# 214043  BIDDING FOR THE SUPPLY AND DELIVERY OF BRAND N...   2016-09-17
# 250193            Lease of Venue for the 42nd APA Meeting   2016-09-30
#
#        Classification                  Notice_Type  \
# 214043          Goods      Invitation to Bid (ITB)
# 250193          Goods  Request for Quotation (RFQ)
#
#                                Business_Category  \
# 214043                                  Vehicles
# 250193  Lease and Rental of Property or Building
#
#                              Funding_Source  \
# 214043                               Others
# 250193  Government of the Philippines (GOP)
#
#                                          Procurement_Mode  \
# ...

# %%
PPA_HQ_julsep2016 = Abajulsep2016[Abajulsep2016.Organization_Name == 'PHILIPPINE PORTS AUTHORITY - HEAD OFFICE']

# %%
PPA_HQ_julsep2016.Awardee_Corporate_Title.value_counts().reset_index()
# Out:
#                     index  Awardee_Corporate_Title
# 0  SURESTE PROPERTY, INC.                        1
# 1         TOYOTA OTIS INC                        1

# %%
Abajulsep2016[Abajulsep2016.Organization_Name == 'PHILIPPINE PORTS AUTHORITY - REGION XI']
# Out:
#                              Organization_Name Reference_ID  \
# 47717   PHILIPPINE PORTS AUTHORITY - REGION XI      3952539
# 77208   PHILIPPINE PORTS AUTHORITY - REGION XI      3972913
# 90075   PHILIPPINE PORTS AUTHORITY - REGION XI      3981481
# 128928  PHILIPPINE PORTS AUTHORITY - REGION XI      4007634
# 159659  PHILIPPINE PORTS AUTHORITY - REGION XI      4028611
# 234724  PHILIPPINE PORTS AUTHORITY - REGION XI      4080742
# 251584  PHILIPPINE PORTS AUTHORITY - REGION XI      4091336
#
#                                              Notice_Title Publish_Date  \
# 47717   Invitation to Bid re Repair for the Maintenanc...   2016-07-20
# 77208   Request for Quotation re Wall Signage at Truck...   2016-07-30
# 90075   Invitation To Bid re Repair and Maintenance of...   2016-08-04
# 128928        Request for Quotation re Printer, 3-1, CISS   2016-08-17
# 159659  Request for Quotation re Provision of two(2) C...   2016-08-26
# ...

# %%
PPA_R11_julsep2016 = Abajulsep2016[Abajulsep2016.Organization_Name == 'PHILIPPINE PORTS AUTHORITY - REGION XI']

# %%
PPA_R11_julsep2016.Awardee_Corporate_Title.value_counts().reset_index()
# Out:
#                                       index  Awardee_Corporate_Title
# 0      SANPLAS MANPOWER AND ALLIED SERVICES                        2
# 1              DAVAO MARK ENTERPRISES, INC.                        1
# 2                          ZET CONSTRUCTION                        1
# 3                     DIGITAL INTERFACE INC                        1
# 4  UNIVERSAL JANITORIAL AND ALLIED SERVICES                        1
# 5                 KHAN KON CHI CONSTRUCTION                        1

# %% [markdown]
# # October to December

# %%
baoctdec2016 = pd.read_excel("C:/Users/wolfgang/Documents/Work/2018/PhilGEPS_2016-2017/2016/Bid Notice and Award Details Oct-Dec 2016.xlsx")

# %%
baoctdec2016.Notice_Status.value_counts().reset_index()
# Out:
#          index  Notice_Status
# 0       Closed         182265
# 1      Awarded          58660
# 2       Failed          13383
# 3    Cancelled           7775
# 4  Shortlisted             89
# 5       Active             11

# %%
Abaoctdec2016 = baoctdec2016[baoctdec2016.Notice_Status == 'Awarded']

# %%
Abaoctdec2016.Organization_Name.value_counts()
# Out:
# MUNICIPALITY OF KAPALONG, DAVAO DEL NORTE                       1132
# PHILIPPINE NATIONAL POLICE - LOGISTICS SUPPORT SERVICE           823
# CITY OF DIGOS, DAVAO DEL SUR                                     759
# MUNICIPALITY OF PINILI, ILOCOS NORTE                             576
# CORAZON LOCSIN MONTELIBANO MEMORIAL REGIONAL HOSPITAL-DOH R6     565
# MUNICIPALITY OF VALLEHERMOSO, NEGROS                             455
# PROVINCE OF KALINGA                                              443
# SOUTHERN PHILIPPINES MEDICAL CENTER                              413
# BUKIDNON STATE UNIVERSITY                                        413
# CITY OF QUEZON                                                   408
# MUNICIPALITY OF LEON, ILOILO                                     389
# PROVINCE OF AGUSAN DEL SUR                                       358
# PROVINCE OF LAGUNA                                               350
# MUNICIPALITY OF BARUGO, LEYTE                                    337
# ...

# %%
PPA_HQ_octdec2016 = Abaoctdec2016[Abaoctdec2016.Organization_Name == 'PHILIPPINE PORTS AUTHORITY - HEAD OFFICE']

# %%
PPA_HQ_octdec2016
# Out:
#                                Organization_Name Reference_ID  \
# 68539   PHILIPPINE PORTS AUTHORITY - HEAD OFFICE      4140971
# 68730   PHILIPPINE PORTS AUTHORITY - HEAD OFFICE      4141103
# 68874   PHILIPPINE PORTS AUTHORITY - HEAD OFFICE      4141190
# 68919   PHILIPPINE PORTS AUTHORITY - HEAD OFFICE      4141234
# 76730   PHILIPPINE PORTS AUTHORITY - HEAD OFFICE      4147076
# 76784   PHILIPPINE PORTS AUTHORITY - HEAD OFFICE      4147127
# 76813   PHILIPPINE PORTS AUTHORITY - HEAD OFFICE      4147157
# 76866   PHILIPPINE PORTS AUTHORITY - HEAD OFFICE      4147207
# 143920  PHILIPPINE PORTS AUTHORITY - HEAD OFFICE    4147236-2
# 143921  PHILIPPINE PORTS AUTHORITY - HEAD OFFICE    4147255-2
# 150781  PHILIPPINE PORTS AUTHORITY - HEAD OFFICE      4199761
# 150808  PHILIPPINE PORTS AUTHORITY - HEAD OFFICE      4199820
# 150848  PHILIPPINE PORTS AUTHORITY - HEAD OFFICE      4199869
# 240288  PHILIPPINE PORTS AUTHORITY - HEAD OFFICE      4264318
#
# ...

# %%
PPA_HQ_octdec2016.Awardee_Corporate_Title.value_counts()
# Out:
# GOLDRIDGE CONST. & DEV'T. CORP.                                                                  3
# SYCONSULT, INCORPORATED                                                                          1
# PROPMECH CORPORATION                                                                             1
# EQUI-PARCO CONSTRUCTION COMPANY                                                                  1
# HG-III CONSTRUCTION & DEVELOPMENT CORPORATION                                                    1
# MARRA BUILDERS, INC.                                                                             1
# GOLDRIDGE CONSTRUCTION & DEVELOPMENT INC./DALEBO CONSTRUCTION &GEN. MERCHANDISE/JOINT VENTURE    1
# R.S. JARDIN & ASSOCIATES                                                                         1
# F.GURREA CONST. INC/GRACE CONST. CORP.                                                           1
# ...

# %%
PPA_R11_octdec2016 = Abaoctdec2016[Abaoctdec2016.Organization_Name == 'PHILIPPINE PORTS AUTHORITY - REGION XI']

# %%
PPA_R11_octdec2016
# Out:
#                              Organization_Name Reference_ID  \
# 50547   PHILIPPINE PORTS AUTHORITY - REGION XI      4127214
# 50908   PHILIPPINE PORTS AUTHORITY - REGION XI      4127515
# 75826   PHILIPPINE PORTS AUTHORITY - REGION XI      4146198
# 166304  PHILIPPINE PORTS AUTHORITY - REGION XI      4209926
# 260699  PHILIPPINE PORTS AUTHORITY - REGION XI      4279018
#
#                                              Notice_title Publish_Date  \
# 50547   Invitation to Bid re Repair of Perimeter Fence...   2016-10-18
# 50908   Invitation to Bid re Repainting of PPA PMO-Adm...   2016-10-18
# 75826   Request for Quotation re Food accommodation fo...   2016-10-27
# 166304  Request for Quotation re Supply and Deliver Di...   2016-11-24
# 260699          Request for Quotation re Various signages   2016-12-29
#
#        Classification                  Notice_Type        Business_Category  \
# 50547     Civil Works      Invitation to Bid (ITB)    Construction Projects
# ...

# %%
PPA_R11_octdec2016.Awardee_Corporate_Title.value_counts()
# Out:
# ZET CONSTRUCTION                                      2
# COPYLANDIA OFFICE SYSTEMS CORPORATION (COPYLANDIA)    1
# HIJO RESOURCES CORPORATION                            1
# DIGIMARK ADVERTISING                                  1
# Name: Awardee_Corporate_Title, dtype: int64
