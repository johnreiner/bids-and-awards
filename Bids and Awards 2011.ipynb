# %%
import pandas as pd
import numpy as np

# %%
pd.options.display.max_columns = None
pd.options.display.max_rows = None

# %% [markdown]
# # Jan-Mar 2011

# %%
bajanmar2011 = pd.read_excel("C:/Users/wolfgang/Documents/Work/DPWH/PhilGEPS Data/2011/Bid Notice and Award Details Jan-Mar 2011.xlsx")

# %%
bajanmar2011.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85461 entries, 0 to 85460
# Data columns (total 26 columns):
# Organization_Name         85461 non-null object
# Reference_No              85461 non-null object
# Bid_Notice_Title          85461 non-null object
# Publish_Date              85461 non-null datetime64[ns]
# Classification            85461 non-null object
# Notice_Type               85461 non-null object
# Business_Category         85461 non-null object
# Funding_Source            85461 non-null object
# Procurement_Mode          85461 non-null object
# Trade_Agreement           85461 non-null object
# Approved_Budget           85461 non-null float64
# Item_No                   30411 non-null float64
# Item_Name                 30411 non-null object
# Item_Description          30319 non-null object
# Item_Budget               30411 non-null float64
# Closing_Date              85461 non-null datetime64[ns]
# Bid_Notice_Status         85461 non-null object
# ...

# %%
bajanmar2011.Bid_Notice_Status.value_counts()
# Out:
# Closed         67663
# Awarded        13924
# Cancelled       1939
# Failed          1916
# Shortlisted       19
# Name: Bid_Notice_Status, dtype: int64

# %%
Abajanmar2011 = bajanmar2011[bajanmar2011.Bid_Notice_Status == 'Awarded']

# %%
Abajanmar2011.Organization_Name.value_counts()
# Out:
# PROVINCE OF LAGUNA                                              1109
# PROVINCE OF RIZAL                                                581
# CITY OF QUEZON                                                   438
# CITY OF DIPOLOG, ZAMBOANGA DEL NORTE                             428
# PROVINCE OF COMPOSTELA VALLEY                                    327
# CITY OF SAN CARLOS, NEGROS OCCIDENTAL                            319
# THE NATIONAL LIBRARY                                             275
# PHILIPPINE AMUSEMENT AND GAMING CORPORATION                      235
# LUNG CENTER OF THE PHILIPPINES                                   216
# CITY OF MAKATI                                                   203
# MUNICIPALITY OF STO. TOMAS, BATANGAS                             195
# PROVINCE OF BATANGAS                                             193
# PROVINCE OF ALBAY                                                180
# UNIVERSITY OF THE PHILIPPINES SYSTEM - DILIMAN                   166
# ...

# %% [markdown]
# ## Awarded DPWH

# %%
DPWH_Abajanmar2011 = Abajanmar2011[Abajanmar2011.Organization_Name == 'DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN']

# %%
DPWH_Abajanmar2011.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 31 entries, 829 to 77782
# Data columns (total 26 columns):
# Organization_Name         31 non-null object
# Reference_No              31 non-null object
# Bid_Notice_Title          31 non-null object
# Publish_Date              31 non-null datetime64[ns]
# Classification            31 non-null object
# Notice_Type               31 non-null object
# Business_Category         31 non-null object
# Funding_Source            31 non-null object
# Procurement_Mode          31 non-null object
# Trade_Agreement           31 non-null object
# Approved_Budget           31 non-null float64
# Item_No                   23 non-null float64
# Item_Name                 23 non-null object
# Item_Description          23 non-null object
# Item_Budget               23 non-null float64
# Closing_Date              31 non-null datetime64[ns]
# Bid_Notice_Status         31 non-null object
# Award_No                  31 non-null float64
# ...

# %% [markdown]
# ### Awardees

# %%
DPWH_Abajanmar2011.Awardee.value_counts()
# Out:
# J.D. LEGASPI CONSTRUCTION                                       3
# NORTHERN BUILDERS                                               2
# DEVELOPEMENT ENGINEERING AND MANAGEMENT CORP. (DEMCOR, INC.)    1
# QINGJIAN GROUP CO., LTD. PHILIPPINE BRANCH                      1
# MAC BUILDERS                                                    1
# R.A. PAHATI GRAVEL AND SAND                                     1
# MONOLITHIC CONSTRUCTION AND CONCRETE PRODUCTS, INC.             1
# LUZON SALES COMPANY, INCORPORATED                               1
# MAR-DEB CONSTRUCTION AND DEVELOPMENT                            1
# E. A. SANCHO CONSTRUCTION, INC.                                 1
# CAMIA CONST. DEVELOPMENT CORPORATION                            1
# RENARDET S.A.                                                   1
# GCI CONSTRUCTION                                                1
# ZABU ENGINEERING                                                1
# ...

# %% [markdown]
# ### Procurement Mode

# %%
DPWH_Abajanmar2011.Procurement_Mode.value_counts()
# Out:
# Public Bidding                       24
# International Competitive Bidding     4
# Shopping                              3
# Name: Procurement_Mode, dtype: int64

# %% [markdown]
# #### Public Bidding

# %%
DPWH_Abajanmar2011[DPWH_Abajanmar2011.Procurement_Mode == 'Public Bidding']
# Out:
#                                     Organization_Name Reference_No  \
# 829    DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1393770
# 830    DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1393770
# 831    DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1393770
# 1348   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1394176
# 1349   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1394176
# 1350   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1394176
# 1351   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1394176
# 1352   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1394176
# 1353   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1394176
# 1354   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1394176
# 1355   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1394176
# 1356   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1394176
# 1357   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1394176
# ...

# %% [markdown]
# #### International Competitive Bidding

# %%
DPWH_Abajanmar2011[DPWH_Abajanmar2011.Procurement_Mode == 'International Competitive Bidding']
# Out:
#                                     Organization_Name Reference_No  \
# 11040  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1402197
# 24846  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1412731
# 44079  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1427389
# 55530  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1435586
#
#                                         Bid_Notice_Title Publish_Date  \
# 11040  Consultancy Services to undertake Project Impl...   2011-01-21
# 24846  CP RI 2.4 Improvement of Bacolod Kabankalan Ro...   2011-02-05
# 44079  CP RI 2.1: IMPROVEMENT OF MAGAPIT STA. ANA ROA...   2011-02-24
# 55530  Consultancy Services for the Detailed Engineer...   2011-03-05
#
#             Classification                         Notice_Type  \
# 11040  Consulting Services  Request for Expression of Interest
# 24846          Civil Works             Invitation to Bid (ITB)
# 44079                Goods             Invitation to Bid (ITB)
# ...

# %% [markdown]
# #### Shopping

# %%
DPWH_Abajanmar2011[DPWH_Abajanmar2011.Procurement_Mode == 'Shopping']
# Out:
#                                     Organization_Name Reference_No  \
# 16645  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1406193
# 16648  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1406197
# 74967  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1450420
#
#                                         Bid_Notice_Title Publish_Date  \
# 16645  VARIOUS CONST. MATERIALS FOR THE PROPOSED FABR...   2011-01-28
# 16648  Tires, tubeless with snap on valve SIZE 245/70...   2011-01-28
# 74967  VARIOUS CONST. MATERIALS FOR USE IN THE REPAIR...   2011-03-23
#
#       Classification                  Notice_Type  \
# 16645          Goods  Request for Quotation (RFQ)
# 16648          Goods  Request for Quotation (RFQ)
# 74967          Goods  Request for Quotation (RFQ)
#
#                          Business_Category  \
# 16645  Construction Materials and Supplies
# 16648        Vehicle Parts and Accessories
# 74967  Construction Materials and Supplies
#
# ...

# %% [markdown]
# ## City of Las Pinas

# %%
CLP_Abajanmar2011 = Abajanmar2011[Abajanmar2011.Organization_Name == 'CITY OF LAS PINAS']

# %%
CLP_Abajanmar2011.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5 entries, 47798 to 47802
# Data columns (total 26 columns):
# Organization_Name         5 non-null object
# Reference_No              5 non-null object
# Bid_Notice_Title          5 non-null object
# Publish_Date              5 non-null datetime64[ns]
# Classification            5 non-null object
# Notice_Type               5 non-null object
# Business_Category         5 non-null object
# Funding_Source            5 non-null object
# Procurement_Mode          5 non-null object
# Trade_Agreement           5 non-null object
# Approved_Budget           5 non-null float64
# Item_No                   5 non-null float64
# Item_Name                 5 non-null object
# Item_Description          5 non-null object
# Item_Budget               5 non-null float64
# Closing_Date              5 non-null datetime64[ns]
# Bid_Notice_Status         5 non-null object
# Award_No                  5 non-null float64
# ...

# %% [markdown]
# ### Awardee

# %%
CLP_Abajanmar2011.Awardee.value_counts()
# Out:
# E.M. ANGELES ENTERPRISES           2
# ARAC CONSTRUCTION                  1
# KME DESIGN AND CONSTRUCTION        1
# REDCAR TRADING AND CONSTRUCTION    1
# Name: Awardee, dtype: int64

# %% [markdown]
# ### Procurement Mode

# %%
CLP_Abajanmar2011.Procurement_Mode.value_counts()
# Out:
# Public Bidding    5
# Name: Procurement_Mode, dtype: int64

# %% [markdown]
# #### Public Bidding

# %%
CLP_Abajanmar2011[CLP_Abajanmar2011.Procurement_Mode == 'Public Bidding']
# Out:
#        Organization_Name Reference_No  \
# 47798  CITY OF LAS PINAS      1428772
# 47799  CITY OF LAS PINAS      1428772
# 47800  CITY OF LAS PINAS      1428772
# 47801  CITY OF LAS PINAS      1428772
# 47802  CITY OF LAS PINAS      1428772
#
#                                         Bid_Notice_Title Publish_Date  \
# 47798  Various Infrastructure Projects in Las Pinas City   2011-02-25
# 47799  Various Infrastructure Projects in Las Pinas City   2011-02-25
# 47800  Various Infrastructure Projects in Las Pinas City   2011-02-25
# 47801  Various Infrastructure Projects in Las Pinas City   2011-02-25
# 47802  Various Infrastructure Projects in Las Pinas City   2011-02-25
#
#       Classification              Notice_Type      Business_Category  \
# 47798    Civil Works  Invitation to Bid (ITB)  Construction Projects
# 47799    Civil Works  Invitation to Bid (ITB)  Construction Projects
# 47800    Civil Works  Invitation to Bid (ITB)  Construction Projects
# ...

# %% [markdown]
# # Apr-Jun 2011

# %%
baaprjun2011 = pd.read_excel("C:/Users/wolfgang/Documents/Work/DPWH/PhilGEPS Data/2011/Bid Notice and Award Details Apr-June 2011.xlsx")

# %%
baaprjun2011.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93270 entries, 0 to 93269
# Data columns (total 26 columns):
# Organization_Name         93270 non-null object
# Reference_No              93270 non-null object
# Bid_Notice_Title          93270 non-null object
# Publish_Date              93270 non-null datetime64[ns]
# Classification            93270 non-null object
# Notice_Type               93270 non-null object
# Business_Category         93270 non-null object
# Funding_Source            93270 non-null object
# Procurement_Mode          93270 non-null object
# Trade_Agreement           93270 non-null object
# Approved_Budget           93270 non-null float64
# Item_No                   29977 non-null float64
# Item_Name                 29977 non-null object
# Item_Description          29950 non-null object
# Item_Budget               29977 non-null float64
# Closing_Date              93270 non-null datetime64[ns]
# Bid_Notice_Status         93270 non-null object
# ...

# %%
baaprjun2011.Bid_Notice_Status.value_counts().reset_index()
# Out:
#          index  Bid_Notice_Status
# 0       Closed              72352
# 1      Awarded              16109
# 2       Failed               2763
# 3    Cancelled               2034
# 4  Shortlisted                 12

# %%
Abaaprjun2011 = baaprjun2011[baaprjun2011.Bid_Notice_Status == 'Awarded']

# %%
Abaaprjun2011.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16109 entries, 0 to 93267
# Data columns (total 26 columns):
# Organization_Name         16109 non-null object
# Reference_No              16109 non-null object
# Bid_Notice_Title          16109 non-null object
# Publish_Date              16109 non-null datetime64[ns]
# Classification            16109 non-null object
# Notice_Type               16109 non-null object
# Business_Category         16109 non-null object
# Funding_Source            16109 non-null object
# Procurement_Mode          16109 non-null object
# Trade_Agreement           16109 non-null object
# Approved_Budget           16109 non-null float64
# Item_No                   4704 non-null float64
# Item_Name                 4704 non-null object
# Item_Description          4704 non-null object
# Item_Budget               4704 non-null float64
# Closing_Date              16109 non-null datetime64[ns]
# Bid_Notice_Status         16109 non-null object
# ...

# %%
Abaaprjun2011.Organization_Name.value_counts()
# Out:
# PROVINCE OF LAGUNA                                              840
# PROVINCE OF RIZAL                                               614
# CITY OF DIPOLOG, ZAMBOANGA DEL NORTE                            516
# PROVINCE OF COMPOSTELA VALLEY                                   433
# CITY OF QUEZON                                                  389
# CITY OF SAN CARLOS, NEGROS OCCIDENTAL                           264
# PHILIPPINE AMUSEMENT AND GAMING CORPORATION-PARAÑAQUE           259
# DEPARTMENT OF EDUCATION - DIVISION OF CAMARINES SUR             242
# CITY OF MAKATI                                                  239
# MUNICIPALITY OF STO. TOMAS, BATANGAS                            224
# PHILIPPINE AMUSEMENT AND GAMING CORPORATION                     220
# CITY OF CALAMBA, LAGUNA                                         199
# PHILIPPINE AMUSEMENT AND GAMING CORPORATION-HERITAGE            188
# NATIONAL POWER CORPORATION SPUG-MINDANAO                        185
# ...

# %% [markdown]
# ## Awarded DPWH

# %%
DPWH_Abaaprjun2011 = Abaaprjun2011[Abaaprjun2011.Organization_Name == 'DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN']

# %%
DPWH_Abaaprjun2011.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 49 entries, 8857 to 90373
# Data columns (total 26 columns):
# Organization_Name         49 non-null object
# Reference_No              49 non-null object
# Bid_Notice_Title          49 non-null object
# Publish_Date              49 non-null datetime64[ns]
# Classification            49 non-null object
# Notice_Type               49 non-null object
# Business_Category         49 non-null object
# Funding_Source            49 non-null object
# Procurement_Mode          49 non-null object
# Trade_Agreement           49 non-null object
# Approved_Budget           49 non-null float64
# Item_No                   8 non-null float64
# Item_Name                 8 non-null object
# Item_Description          8 non-null object
# Item_Budget               8 non-null float64
# Closing_Date              49 non-null datetime64[ns]
# Bid_Notice_Status         49 non-null object
# Award_No                  49 non-null float64
# ...

# %% [markdown]
# ### Awardees

# %%
DPWH_Abaaprjun2011.Awardee.value_counts()
# Out:
# NORTHERN BUILDERS                                   4
# J.D. LEGASPI CONSTRUCTION                           4
# MASANGKAY COMPUTER CENTER                           2
# CENTRAL LOCKWOOD HARDWARE AND LUMBER INC.           2
# JM AUTO PARTS & GENERAL MERCHANDISE CO.             2
# MICROBASE INCORPORATED                              2
# UNLIMITED RESOURCE GROUP PHILS,. INC.               2
# HP TRADING AND AIRCONDITIONING CORP.                2
# MCSA MARKETING                                      2
# CHAMPION HARDWARE & CO., INC.                       1
# CUBIXOFFICE INC.                                    1
# CHEMGATE INDUSTRIAL SALES                           1
# A.J. TAYLAN CONSTRUCTION CORPORATION                1
# R.A. PAHATI GRAVEL AND SAND                         1
# GLOBAL MYOHO RENGE COPY INC.                        1
# MAC BUILDERS                                        1
# BREN MOTORS                                         1
# ...

# %% [markdown]
# ### Procurement Mode

# %%
DPWH_Abaaprjun2011.Procurement_Mode.value_counts()
# Out:
# Shopping                                                                 29
# Public Bidding                                                           13
# Negotiated Procurement                                                    6
# Shopping - Ordinary/Regular Office Supplies & Equipment (Sec. 52.1.b)     1
# Name: Procurement_Mode, dtype: int64

# %% [markdown]
# #### Shopping

# %%
DPWH_Abaaprjun2011[DPWH_Abaaprjun2011.Procurement_Mode == 'Shopping']
# Out:
#                                     Organization_Name Reference_No  \
# 8857   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1465515
# 8870   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1465531
# 8877   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1465538
# 10112  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1466781
# 14811  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1470186
# 25665  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1478851
# 26497  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1479763
# 26501  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1479767
# 26506  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1479772
# 26518  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1479778
# 26542  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1479798
# 26548  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1479802
# 26551  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1479805
# ...

# %% [markdown]
# #### Public Bidding

# %%
DPWH_Abaaprjun2011[DPWH_Abaaprjun2011.Procurement_Mode == 'Public Bidding']
# Out:
#                                     Organization_Name Reference_No  \
# 21332  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1475852
# 27508  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1480542
# 52015  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1499214
# 61861  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1506185
# 61862  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1506185
# 68953  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1512617
# 71609  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1514598
# 73019  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1515750
# 74426  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1517117
# 78995  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1520892
# 79013  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1520914
# 83692  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1524489
# 90373  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1530454
#
# ...

# %% [markdown]
# #### Negotiated Procurement

# %%
DPWH_Abaaprjun2011[DPWH_Abaaprjun2011.Procurement_Mode == 'Negotiated Procurement']
# Out:
#                                     Organization_Name Reference_No  \
# 74296  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1516988
# 74297  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1516988
# 74298  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1516988
# 74299  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1516988
# 74300  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1516988
# 74301  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1516988
#
#                                         Bid_Notice_Title Publish_Date  \
# 74296  Contract Packages 7, 9, 29, 35, 36, 40 under P...   2011-06-10
# 74297  Contract Packages 7, 9, 29, 35, 36, 40 under P...   2011-06-10
# 74298  Contract Packages 7, 9, 29, 35, 36, 40 under P...   2011-06-10
# 74299  Contract Packages 7, 9, 29, 35, 36, 40 under P...   2011-06-10
# 74300  Contract Packages 7, 9, 29, 35, 36, 40 under P...   2011-06-10
# 74301  Contract Packages 7, 9, 29, 35, 36, 40 under P...   2011-06-10
#
# ...

# %% [markdown]
# #### Shopping - Ordinary/Regular Office Supplies & Equipment (Sec. 52.1.b)

# %%
DPWH_Abaaprjun2011[DPWH_Abaaprjun2011.Procurement_Mode == 'Shopping - Ordinary/Regular Office Supplies & Equipment (Sec. 52.1.b)']
# Out:
#                                     Organization_Name Reference_No  \
# 33632  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1485508
#
#                                         Bid_Notice_Title Publish_Date  \
# 33632  various spare parts for the Mitsubishi L 200 P...   2011-05-04
#
#       Classification                  Notice_Type  \
# 33632          Goods  Request for Quotation (RFQ)
#
#                    Business_Category                       Funding_Source  \
# 33632  Vehicle Parts and Accessories  Government of the Philippines (GOP)
#
#                                         Procurement_Mode  \
# 33632  Shopping - Ordinary/Regular Office Supplies & ...
#
#                           Trade_Agreement  Approved_Budget  Item_No Item_Name  \
# 33632  Implementing Rules and Regulations          80250.0      NaN       NaN
#
#       Item_Description  Item_Budget        Closing_Date Bid_Notice_Status  \
# ...

# %% [markdown]
# ## City of Las Pinas

# %%
CLP_Abaaprjun2011 = Abaaprjun2011[Abaaprjun2011.Organization_Name == 'CITY OF LAS PINAS']

# %%
CLP_Abaaprjun2011.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32 entries, 1722 to 87202
# Data columns (total 26 columns):
# Organization_Name         32 non-null object
# Reference_No              32 non-null object
# Bid_Notice_Title          32 non-null object
# Publish_Date              32 non-null datetime64[ns]
# Classification            32 non-null object
# Notice_Type               32 non-null object
# Business_Category         32 non-null object
# Funding_Source            32 non-null object
# Procurement_Mode          32 non-null object
# Trade_Agreement           32 non-null object
# Approved_Budget           32 non-null float64
# Item_No                   32 non-null float64
# Item_Name                 32 non-null object
# Item_Description          32 non-null object
# Item_Budget               32 non-null float64
# Closing_Date              32 non-null datetime64[ns]
# Bid_Notice_Status         32 non-null object
# Award_No                  32 non-null float64
# ...

# %% [markdown]
# ### Awardees

# %%
CLP_Abaaprjun2011.Awardee.value_counts().reset_index()
# Out:
#                              index  Awardee
# 0         E.M. ANGELES ENTERPRISES       12
# 1              EXEL CONCEPTS CORP.        7
# 2        CYNDEL GENERAL CONTRACTOR        5
# 3                ARAC CONSTRUCTION        4
# 4      KME DESIGN AND CONSTRUCTION        2
# 5  REDCAR TRADING AND CONSTRUCTION        2

# %% [markdown]
# ### Procurement Mode

# %%
CLP_Abaaprjun2011.Procurement_Mode.value_counts()
# Out:
# Public Bidding    32
# Name: Procurement_Mode, dtype: int64

# %% [markdown]
# #### Public Bidding

# %%
CLP_Abaaprjun2011[CLP_Abaaprjun2011.Procurement_Mode == 'Public Bidding']
# Out:
#        Organization_Name Reference_No  \
# 1722   CITY OF LAS PINAS      1458806
# 1723   CITY OF LAS PINAS      1458806
# 1724   CITY OF LAS PINAS      1458806
# 1725   CITY OF LAS PINAS      1458806
# 1726   CITY OF LAS PINAS      1458806
# 1727   CITY OF LAS PINAS      1458806
# 1728   CITY OF LAS PINAS      1458806
# 1729   CITY OF LAS PINAS      1458806
# 1730   CITY OF LAS PINAS      1458806
# 1731   CITY OF LAS PINAS      1458806
# 1732   CITY OF LAS PINAS      1458806
# 1733   CITY OF LAS PINAS      1458806
# 1734   CITY OF LAS PINAS      1458806
# 1735   CITY OF LAS PINAS      1458806
# 1736   CITY OF LAS PINAS      1458806
# 1737   CITY OF LAS PINAS      1458806
# 1738   CITY OF LAS PINAS      1458806
# 1739   CITY OF LAS PINAS      1458806
# 1740   CITY OF LAS PINAS      1458806
# 1741   CITY OF LAS PINAS      1458806
# 1742   CITY OF LAS PINAS      1458806
# 80827  CITY OF LAS PINAS      1522177
# 80828  CITY OF LAS PINAS      1522177
# ...

# %% [markdown]
# # Jul-Sep 2011

# %%
bajulsep2011 = pd.read_excel("C:/Users/wolfgang/Documents/Work/DPWH/PhilGEPS Data/2011/Bid Notice and Award Details July-Sept 2011.xlsx")

# %%
bajulsep2011.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101393 entries, 0 to 101392
# Data columns (total 26 columns):
# Organization_Name         101393 non-null object
# Reference_No              101393 non-null object
# Bid_Notice_Title          101393 non-null object
# Publish_Date              101393 non-null datetime64[ns]
# Classification            101393 non-null object
# Notice_Type               101393 non-null object
# Business_Category         101393 non-null object
# Funding_Source            101393 non-null object
# Procurement_Mode          101393 non-null object
# Trade_Agreement           101393 non-null object
# Approved_Budget           101393 non-null float64
# Item_No                   33389 non-null float64
# Item_Name                 33377 non-null object
# Item_Description          33310 non-null object
# Item_Budget               33389 non-null float64
# Closing_Date              101393 non-null datetime64[ns]
# Bid_Notice_Status         101393 non-null object
# ...

# %%
bajulsep2011.Bid_Notice_Status.value_counts()
# Out:
# Closed         79281
# Awarded        17115
# Failed          2700
# Cancelled       2267
# Shortlisted       30
# Name: Bid_Notice_Status, dtype: int64

# %%
Abajulsep2011 = bajulsep2011[bajulsep2011.Bid_Notice_Status == 'Awarded']

# %%
Abajulsep2011.Organization_Name.value_counts()
# Out:
# PROVINCE OF RIZAL                                               500
# SUPREME COURT OF THE PHILIPPINES                                370
# PROVINCE OF COMPOSTELA VALLEY                                   365
# CITY OF DIPOLOG, ZAMBOANGA DEL NORTE                            331
# CITY OF QUEZON                                                  309
# NATIONAL POWER CORPORATION SPUG-MINDANAO                        300
# MUNICIPALITY OF STO. TOMAS, BATANGAS                            242
# PHILIPPINE AMUSEMENT AND GAMING CORPORATION                     229
# PROVINCE OF CAPIZ                                               201
# BANGKO SENTRAL NG PILIPINAS                                     199
# CITY OF ILOILO                                                  188
# CITY OF CALAMBA, LAGUNA                                         187
# CITY OF SAN CARLOS, NEGROS OCCIDENTAL                           182
# UNIVERSITY OF THE PHILIPPINES SYSTEM - DILIMAN                  172
# ...

# %% [markdown]
# ## Awarded DPWH

# %%
DPWH_Abajulsep2011 = Abajulsep2011[Abajulsep2011.Organization_Name == 'DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN']

# %%
DPWH_Abajulsep2011.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 54 entries, 1331 to 94912
# Data columns (total 26 columns):
# Organization_Name         54 non-null object
# Reference_No              54 non-null object
# Bid_Notice_Title          54 non-null object
# Publish_Date              54 non-null datetime64[ns]
# Classification            54 non-null object
# Notice_Type               54 non-null object
# Business_Category         54 non-null object
# Funding_Source            54 non-null object
# Procurement_Mode          54 non-null object
# Trade_Agreement           54 non-null object
# Approved_Budget           54 non-null float64
# Item_No                   5 non-null float64
# Item_Name                 5 non-null object
# Item_Description          5 non-null object
# Item_Budget               5 non-null float64
# Closing_Date              54 non-null datetime64[ns]
# Bid_Notice_Status         54 non-null object
# Award_No                  54 non-null float64
# ...

# %% [markdown]
# ### Awardees

# %%
DPWH_Abajulsep2011.Awardee.value_counts()
# Out:
# CENTRAL LOCKWOOD HARDWARE AND LUMBER INC.                4
# O.R. SARMIENTO CONSTRUCTION                              3
# MCSA MARKETING                                           3
# HANJIN HEAVY INDUSTRIES & CONSTRUCTION CO., LTD.         2
# J.D. LEGASPI CONSTRUCTION                                2
# FOXROD AUTO PARTS AND SERVICES                           2
# GILCOR PRINTING PRESS                                    2
# TRI-GLOBE TRANSPORT SERVICES AND TRADING, INC.           2
# MICROBASE INCORPORATED                                   2
# VICENTE T. LAO CONSTRUCTION                              2
# CIVIC MERCHANDISING, INC.                                1
# RHINE MARKETING CORPORATION - MAKATI                     1
# CENTER FOR ENVIRONMENTAL STUDIES AND MANAGEMENT, INC.    1
# EDDMARI CONSTRUCTION & TRADING                           1
# E.H. SISON ENGINEERS, CO. (EHSEC)                        1
# HAIDEE CONSTRUCTION & DEVELOPMENT CORPORATION            1
# ...

# %% [markdown]
# ### Procurement Mode

# %%
DPWH_Abajulsep2011.Procurement_Mode.value_counts()
# Out:
# Shopping                             24
# Public Bidding                       24
# International Competitive Bidding     5
# Negotiated Procurement                1
# Name: Procurement_Mode, dtype: int64

# %% [markdown]
# #### Shopping

# %%
DPWH_Abajulsep2011[DPWH_Abajulsep2011.Procurement_Mode == "Shopping"]
# Out:
#                                     Organization_Name Reference_No  \
# 1331   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1534025
# 10424  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1541490
# 10473  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1541538
# 14531  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1544863
# 28080  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1555608
# 28086  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1555615
# 30622  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1557487
# 39478  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1563458
# 39479  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1563459
# 46474  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1568940
# 46492  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1568961
# 46514  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1568990
# 46527  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1569007
# ...

# %% [markdown]
# #### Public Bidding

# %%
DPWH_Abajulsep2011[DPWH_Abajulsep2011.Procurement_Mode == 'Public Bidding']
# Out:
#                                     Organization_Name Reference_No  \
# 4514   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1536724
# 11130  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1542140
# 11291  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1542296
# 15417  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1544739
# 34470  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1559742
# 35965  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1560887
# 35966  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1560887
# 35967  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1560887
# 35968  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1560887
# 39091  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1563094
# 40919  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1564579
# 47002  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1569477
# 48654  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1570309
# ...

# %% [markdown]
# #### International Competitive Bidding

# %%
DPWH_Abajulsep2011[DPWH_Abajulsep2011.Procurement_Mode == 'International Competitive Bidding']
# Out:
#                                     Organization_Name Reference_No  \
# 84474  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1599656
# 86367  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1600555
# 91754  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1605139
# 91781  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1605162
# 92138  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1605471
#
#                                         Bid_Notice_Title Publish_Date  \
# 84474  Construction Works for the Widening of Gapan –...   2011-09-15
# 86367  Construction of Bacolod Silay Airport Access R...   2011-09-17
# 91754  Asphalt Overlay of Manila North Road (Pasuquin...   2011-09-22
# 91781  Asphalt Overlay of Sayre Highway (Kitaotao Kib...   2011-09-22
# 92138  CS RI 03: CONSULTANCY SERVICES TO UNDERTAKE TH...   2011-09-22
#
#             Classification                         Notice_Type  \
# 84474          Civil Works             Invitation to Bid (ITB)
# ...

# %% [markdown]
# #### Negotiated Procurement

# %%
DPWH_Abajulsep2011[DPWH_Abajulsep2011.Procurement_Mode == 'Negotiated Procurement']
# Out:
#                                     Organization_Name Reference_No  \
# 61518  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1580682
#
#                                         Bid_Notice_Title Publish_Date  \
# 61518  Consulting Services for Structural Investigati...   2011-08-24
#
#             Classification                        Notice_Type  \
# 61518  Consulting Services  Notice for Negotiated Procurement
#
#          Business_Category                       Funding_Source  \
# 61518  Consulting Services  Government of the Philippines (GOP)
#
#              Procurement_Mode                     Trade_Agreement  \
# 61518  Negotiated Procurement  Implementing Rules and Regulations
#
#        Approved_Budget  Item_No Item_Name Item_Description  Item_Budget  \
# 61518        2100000.0      NaN       NaN              NaN          NaN
#
#              Closing_Date Bid_Notice_Status  Award_No  \
# 61518 2011-08-30 05:00:00           Awarded  273538.0
#
# ...

# %% [markdown]
# ## City of Las Pinas

# %%
CLP_Abajulsep2011 = Abajulsep2011[Abajulsep2011.Organization_Name == 'CITY OF LAS PINAS']

# %%
CLP_Abajulsep2011.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 35 entries, 3617 to 28921
# Data columns (total 26 columns):
# Organization_Name         35 non-null object
# Reference_No              35 non-null object
# Bid_Notice_Title          35 non-null object
# Publish_Date              35 non-null datetime64[ns]
# Classification            35 non-null object
# Notice_Type               35 non-null object
# Business_Category         35 non-null object
# Funding_Source            35 non-null object
# Procurement_Mode          35 non-null object
# Trade_Agreement           35 non-null object
# Approved_Budget           35 non-null float64
# Item_No                   34 non-null float64
# Item_Name                 34 non-null object
# Item_Description          34 non-null object
# Item_Budget               34 non-null float64
# Closing_Date              35 non-null datetime64[ns]
# Bid_Notice_Status         35 non-null object
# Award_No                  35 non-null float64
# ...

# %% [markdown]
# ### Awardees

# %%
CLP_Abajulsep2011.Awardee.value_counts().reset_index()
# Out:
#                              index  Awardee
# 0         E.M. ANGELES ENTERPRISES       16
# 1                ARAC CONSTRUCTION        7
# 2              EXEL CONCEPTS CORP.        5
# 3        CYNDEL GENERAL CONTRACTOR        3
# 4      KME DESIGN AND CONSTRUCTION        3
# 5  REDCAR TRADING AND CONSTRUCTION        1

# %% [markdown]
# ### Procurement Mode

# %%
CLP_Abajulsep2011.Procurement_Mode.value_counts()
# Out:
# Public Bidding    35
# Name: Procurement_Mode, dtype: int64

# %% [markdown]
# #### Public Bidding

# %%
CLP_Abajulsep2011[CLP_Abajulsep2011.Procurement_Mode == 'Public Bidding']
# Out:
#        Organization_Name Reference_No  \
# 3617   CITY OF LAS PINAS      1535968
# 3618   CITY OF LAS PINAS      1535968
# 3619   CITY OF LAS PINAS      1535968
# 3620   CITY OF LAS PINAS      1535968
# 3621   CITY OF LAS PINAS      1535968
# 3622   CITY OF LAS PINAS      1535968
# 3623   CITY OF LAS PINAS      1535968
# 3624   CITY OF LAS PINAS      1535968
# 3625   CITY OF LAS PINAS      1535968
# 3626   CITY OF LAS PINAS      1535968
# 3627   CITY OF LAS PINAS      1535968
# 3628   CITY OF LAS PINAS      1535968
# 3683   CITY OF LAS PINAS      1536044
# 5570   CITY OF LAS PINAS      1535200
# 5571   CITY OF LAS PINAS      1535200
# 5572   CITY OF LAS PINAS      1535200
# 5573   CITY OF LAS PINAS      1535200
# 5574   CITY OF LAS PINAS      1535200
# 5575   CITY OF LAS PINAS      1535200
# 5576   CITY OF LAS PINAS      1535200
# 5577   CITY OF LAS PINAS      1535200
# 5578   CITY OF LAS PINAS      1535200
# 5579   CITY OF LAS PINAS      1535200
# ...

# %% [markdown]
# # Oct-Dec 2011

# %%
baoctdec2011 = pd.read_excel("C:/Users/wolfgang/Documents/Work/DPWH/PhilGEPS Data/2011/Bid Notice and Award Details Oct-Dec 2011.xlsx")

# %%
baoctdec2011.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106804 entries, 0 to 106803
# Data columns (total 26 columns):
# Organization_Name         106804 non-null object
# Reference_No              106804 non-null object
# Bid_Notice_Title          106804 non-null object
# Publish_Date              106804 non-null datetime64[ns]
# Classification            106804 non-null object
# Notice_Type               106804 non-null object
# Business_Category         106804 non-null object
# Funding_Source            106804 non-null object
# Procurement_Mode          106804 non-null object
# Trade_Agreement           106804 non-null object
# Approved_Budget           106804 non-null float64
# Item_No                   35328 non-null float64
# Item_Name                 35271 non-null object
# Item_Description          35206 non-null object
# Item_Budget               35328 non-null float64
# Closing_Date              106804 non-null datetime64[ns]
# Bid_Notice_Status         106804 non-null object
# ...

# %%
baoctdec2011.Bid_Notice_Status.value_counts().reset_index()
# Out:
#          index  Bid_Notice_Status
# 0       Closed              82746
# 1      Awarded              19164
# 2    Cancelled               2461
# 3       Failed               2403
# 4  Shortlisted                 30

# %%
Abaoctdec2011 = baoctdec2011[baoctdec2011.Bid_Notice_Status == 'Awarded']

# %%
Abaoctdec2011.Organization_Name.value_counts()
# Out:
# PROVINCE OF LAGUNA                                              734
# PROVINCE OF COMPOSTELA VALLEY                                   666
# PROVINCE OF RIZAL                                               495
# CITY OF QUEZON                                                  378
# MANILA INTERNATIONAL AIRPORT AUTHORITY                          360
# PHILIPPINE AMUSEMENT AND GAMING CORPORATION                     359
# CITY OF DIPOLOG, ZAMBOANGA DEL NORTE                            307
# CITY OF CALAMBA, LAGUNA                                         233
# PROVINCE OF CAPIZ                                               208
# PROVINCE OF ALBAY                                               201
# NATIONAL POWER CORPORATION SPUG-MINDANAO                        195
# CITY OF ZAMBOANGA, ZAMBOANGA DEL SUR                            182
# DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MALABON-NAVOTAS SD    176
# CITY OF ILOILO                                                  165
# ...

# %% [markdown]
# ## Awarded DPWH

# %%
DPWH_Abaoctdec2011 = Abaoctdec2011[Abaoctdec2011.Organization_Name == 'DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN']

# %%
DPWH_Abaoctdec2011.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 37 entries, 1086 to 97827
# Data columns (total 26 columns):
# Organization_Name         37 non-null object
# Reference_No              37 non-null object
# Bid_Notice_Title          37 non-null object
# Publish_Date              37 non-null datetime64[ns]
# Classification            37 non-null object
# Notice_Type               37 non-null object
# Business_Category         37 non-null object
# Funding_Source            37 non-null object
# Procurement_Mode          37 non-null object
# Trade_Agreement           37 non-null object
# Approved_Budget           37 non-null float64
# Item_No                   14 non-null float64
# Item_Name                 14 non-null object
# Item_Description          14 non-null object
# Item_Budget               14 non-null float64
# Closing_Date              37 non-null datetime64[ns]
# Bid_Notice_Status         37 non-null object
# Award_No                  37 non-null float64
# ...

# %% [markdown]
# ### Awardees

# %%
DPWH_Abaoctdec2011.Awardee.value_counts()
# Out:
# VICENTE T. LAO CONSTRUCTION                                  3
# J.D. LEGASPI CONSTRUCTION                                    3
# ULTICON BUILDERS, INC.                                       2
# CIVIC MERCHANDISING, INC.                                    2
# R. D. INTERIOR JUNIOR CONSTRUCTION                           2
# CENTRAL LOCKWOOD HARDWARE AND LUMBER INC.                    2
# HUNAN ROAD & BRIDGE CORPORATION PHIL. BRANCH                 1
# NORTHERN BUILDERS                                            1
# ASSOCIATED RESOURCES FOR MANAGEMENT AND DEVELOPMENT, INC.    1
# P.T. DIAMOND MERCHANDISE AND CONSTRUCTION                    1
# MICROBASE INCORPORATED                                       1
# LUZON SALES COMPANY, INCORPORATED                            1
# DEVELOPMENT ACADEMY OF THE PHILIPPINES                       1
# FILPRIDE RESOURCES INC.                                      1
# BIOSPHERE CONSTRUCTION AND SUPPLIES, INC.                    1
# ...

# %% [markdown]
# ### Procurement Mode

# %%
DPWH_Abaoctdec2011.Procurement_Mode.value_counts()
# Out:
# Public Bidding                                           24
# Shopping                                                 10
# Negotiated Procurement - Agency to Agency (Sec. 53.5)     1
# Negotiated Procurement                                    1
# International Competitive Bidding                         1
# Name: Procurement_Mode, dtype: int64

# %% [markdown]
# #### Public Bidding

# %%
DPWH_Abaoctdec2011[DPWH_Abaoctdec2011.Procurement_Mode == 'Public Bidding']
# Out:
#                                     Organization_Name Reference_No  \
# 1086   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1614062
# 4773   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1616276
# 8806   DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1619585
# 13906  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1623493
# 17223  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1626493
# 17241  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1626513
# 24270  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1630900
# 27507  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1633792
# 35487  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1639595
# 35539  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1639660
# 35565  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1639697
# 35721  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1639854
# 35758  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1639881
# ...

# %% [markdown]
# #### Shopping

# %%
DPWH_Abaoctdec2011[DPWH_Abaoctdec2011.Procurement_Mode == 'Shopping']
# Out:
#                                     Organization_Name Reference_No  \
# 13831  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1623432
# 19088  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1627968
# 19210  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1628164
# 37363  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1641059
# 51325  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1652594
# 51842  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1653104
# 69558  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1666563
# 92017  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1685695
# 96537  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1689218
# 96572  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1689244
#
#                                         Bid_Notice_Title Publish_Date  \
# 13831  SUPPLY OF 8 PCS. TONER CARTRIDGE FOR LEXMARK W...   2011-10-12
# 19088  14 PCS DRUM FOR BROTHER HL 6050DN PRINTER 42 P...   2011-10-15
# ...

# %% [markdown]
# #### Negotiated Procurement - Agency to Agency (Sec. 53.5)

# %%
DPWH_Abaoctdec2011[DPWH_Abaoctdec2011.Procurement_Mode == 'Negotiated Procurement - Agency to Agency (Sec. 53.5)']
# Out:
#                                     Organization_Name Reference_No  \
# 97827  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1690474
#
#                                         Bid_Notice_Title Publish_Date  \
# 97827  Consultancy Services for the Executive Leaders...   2011-12-16
#
#             Classification                        Notice_Type  \
# 97827  Consulting Services  Notice for Negotiated Procurement
#
#          Business_Category                       Funding_Source  \
# 97827  Consulting Services  Government of the Philippines (GOP)
#
#                                         Procurement_Mode  \
# 97827  Negotiated Procurement - Agency to Agency (Sec...
#
#                           Trade_Agreement  Approved_Budget  Item_No Item_Name  \
# 97827  Implementing Rules and Regulations         941623.2      NaN       NaN
#
#       Item_Description  Item_Budget        Closing_Date Bid_Notice_Status  \
# ...

# %% [markdown]
# #### Negotiated Procurement

# %%
DPWH_Abaoctdec2011[DPWH_Abaoctdec2011.Procurement_Mode == 'Negotiated Procurement']
# Out:
#                                     Organization_Name Reference_No  \
# 68204  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1665449
#
#                                         Bid_Notice_Title Publish_Date  \
# 68204  (Negotiated Procurement) Strengthening/Retrofi...   2011-11-24
#
#       Classification                        Notice_Type  \
# 68204    Civil Works  Notice for Negotiated Procurement
#
#            Business_Category                       Funding_Source  \
# 68204  Construction Projects  Government of the Philippines (GOP)
#
#              Procurement_Mode                     Trade_Agreement  \
# 68204  Negotiated Procurement  Implementing Rules and Regulations
#
#        Approved_Budget  Item_No Item_Name Item_Description  Item_Budget  \
# 68204      42164909.97      NaN       NaN              NaN          NaN
#
#              Closing_Date Bid_Notice_Status  Award_No  \
# 68204 2011-12-02 10:00:00           Awarded  287712.0
#
# ...

# %% [markdown]
# #### International Competitive Bidding

# %%
DPWH_Abaoctdec2011[DPWH_Abaoctdec2011.Procurement_Mode == 'International Competitive Bidding']
# Out:
#                                     Organization_Name Reference_No  \
# 25925  DEPARTMENT OF PUBLIC WORKS AND HIGHWAYS - MAIN      1632425
#
#                                         Bid_Notice_Title Publish_Date  \
# 25925  CP RI 2.2: Bongabong Bypass, Danggay Jct. Roxa...   2011-10-20
#
#       Classification              Notice_Type      Business_Category  \
# 25925    Civil Works  Invitation to Bid (ITB)  Construction Projects
#
#         Funding_Source                   Procurement_Mode  \
# 25925  World Bank (WB)  International Competitive Bidding
#
#                  Trade_Agreement  Approved_Budget  Item_No Item_Name  \
# 25925  WB Procurement Guidelines              0.0      NaN       NaN
#
#       Item_Description  Item_Budget        Closing_Date Bid_Notice_Status  \
# 25925              NaN          NaN 2011-12-19 17:00:00           Awarded
#
#        Award_No                                        Award_Title  \
# ...

# %% [markdown]
# ## City of Las Pinas

# %%
CLP_Abaoctdec2011 = Abaoctdec2011[Abaoctdec2011.Organization_Name == 'CITY OF LAS PINAS']

# %% [markdown]
# ### Awardee

# %%
CLP_Abaoctdec2011.Awardee.value_counts()
# Out:
# ARAC CONSTRUCTION                  11
# E.M. ANGELES ENTERPRISES            6
# CYNDEL GENERAL CONTRACTOR           3
# KME DESIGN AND CONSTRUCTION         2
# EXEL CONCEPTS CORP.                 2
# REDCAR TRADING AND CONSTRUCTION     1
# Name: Awardee, dtype: int64

# %% [markdown]
# ### Procurement Mode

# %%
CLP_Abaoctdec2011.Procurement_Mode.value_counts()
# Out:
# Public Bidding    25
# Name: Procurement_Mode, dtype: int64

# %% [markdown]
# #### Public Bidding

# %%
CLP_Abaoctdec2011[CLP_Abaoctdec2011.Procurement_Mode == 'Public Bidding']
# Out:
#        Organization_Name Reference_No  \
# 18464  CITY OF LAS PINAS      1622180
# 18465  CITY OF LAS PINAS      1622180
# 18466  CITY OF LAS PINAS      1622180
# 18467  CITY OF LAS PINAS      1622180
# 18468  CITY OF LAS PINAS      1622180
# 18469  CITY OF LAS PINAS      1622180
# 18470  CITY OF LAS PINAS      1622180
# 18471  CITY OF LAS PINAS      1622180
# 18472  CITY OF LAS PINAS      1622180
# 18473  CITY OF LAS PINAS      1622180
# 18474  CITY OF LAS PINAS      1622180
# 18475  CITY OF LAS PINAS      1622180
# 18476  CITY OF LAS PINAS      1622180
# 18477  CITY OF LAS PINAS      1622180
# 18478  CITY OF LAS PINAS      1622180
# 18479  CITY OF LAS PINAS      1622180
# 38818  CITY OF LAS PINAS      1642625
# 38819  CITY OF LAS PINAS      1642625
# 38820  CITY OF LAS PINAS      1642625
# 38821  CITY OF LAS PINAS      1642625
# 43544  CITY OF LAS PINAS      1646336
# 77589  CITY OF LAS PINAS      1674043
# 77590  CITY OF LAS PINAS      1674043
# ...
