# %%
import pandas as pd
import numpy as np

# %%
pd.options.display.max_columns = None
pd.options.display.max_rows = None

# %% [markdown]
# # January to March

# %%
bajanmar2017 = pd.read_excel("C:/Users/wolfgang/Documents/Work/2018/PhilGEPS_2016-2017/2017/Bid Notice and Award Details Jan-Mar 2017.xlsx")

# %%
bajanmar2017.Organization_Name.value_counts()
# Out:
# AGUSAN DEL SUR STATE COLLEGE OF AGRICULTURE AND TECHNOLOGY      2130
# VETERANS MEMORIAL MEDICAL CENTER, DND                           1664
# BATAAN GENERAL HOSPITAL                                         1557
# DAVAO REGIONAL MEDICAL CENTER                                   1324
# CITY OF DIGOS, DAVAO DEL SUR                                    1297
# PROVINCE OF CEBU                                                1249
# MUNICIPALITY OF SOCORRO , SURIGAO DEL NORTE                     1248
# CITY OF LEGAZPI, ALBAY                                          1174
# CITY OF BAIS, NEGROS ORIENTAL                                   1123
# PROVINCE OF BATAAN                                              1114
# VETERANS REGIONAL HOSPITAL                                      1108
# BICOL MEDICAL CENTER                                            1085
# BICOL REGIONAL TRAINING AND TEACHING HOSPITAL                   1012
# MUNICIPALITY OF SIOCON                                          1005
# ...

# %%
bajanmar2017.Award_Status.value_counts().reset_index()
# Out:
#        index  Award_Status
# 0    Updated         26845
# 1     Posted         15875
# 2  Cancelled            94

# %%
bajanmar2017.Notice_Status.value_counts().reset_index()
# Out:
#          index  Notice_Status
# 0       Closed         162548
# 1      Awarded          37966
# 2       Failed           9341
# 3    Cancelled           6548
# 4  Shortlisted            106
# 5       Active             11

# %%
Abajanmar2017 = bajanmar2017[bajanmar2017.Notice_Status == 'Awarded']

# %%
Abajanmar2017.Organization_Name.value_counts()
# Out:
# PHILIPPINE NATIONAL POLICE - LOGISTICS SUPPORT SERVICE          552
# PROVINCE OF KALINGA                                             539
# CORAZON LOCSIN MONTELIBANO MEMORIAL REGIONAL HOSPITAL-DOH R6    448
# MUNICIPALITY OF KAPALONG, DAVAO DEL NORTE                       447
# MUNICIPALITY OF VALLEHERMOSO, NEGROS                            416
# MISAMIS ORIENTAL STATE COLLEGE OF AGRICULTURE AND TECHNOLOGY    291
# MUNICIPALITY OF QUEZON, PALAWAN                                 288
# MUNICIPALITY OF ABUYOG, LEYTE                                   288
# LANDBANK OF THE PHILIPPINES - HEAD OFFICE                       255
# UNIVERSITY OF THE PHILIPPINES - DILIMAN                         241
# PROVINCE OF AGUSAN DEL SUR                                      231
# TONDO MEDICAL CENTER                                            228
# PHILIPPINE COAST GUARD                                          218
# PROVINCE OF ILOCOS NORTE                                        216
# ...

# %%
PPA_R11_janmar2017 = Abajanmar2017[Abajanmar2017.Organization_Name == 'PHILIPPINE PORTS AUTHORITY - REGION XI']

# %%
PPA_R11_janmar2017
# Out:
#                              Organization_Name Reference_ID  \
# 107305  PHILIPPINE PORTS AUTHORITY - REGION XI      4354929
# 146954  PHILIPPINE PORTS AUTHORITY - REGION XI      4386462
# 147017  PHILIPPINE PORTS AUTHORITY - REGION XI      4386537
# 171150  PHILIPPINE PORTS AUTHORITY - REGION XI      4403679
#
#                                              Notice_Title Publish_Date  \
# 107305  Request for Quotation re Repair of Port Manage...   2017-02-22
# 146954  Request for Quotation re T-Shirt with Collar, ...   2017-03-09
# 147017      Request for Quotation re Printer, 3 in 1 CISS   2017-03-09
# 171150  SVRM-17-03 re Refurbishing of Wall Finishes an...   2017-03-16
#
#        Classification                  Notice_Type  \
# 107305          Goods  Request for Quotation (RFQ)
# 146954          Goods  Request for Quotation (RFQ)
# 147017          Goods  Request for Quotation (RFQ)
# 171150          Goods  Request for Quotation (RFQ)
#
# ...

# %%
PPA_R11_janmar2017.Awardee_Corporate_Title.value_counts().reset_index()
# Out:
#                    index  Awardee_Corporate_Title
# 0       ZET CONSTRUCTION                        2
# 1  VENMARK SOUVENIR SHOP                        1
# 2  DIGITAL INTERFACE INC                        1

# %%
PPA_R11_janmar2017.Award_Status.value_counts()
# Out:
# Posted     2
# Updated    2
# Name: Award_Status, dtype: int64

# %% [markdown]
# # April to June 2017

# %%
baaprjun2017 = pd.read_excel("C:/Users/wolfgang/Documents/Work/2018/PhilGEPS_2016-2017/2017/Bid Notice and Award Details Apr-June 2017.xlsx")

# %%
baaprjun2017.Award_Status.value_counts().reset_index()
# Out:
#        index  Award_Status
# 0    Updated         10888
# 1     Posted         10346
# 2  Cancelled            27

# %%
baaprjun2017.Notice_Status.value_counts().reset_index()
# Out:
#          index  Notice_Status
# 0       Closed         200557
# 1      Awarded          19988
# 2       Failed           7707
# 3       Active           7690
# 4    Cancelled           6152
# 5  Shortlisted             43

# %%
baaprjun2017[baaprjun2017.Organization_Name == 'PHILIPPINE PORTS AUTHORITY - HEAD OFFICE']
# Out:
#                                Organization_Name Reference_ID  \
# 309     PHILIPPINE PORTS AUTHORITY - HEAD OFFICE      4439806
# 808     PHILIPPINE PORTS AUTHORITY - HEAD OFFICE      4441157
# 15450   PHILIPPINE PORTS AUTHORITY - HEAD OFFICE      4451027
# 17926   PHILIPPINE PORTS AUTHORITY - HEAD OFFICE      4452743
# 22015   PHILIPPINE PORTS AUTHORITY - HEAD OFFICE      4455686
# 22099   PHILIPPINE PORTS AUTHORITY - HEAD OFFICE      4455838
# 22377   PHILIPPINE PORTS AUTHORITY - HEAD OFFICE      4456260
# 23110   PHILIPPINE PORTS AUTHORITY - HEAD OFFICE      4457268
# 27197   PHILIPPINE PORTS AUTHORITY - HEAD OFFICE      4459076
# 27297   PHILIPPINE PORTS AUTHORITY - HEAD OFFICE      4459156
# 32523   PHILIPPINE PORTS AUTHORITY - HEAD OFFICE      4463305
# 32927   PHILIPPINE PORTS AUTHORITY - HEAD OFFICE      4463492
# 48763   PHILIPPINE PORTS AUTHORITY - HEAD OFFICE      4475431
# 49901   PHILIPPINE PORTS AUTHORITY - HEAD OFFICE      4476475
# ...

# %%
Abaaprjun2017 = baaprjun2017[baaprjun2017.Notice_Status == 'Awarded']

# %%
Abaaprjun2017.Organization_Name.value_counts()
# Out:
# MUNICIPALITY OF KAPALONG, DAVAO DEL NORTE                       492
# PHILIPPINE NATIONAL POLICE - LOGISTICS SUPPORT SERVICE          490
# PHILIPPINE COAST GUARD                                          264
# CITY OF DIGOS, DAVAO DEL SUR                                    241
# PROVINCE OF DAVAO ORIENTAL                                      211
# PROVINCE OF KALINGA                                             172
# DEPARTMENT OF AGRICULTURE - REGION VI                           167
# LUNG CENTER OF THE PHILIPPINES                                  164
# HOME DEVELOPMENT MUTUAL FUND - CORPORATE HEADQUARTERS           126
# CITY OF TACURONG, SULTAN KUDARAT                                124
# MUNICIPALITY OF ALBUERA, LEYTE                                  116
# PROVINCE OF ALBAY                                               113
# CARAGA STATE UNIVERSITY                                         104
# MUNICIPALITY OF PINILI, ILOCOS NORTE                             98
# ...

# %%
PPA_HQ_aprjun2017 = Abaaprjun2017[Abaaprjun2017.Organization_Name == 'PHILIPPINE PORTS AUTHORITY - HEAD OFFICE']

# %%
PPA_HQ_aprjun2017.Awardee_Corporate_Title.value_counts()
# Out:
# WTG CONSTRUCTION AND DEVELOPMENT CORPORATION                                                                   1
# GOLDRIDGE CONST. & DEV'T. CORP.                                                                                1
# GOLDRIDGE CONSTRUCTION & DEVELOPMENT INC./DALEBO CONSTRUCTION &GEN. MERCHANDISE/JOINT VENTURE                  1
# BCT TRADING AND CONSTRUCTION                                                                                   1
# LUCK-WELL CONSTRUCTION                                                                                         1
# MULTI-SYSTEM CONSTRUCTION AND DEVELOPMENT CORP./ RT CRISMAN BUILDERS AND CONSTRUCTION SUPPLY/ JOINT VENTURE    1
# MRBII CONSTRUCTION CORPORATION                                                                                 1
# Name: Awardee_Corporate_Title, dtype: int64

# %%
PPA_R11_aprjun2017 = Abaaprjun2017[Abaaprjun2017.Organization_Name == 'PHILIPPINE PORTS AUTHORITY - REGION XI']

# %%
PPA_R11_aprjun2017.Awardee_Corporate_Title.value_counts()
# Out:
# KHAN KON CHI CONSTRUCTION          2
# TIPICON ENGINEERING INNOVATIONS    1
# Name: Awardee_Corporate_Title, dtype: int64
